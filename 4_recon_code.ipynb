# %% [markdown]
# # **Recon Algorithm**
#
# This code comes from https://github.com/ArnaoutLab/Recon. It is only slightly adapted to use in a jupyter notebook format here.

# %% [markdown]
# # Imports & Google Drive Setup

# %%
import argparse # added
from argparse import ArgumentParser, REMAINDER, RawDescriptionHelpFormatter
from ast import literal_eval
from collections import defaultdict
# from subprocess import getoutput
import subprocess
from datetime import datetime
from math import isnan, log, ceil, floor, exp, factorial
from numpy import sqrt, array, interp, mean, arange
from os.path import expanduser, isfile, isdir, dirname, abspath, exists, isabs
from os import listdir, system, getcwd
# from scipy.optimize.lbfgsb import _minimize_lbfgsb as minimize # Deprecated, changed to line below
from scipy.optimize import minimize
from sys import argv, exit, stdout
from time import time
from traceback import print_exc
import warnings

#new
from collections import Counter

# added
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
from pathlib import Path
import os

# %%
drive.mount('/content/drive')
# !ls
# Out:
# Mounted at /content/drive
# drive  sample_data

# %%
PATH = "/content/drive/MyDrive/Data Science/Thesis/Recon"
os.chdir(PATH)

# %%
pwd
# Out:
# '/content/drive/MyDrive/Data Science/Thesis/Recon'

# %% [markdown]
# # Code to run (Adapted from Parser)

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
verbose = True # print verbose output to stdout
very_verbose = True # print even more verbose output to stdout
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
file_in = ['df_fill_in_1_5.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# # Parser

# %%
parser = argparse.ArgumentParser(formatter_class=argparse.RawDescriptionHelpFormatter) # added

# formatter_class=RawDescriptionHelpFormatter) # try to maintain alphabetical order a-zA-z # removed
parser.add_argument('-a', '--aicc_multiple', type=float, default=1.3, help='multiple of the observed number of datapoints used for AICc')
parser.add_argument('-b', '--precomputed_error_bar_file', type=str, help='file name for precomputed error bars')
parser.add_argument('-c', '--clone_distribution_in_file', action='store_true', help='input file is of the form clone_size tab number_of_clones of that size')
parser.add_argument('-d', '--bin_size', type=int, default=1, help='average number of observations for each individual')
parser.add_argument('-df', '--D_number_file', default=None, type=str, help='D-number file (output of -D option)')
parser.add_argument('-e', '--make_error_bars', action='store_true', help='make a precomputed error bar file that can be used to calculate error bars')
parser.add_argument('-f', '--fraction_small_clones', default=0.1, type=float, help='see get_sampling_limit')
parser.add_argument('-ff', '--fit_file', default=None, type=str, help='Recon fit-file (output of -R option)')
parser.add_argument("-j", "--javascript_file", default="plot_clone_size_distribution_ref.js", help="reference javascript file, for plotting resample")
parser.add_argument('-l', '--parameter_limit', default=20, type=int, help='maximum number of parameters to fit')
parser.add_argument('-m', '--min_number_of_doublets', default=100, type=int, help='see get_sampling_limit')
parser.add_argument('-n', '--number_of_error_bars', default=2., type=float, help='mapping between gold-standard error bar fits and standard deviations in power calculation')
parser.add_argument('-o', '--file_out', default="test_recon_output.txt", type=str, help='output file for fit')
parser.add_argument('-p', '--make_power_table', action='store_true', help='output a table of cells required to see fold difference')
parser.add_argument('-q', '--q', type=str, default=0., help='Hill number parameter to use when making table for power calculations')
parser.add_argument('-r', '--resample', action='store_true', help='output a resampling of the model fit with the given fit file')
parser.add_argument('-s', '--noise_test_ratio_threshold', default=3., type=float, help='for avoiding fitting noise')
parser.add_argument('-ss', '--sample_size', default=None, type=float, help='sample size, for calculating U_max')
parser.add_argument('-t', '--threshold', type=int, default=30, help='largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed')
parser.add_argument('-u', '--cutoff_score', type=float, default=0.1, help='for stopping iteration when estimated clone distribution is at a fixed point')
parser.add_argument('-v', '--verbose', action='store_true', help='print verbose output to stdout')
parser.add_argument('-vv', '--very_verbose', action='store_true', help='print even more verbose output to stdout')
parser.add_argument('-x', '--make_resample_plot', action='store_true', help="plots resample of fit against original sample")
parser.add_argument('-A', '--total_clones_in_overall_population', type=float, default=None, help='total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution (optionally)')
parser.add_argument('-C', '--list_of_number_of_clones', nargs='+', default=[1e4, 3e4, 1e5, 1e6, 3e6], help='column headers for power table')
parser.add_argument('-D', '--make_table_of_D_numbers', action='store_true', help='output a table of reconstructed D numbers with error bars from input fit files.')
parser.add_argument('-F', '--list_of_fold_differences', nargs='+', default=[1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.], help='row titles for power table')
parser.add_argument('-N', '--N', default=None, type=float, help='overall population size, for calculating U_max')
parser.add_argument('-Q', '--qs', nargs='+', default=[0., 1., 2., float('inf')], help='space-separated list of Hill-number parameters for making error-bar files and table of D numbers')
parser.add_argument('-R', '--run_recon', action='store_true', help='run Recon on sample to generate overall distribution parameters and fit file')
parser.add_argument('-S', '--initial_scale_factors', nargs='+', default=[0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1], help='for determining means')
parser.add_argument('-U', '--resource_path', type=str, default = expanduser('~')+"/Desktop", help='folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js')
parser.add_argument('-Umax', '--upper_bound', action='store_true', help='calculate U_max')
parser.add_argument('-W', '--test_weights_list', nargs='+', default=[0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6], help='list of weights to attempt to add')
parser.add_argument('-X', '--x_max', type=float, default=None, help='the x_max for the output plot')
parser.add_argument('-Y', '--y_max', type=float, default=None, help='the y_max for the output plot (note, log scale)')

parser.add_argument('file_in', nargs=REMAINDER, help='list of file names containing clone data. A long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files')

args = parser.parse_args()
globals().update(vars(args))
if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# # Classes

# %%
# CLASSES ===============================================

class mixed_distribution:
    """
    A mixed_distribution object represents a mixed Poisson
    distribution.
    
    A mixed_distribution is defined by a sum of Poisson distributions
    where the weight and mean of each subdistribution must be specified
    and the weights must sum to one.
    """
    def __init__(self,weight_mean_pairs):
        total_weight = float(sum(k[0] for k in weight_mean_pairs)) # Normalise weights to 1.
        self.weights = [k[0]/total_weight for k in weight_mean_pairs]
        self.means = [float(k[1]) for k in weight_mean_pairs]
        self.weight_mean_pairs = list(zip(self.weights, self.means))

    def value_at_clone_size(self,i):
        vals = [weight*poisson_pmf(mean, i) for weight, mean in self.weight_mean_pairs]
        return sum(vals)


class sample_from_parent:
    def __init__(self, weights, means, sample_size, total_clones, population_size, total_observed_clones, estimated_n0, fitted_weights, fitted_means):
        try:
            total_weight = float(sum(weights)) # Normalise weights to 1.0
            self.weights = [weight/total_weight for weight in weights]
        except: self.weights = weights
        self.means = means
        self.sample_size = sample_size
        self.total_clones = total_clones
        self.population_size = population_size
        self.fitted_weights = fitted_weights
        self.fitted_means = fitted_means
        self.total_observed_clones = total_observed_clones
        self.estimated_n0 = estimated_n0

# %% [markdown]
# # Functions

# %%
# 1. FUNCTIONS =====================================

max_clone_size_for_which_factorials_can_be_converted_to_float = 170 # empirical platform limit
factorials = [factorial(k) for k in range( max_clone_size_for_which_factorials_can_be_converted_to_float+1 )] # need to go beyond threshold for when sample_from_model uses it
epsilon = 0.001
def poisson_pmf(mu, k): 
    try: return exp(-mu) * mu**k / factorials[k]
    except IndexError: return epsilon # if the factorial is too big, assume the result will be zero. Return an epsilon so eventually the clone limit will be reached; otherwise risk an infinite loop
    except OverflowError: pass
    try: return exp( -mu + k*log(mu) - log(factorials[k]) ) # triggered if OverflowError (number too large). Get around that by taking exp(log())
    except: pass
    return epsilon # to prevent an infinite loop

# %% [markdown]
# ## 1.1 Functions for Reconstruction

# %%
# 1.1 functions for reconstruction ==================

def calculate_AICc(AIC, number_of_parameters, effective_number_of_data_points):
    """
    AIC is the Aikaike Information Criterion and AICc the corrected
    criterion for small numbers of observations
    """
    return AIC + 2.*number_of_parameters*(number_of_parameters + 1.) / (effective_number_of_data_points - number_of_parameters - 1.)


def read_observed_clone_size_distribution_v2(file_in, clone_distribution_in_file, threshold):
    """
    Return dict[clones size] = count
    """
    # with open(file_in,'rU') as f:
    with open(file_in) as f:
        observed_clone_size_distribution = defaultdict(int)
        if clone_distribution_in_file: # Format from literature
            for line in f:
            	# below was originally written for python 2
                # if line.startswith("#") or strip(line) == "": continue
                # if line.startswith("#") or line.strip() == "": continue
                if line.startswith("#") or line.strip() == "": continue # changed because my data lines are already strings -Carla
                # if line.startswith("#") or line.str.strip() == "": continue
                try:
                    # below was originally written for python 2
                    # clone_size, no = split(strip(line), "\t")
                    clone_size, no = (line.strip()).split("\t")
                except ValueError:
                    print("Error: this line in the input file does not contain two columns separated by a tab:\n")
                    print(line)
                    print("\nExiting...")
                    exit()
                # try-except the ints
                if clone_size.isdigit() and no.isdigit():
                	clone_size = int(clone_size)
                	no = int(no)
                else:
                    print("Error: either the clone_size '%s' or the no '%s' is not an integer. These must be integers. Exiting..." % (clone_size, no))
                    exit()
                observed_clone_size_distribution[clone_size] = int(no)
        else:
            species_count_hash = defaultdict(int)
            for line in f:
            	# below was originally written for python 2
            	# if line.startswith("#") or strip(line) == "": continue
                if line.startswith("#") or line.strip() == "": continue
                try:
                    # below was originally written for python 2
                    # species, no = split(strip(line), "\t")
                    species, no = (line.strip()).split("\t")
                except ValueError:
                    print("Error: this line in the input file does not contain two columns separated by a tab:\n")
                    print(line)
                    print("\nExiting...")
                    exit()
                if no.isdigit():
                    no = int(no) # check that it's an integer, not just that you can integerize it
                else:
                    print("Error: the count for species '%s' is '%s', which appears to be not an integer. Counts must be integers. Exiting..." % (species, no))
                    exit()
                species_count_hash[species] += no
            observed_clone_size_distribution = Counter(list(species_count_hash.values()))
            if verbose: print("species_count_hash:", species_count_hash)
    # if verbose: print "observed_clone_size_distribution:", observed_clone_size_distribution
    # print(observed_clone_size_distribution)
    return observed_clone_size_distribution


def calc_log_likelihood_n0_as_data(estimated_clone_size_distribution, distribution, threshold):
    try:
        log_likelihood = sum( estimated_clone_size_distribution[k]*log(distribution.value_at_clone_size(k)) for k in range(0, threshold) ) # note 0
    except ValueError: # triggered if new_distribution.value_at_clone_size(k) = 0.
        log_likelihood = -float('inf')
        if verbose: print("Log likelihood is -inf!")
    return log_likelihood


def calc_log_likelihood_n0_as_parameter(estimated_clone_size_distribution, distribution, threshold, total_observed_clones):
    try: 
        log_likelihood = sum( estimated_clone_size_distribution[k]*log(distribution.value_at_clone_size(k)) for k in range(1, threshold) ) # note 1
        p_0 = distribution.value_at_clone_size(0)
        log_likelihood -= total_observed_clones * log(1. - p_0)
    except ValueError: # triggered if new_distribution.value_at_clone_size(k) = 0.
        log_likelihood = -float("inf")
        if verbose: print('Log likelihood is -inf!')
    return log_likelihood


def log_likelihood_score(fit_params, estimated_clone_size_distribution):
    # double check
    # weights = list(fit_params[:len(fit_params)/2])
    weights = list(fit_params[:int(len(fit_params)/2)])
    if any(weight > 0. for weight in weights):
        weights = [max(weight, 0.) for weight in weights] # Ensure this is a local variable!
    else:
        weights = [float(weight == max(weights)) for weight in weights]
        if verbose: print('All weights negative', weights)
    weight_norm = sum(weights)
    try:  weights = [weight / weight_norm for weight in weights]
    except ZeroDivisionError: weights = [1.] + weights[1:]
    weights = [1. - sum(weights[1:])] + weights[1:]
    # double check
    # means = list(fit_params[len(fit_params)/2:])
    means = list(fit_params[(int(len(fit_params/2))):]) # Ensure this is a local variable!
    means = [max(mean,1e-6) for mean in means]
    test_distribution = mixed_distribution(list(zip(weights,means)))
    log_likelihood = calc_log_likelihood_n0_as_data(estimated_clone_size_distribution, test_distribution, threshold)
    return -log_likelihood


def MLE_fit_v2(file_out, threshold, new_weights, new_means, observed_clone_size_distribution):
    """
    v2 does not return the initial parameters.
        
    The code which call MLE_fit_v2 already knows these.
    """
    if verbose: 
        print('==== BEGIN FIT ===\ninitial parameters '+str(new_weights+new_means))

    with open(file_out,'a') as f: 
        f.write('initial parameters = %s\n' % (new_weights + new_means))
    total_observed_clones = float(sum([observed_clone_size_distribution[key] for key in observed_clone_size_distribution if key < threshold]))
    new_distribution = mixed_distribution(list(zip(new_weights,new_means)))
    # print(total_observed_clones)
    # print(new_distribution)
    
    total_estimated_clones = round( total_observed_clones/(1.-new_distribution.value_at_clone_size(0)) )
    estimated_n_0 = total_estimated_clones - total_observed_clones
    estimated_clone_size_distribution = defaultdict(int)
    estimated_clone_size_distribution[0] = estimated_n_0

    for key in observed_clone_size_distribution:
        estimated_clone_size_distribution[key] = observed_clone_size_distribution[key]
    count_iterations = 0
    score_function = cutoff_score + 1. # score_function stops the iteration when the estimated clone distribution is at a fixed point.
    dictionary_of_fits = {}
    iteration_limit = 20

    while ( (score_function > cutoff_score) and (count_iterations < iteration_limit) ): # Could implement this as separate cutoffs for weights and means. Begin with one cutoff.
        count_iterations += 1

        # Step 1: Use the estimated_clone_distribution to calculate an
        # updated mixed distribution. This is the MLE of weights and
        # means given the estimated clone distribution. scorefunction2
        # stops the iteration when the weights and means are at a
        # fixed point.

        if verbose:
            print("iteration %i" % count_iterations)
            print("old estimated n0\t%i" % estimated_n_0) # This output gives the estimated clones at the start of the iteration
        old_estimated_n_0 = estimated_n_0
        start_params = array(new_weights+new_means)
        try:
            res = minimize(log_likelihood_score, # "L-BFGS-B"; no bounds or callback
                           start_params, 
                           args=(estimated_clone_size_distribution,))
            # double check
            # new_weights = list(res.x[:len(res.x)/2])
            new_weights = list(res.x[:int(len(res.x)/2)])
            if any(weight > 0 for weight in new_weights): # Useful to record in file?
                new_weights = [max(weight,0.) for weight in new_weights]
            else:
                new_weights = [float(weight == max(new_weights)) for weight in new_weights]
            weight_norm = sum(new_weights)
            new_weights = [weight / weight_norm for weight in new_weights]
            # double check
            # new_means = list(res.x[len(res.x)/2:])
            new_means = list(res.x[int(len(res.x)/2):])
            if any(new_mean < 0. for new_mean in new_means):
                new_means = [max(new_mean, 1e-6) for new_mean in new_means]
        except ValueError:
            if verbose: print("ValueError in minimize!")
            new_weights = start_params[:len(start_params)/2]
            new_means = start_params[len(start_params)/2:]
        if verbose: print("Fitted parameters (new_weights, new_means) %s %s" % (new_weights, new_means))

        # Step 2: Calculate an updated estimated_clone_distribution
        # based on old_distribution and
        # observed_clone_size_distribution

        new_distribution = mixed_distribution(list(zip(new_weights,new_means)))
        total_estimated_clones = round(total_observed_clones / (1. - new_distribution.value_at_clone_size(0)))
        estimated_n_0 = round(total_estimated_clones - total_observed_clones)
        if verbose: print("new estimated n_0\t%i" % estimated_n_0)
        estimated_clone_size_distribution[0] = estimated_n_0 # NB we could try looking at the whole of the estimated distribution, not just estimated_n0, as done here.
        try:
            score_function = 2.*abs(estimated_n_0 - old_estimated_n_0)/float(estimated_n_0 + old_estimated_n_0)
        except ZeroDivisionError:
            score_function = 0.
        if verbose: print("score_function %f" % score_function)
        log_likelihood = calc_log_likelihood_n0_as_parameter(estimated_clone_size_distribution, new_distribution, threshold, total_observed_clones)
        if verbose: print("Log likelihood\t%f\n" % log_likelihood) # Note that this is the log likelihood POST update of estimated_n_0

    dictionary_of_fits[log_likelihood] = new_weights + new_means # Take only self consistent values!
    if count_iterations == iteration_limit:
        with open(file_out,'a') as f:
            f.write("Iteration limit reached - check for only small numbers of clones appearing once or twice in sample\n")
        if verbose: print("Iteration limit reached - check for only small numbers of clones appearing once or twice in sample")
    # double check
    # new_weights = dictionary_of_fits[max(dictionary_of_fits.keys())][:len(list(dictionary_of_fits.values())[0])/2]
    # new_means = dictionary_of_fits[max(dictionary_of_fits.keys())][len(list(dictionary_of_fits.values())[0])/2:]
    new_weights = dictionary_of_fits[max(dictionary_of_fits.keys())][:(int(len(list(dictionary_of_fits.values())[0])/2))]
    new_means = dictionary_of_fits[max(dictionary_of_fits.keys())][int(len(list(dictionary_of_fits.values())[0])/2):]
    new_distribution = mixed_distribution(list(zip(new_weights,new_means)))
    total_estimated_clones = round(total_observed_clones / (1. - new_distribution.value_at_clone_size(0)))
    estimated_n_0 = round(total_estimated_clones - total_observed_clones)

    with open(file_out,'a') as f:
        f.write("\n".join([
                    'n_obs %s' % str(total_observed_clones),
                    'weights = %s' % str(new_distribution.weights),
                    'means = %s' % str(new_distribution.means),
                    'log likelihood = %s' % str(log_likelihood),
                    'estimated_n0 = %s\n\n' % str(estimated_n_0)
                    ])
                )

    if verbose:
        print("Completed iteration of clone sizes")
        print("Fitted weights\t%s" % new_distribution.weights)
        print("Fitted means\t%s" % new_distribution.means)
        print("Final estimated_n0\t%i" % estimated_n_0)
        print("Log likelihood\t%f" % log_likelihood)
        print("Observed clones\t%f" % sum(observed_clone_size_distribution.values()))
        print("Observed clones + estimated clones\t%f" % (sum(observed_clone_size_distribution.values()) + estimated_n_0))
        print("=== END FIT ===\n")

    return new_distribution.weights + new_distribution.means, log_likelihood, estimated_n_0


def reconstruct_overall_distribution(file_in, file_out, total_clones=None, weights = 0., means = 0. ):
    """
    Given an observed sample distribution, returns:
    weights        : a list of weights for the spikes that best describe overall distribution
    means          : a list of means for the spikes that best describe the overall distribution
    n0             : the integer number of missing species
    log-likelihood : the float log-likelihood of this overall distribution, given the observed sample
    time elapsed   : in seconds
    """

    # for calculating time elapsed
    time_0 = time()

    # Read in and format data
    observed_clone_size_distribution = read_observed_clone_size_distribution_v2(file_in, clone_distribution_in_file, threshold) # NB clones larger than threshold never enter fit
    observed_clone_size_distribution = dict((key, value) for key, value in observed_clone_size_distribution.items() if value != 0) # remove zeroes
    
    # set effective_number_of_data_points for AICc
    no_observed_clone_sizes = len(list(observed_clone_size_distribution.keys()))
    effective_number_of_data_points = min(aicc_multiple*no_observed_clone_sizes, threshold)

    # initialize final parameters (will be returned)
    final_weights = []
    final_means = []
    final_n0 = None
    final_log_likelihood = 1.
    final_no_spikes = 0.

    # Initialise starting weights and means. For the first round of fitting this should replicate the scan for two spikes. Initial mean depends only on the observed data:
    initial_mean = sum(clone_size * no_clones for clone_size, no_clones in list(observed_clone_size_distribution.items())) / float(sum(observed_clone_size_distribution.values()))

    starting_weights = [1.]
    starting_means = [initial_mean] # the list of starting points for means
    number_of_parameters = 1

    total_observed_clones = float(sum(observed_clone_size_distribution.values())) # NB this is used as a global variable - be careful!
    new_distribution = mixed_distribution( list(zip(starting_weights, starting_means)) )
    
    # print(new_distribution.value_at_clone_size(12))
    total_estimated_clones = round(total_observed_clones/(1.-new_distribution.value_at_clone_size(0)))
    # print(total_estimated_clones)
    # initialize estimated_n0
    estimated_n_0 = total_estimated_clones - total_observed_clones
    print(total_estimated_clones, total_observed_clones)
    estimated_clone_size_distribution = defaultdict(int)
    estimated_clone_size_distribution[0] = estimated_n_0


    for key in observed_clone_size_distribution:
        estimated_clone_size_distribution[key] = observed_clone_size_distribution[key]
    log_likelihood = calc_log_likelihood_n0_as_parameter(estimated_clone_size_distribution, new_distribution, threshold, total_observed_clones)


    AIC = 2. * (number_of_parameters - log_likelihood)

    if no_observed_clone_sizes > 2:
        AICc = calculate_AICc( AIC, number_of_parameters, no_observed_clone_sizes )
        too_few_clone_sizes = False
    else:
        AICc = float('inf')
        too_few_clone_sizes = True

    AICc_old = float('inf')
    AIC_old = float('inf')

    with open(file_out,'w') as f:
        f.write("\n".join([
                    '# %s' % datetime.now().strftime('%c'),
                    # double check 
                    #'# python %s' % join(argv),
                    '# python %s' % ''.join(argv),
                    'observed_clone_size_distribution = %s' % dict(observed_clone_size_distribution),
                    'total_clones = %s' % total_clones,
                    'weights = 0.',
                    'means = 0.',
                    'initial_scale_factors = %s' % initial_scale_factors,
                    'test_weights_list = %s\n\n' % test_weights_list
                    ])
                )

    minimum_observed_clone_size = min(key for key in observed_clone_size_distribution if observed_clone_size_distribution[key] != 0)

    zero_in_fitted_weights = False

    # n0 is estimated above with the starting mean from data. Now we reinitialise starting weights
    starting_means = []
    starting_weights = []

    while (((AICc < AICc_old) or too_few_clone_sizes) and (number_of_parameters < parameter_limit) and (not zero_in_fitted_weights) and (1e-6 not in starting_means)):

        list_of_fits = [] # The list of fits will have one element for each scan starting point

        for initial_scale_factor in initial_scale_factors:

            # The next loop will add a new weight 
            if starting_weights == []:
                weights_to_loop_over = [1.]
            else:
                weights_to_loop_over = test_weights_list

            for test_weight in weights_to_loop_over:

                starting_means_temp = [ initial_scale_factor * initial_mean ] + starting_means
                starting_weights_temp = [test_weight] + [weight*(1. - test_weight) for weight in starting_weights]

                end_params, log_likelihood, estimated_n_0 = MLE_fit_v2(file_out, threshold, starting_weights_temp, starting_means_temp, observed_clone_size_distribution)

                # An element of list_oF_fits contains the following elements:
                # fit[0] : a list of starting_weights+starting_means
                # fit[1] : a list of fitted end weights+means
                # fit[2] : the log likelihood of the fit
                # fit[3] : estimated n0 for the fit
                list_of_fits.append((starting_weights_temp + starting_means_temp, end_params, log_likelihood, estimated_n_0))

        sorted_fits = sorted(list_of_fits, key = lambda my_list: my_list[2], reverse = True) # sort by log_likelihood
        number_of_spikes = len(sorted_fits[0][0])/2 # This is the length of starting_weights+starting_means in the best fit, divided by 2
        # sorted_means = [fit[0][number_of_spikes:] for fit in sorted_fits]
        sorted_means = [fit[0][int(number_of_spikes):] for fit in sorted_fits] # This takes the starting means for the best fit 
        min_means = [min(m) for m in sorted_means] # This takes the smallest amongst these starting means
        if min_means[0] <= initial_scale_factor * initial_mean: # This checks to see if the smallest starting mean was the mean that was added
            average_start_parameters = sorted_fits[0][0]
            # average_start_parameters[number_of_spikes] = min_means[0] / 2.
            average_start_parameters[int(number_of_spikes)] = min_means[0] / 2.
            # end_params, log_likelihood, estimated_n_0 = MLE_fit_v2(file_out, threshold, average_start_parameters[:len(average_start_parameters)/2], average_start_parameters[len(average_start_parameters)/2:], observed_clone_size_distribution)
            end_params, log_likelihood, estimated_n_0 = MLE_fit_v2(file_out, threshold, average_start_parameters[:int(len(average_start_parameters)/2)], average_start_parameters[int(len(average_start_parameters)/2):], observed_clone_size_distribution)
            list_of_fits.append((average_start_parameters, end_params, log_likelihood, estimated_n_0))
            if verbose: print('SMALLER SPIKE TRIGGERED')

        sorted_fits = sorted(list_of_fits, key = lambda my_list: my_list[2], reverse = True) # sort by log_likelihood

        average_start_parameters = [(p1+p2)/2. for p1,p2 in zip(sorted_fits[0][0], sorted_fits[1][0])] # average best and second best fits
        # end_params, log_likelihood, estimated_n_0 = MLE_fit_v2(file_out, threshold, average_start_parameters[:len(average_start_parameters)/2], average_start_parameters[len(average_start_parameters)/2:], observed_clone_size_distribution)
        end_params, log_likelihood, estimated_n_0 = MLE_fit_v2(file_out, threshold, average_start_parameters[:int(len(average_start_parameters)/2)], average_start_parameters[int(len(average_start_parameters)/2):], observed_clone_size_distribution)
        list_of_fits.append((average_start_parameters, end_params, log_likelihood, estimated_n_0))

        noise_test_ratio = 0.
        # noise_test_ratio compares the expected contribution to the sample of the smallest fitted clones
        # to the noise in the sample from remaining clones
        while noise_test_ratio <= 3.:
            max_log_likelihood = max(fit[2] for fit in list_of_fits)
            log_likelihoods = [element[2] for element in list_of_fits]
            max_index = log_likelihoods.index(max(log_likelihoods))

            fitted_parameters = list_of_fits[max_index][1]

            # Set up starting parameters for the next round of fitting:
            # starting_weights = fitted_parameters[:len(fitted_parameters)/2]
            # starting_means = fitted_parameters[len(fitted_parameters)/2:]
            starting_weights = fitted_parameters[:int(len(fitted_parameters)/2)]
            starting_means = fitted_parameters[int(len(fitted_parameters)/2):]
            sorted_params = sorted(zip(starting_weights, starting_means), key = lambda x: x[1])
            sorted_weights, sorted_means = [[x[i] for x in sorted_params] for i in [0,1]]
            if (0. in sorted_weights) and (len(sorted_weights) == 2): break
            if len(sorted_weights) > 1: # This applies on the second and subsequent interations, when there is more than one spike
                noise_test_ratio = sorted_weights[0]*poisson_pmf(sorted_means[0], minimum_observed_clone_size) / sqrt(sum( [weight * poisson_pmf(mean, minimum_observed_clone_size) for weight, mean in zip(sorted_weights[1:], sorted_means[1:]) ] ) / (total_observed_clones + estimated_n0) )
            else:
                noise_test_ratio = 4. # This applies on the first iteration, when there is only a single spike
            if noise_test_ratio <= noise_test_ratio_threshold:
                del list_of_fits[max_index]
                if len(list_of_fits) == 0:
                    max_log_likelihood = -float('inf')
                    break

        if 0. in fitted_parameters:
            zero_in_fitted_weights = True # flag to stop further iterations
            filtered_weights = [w for w in sorted_weights if w != 0.] # Remove zero from parameters
            filtered_means = [sorted_means[i] for i in range(len(sorted_weights)) if sorted_weights[i] != 0.]
            fitted_parameters = filtered_weights + filtered_means

        AIC_old = AIC
        AICc_old = AICc

        number_of_parameters = len(fitted_parameters) - 1
        AIC = 2.*(number_of_parameters - max_log_likelihood)

        if ((effective_number_of_data_points - number_of_parameters - 1.) > 0.):
            AICc = calculate_AICc(AIC, number_of_parameters, effective_number_of_data_points)
        else:
            AICc = float('inf')

        if 0. in fitted_parameters:
            AICc = float('inf')
            AIC = float('inf')

        if (AICc < AICc_old) or too_few_clone_sizes:
            with open(file_out, 'a') as f: # if you change this to 'w' the following is the only thing that gets output
                f.write('\n===========================================\n')
                if number_of_parameters >= parameter_limit:
                    f.write('parameter_limit = %s # REACHED MAX NUMBER OF PARAMETERS\n' % str(parameter_limit))
                initial_parameters, fitted_parameters, log_likelihood, estimated_n0 = list_of_fits[max_index]
                f.write("\n".join([
                            'initial parameters = %s' % initial_parameters,
                            'fitted parameters = %s' % fitted_parameters,
                            'estimated n0 = %s' % estimated_n0,
                            'AIC = %s' % AIC,
                            'AICc = %s' % AICc,
                            'log likelihood = %s' % log_likelihood,
                            '===========================================\n\n'
                            ])
                        )
            too_few_clone_sizes = False
            final_no_parameters = len(fitted_parameters)/2
            # final_weights = fitted_parameters[:final_no_parameters]
            # final_means = fitted_parameters[final_no_parameters:]
            final_weights = fitted_parameters[:int(final_no_parameters)]
            final_means = fitted_parameters[int(final_no_parameters):]
            final_n0 = estimated_n0
            final_log_likelihood = log_likelihood
    # Carla: added if statement
    if final_n0 == None: final_n0=0
    time_elapsed = time()-time_0
    # return final_weights, final_means, final_n0, observed_clone_size_distribution, total_clones, final_log_likelihood, time_elapsed
    return final_weights, final_means, int(final_n0), observed_clone_size_distribution, total_clones, final_log_likelihood, time_elapsed
# CARLA: CHANGE BACK?

# %% [markdown]
# ## 1.2 Functions for error-bar fits

# %%
# 1.2 functions for error-bar fits ==========================================


def read_sample_fit(MLE_filename, return_threshold = False):

    with open(MLE_filename, 'rU') as MLE_file:
        try:
            in_best_fit = False
            in_start_params = True
            for line in MLE_file:
                # read parameters from the start of the file...
                if line == '\n':
                    in_start_params = False
                    continue
                # below was originally written for python 2
                # try: left_side, right_side = list(map(strip, split(line, "=", 1)))
                try: left_side, right_side = list(map(strip, line.split("=", 1)))
                except: continue
                if in_start_params:
                    if not line.startswith('#'):
                        # below was originally written for python 2 
                        # line = split(line, '#')[0] 
                        line = line.split('#')[0] ## Is this necessary?
                        if left_side == "parent_population_size": 
                            parent_population_size = literal_eval(right_side)
                        elif left_side == "total_clones":
                            total_clones = literal_eval(right_side)
                        elif left_side == "sample_size": 
                            sample_size = literal_eval(right_side)
                        elif left_side == "weights": 
                            weights = literal_eval(right_side)
                        elif left_side == "means": 
                            means = literal_eval(right_side)
                        elif left_side == "observed_clone_size_distribution": 
                            observed_clone_size_distribution = literal_eval(right_side)
                        elif left_side == "total_observed_clones":
                            total_observed_clones = literal_eval(right_side)
                        elif left_side == "initial_scale_factors":
                            initial_scale_factors = literal_eval(right_side)
                        elif left_side == "test_weights":
                            test_weights = literal_eval(right_side)
                elif line.startswith('='):
                    in_best_fit = not in_best_fit
                # ...and the best-fit parameters from later in the file
                elif in_best_fit:
                    if left_side == "initial parameters":
                        initial_parameters_try = literal_eval(right_side)
                    elif left_side == "fitted parameters":
                        fitted_params_try = literal_eval(right_side)
                    elif left_side == "estimated n0":
                        estimated_n0_try = literal_eval(right_side)
                        if not 1e-6 in fitted_params_try:
                            initial_parameters = initial_parameters_try
                            fitted_params = fitted_params_try
                            estimated_n0 = estimated_n0_try

            observed_threshold = max(observed_clone_size_distribution.keys())

            # set some defaults if they were not read in file
            if 'observed_clone_size_distribution' not in locals():
                if verbose: print('warning: %s does not contain an observed_clone_size_distribution. Skipping...' % MLE_filename)
                return "Bad fit", None, None
            if 'sample_size' not in locals():
                sample_size = sum([key*observed_clone_size_distribution[key] for key in observed_clone_size_distribution])
            if 'total_observed_clones' not in locals():
                total_observed_clones = sum(observed_clone_size_distribution.values())
            if 'parent_population_size' not in locals():
                parent_population_size = 1e9

            # get start weight and calculate start mean
            start_weight = initial_parameters[0]
            initial_mean_norm = float(sum([observed_clone_size_distribution[i] for i in list(observed_clone_size_distribution.keys()) if i <= observed_threshold]))
            initial_mean = sum([i*observed_clone_size_distribution[i] for i in observed_clone_size_distribution if i <= observed_threshold]) / initial_mean_norm
            start_mean = initial_parameters[len(initial_parameters)/2] / initial_mean
            start_mean = int(10*start_mean)/10.

            # return sample_from_parent objects
            number_of_spikes = len(fitted_params)/2
            fit_weights = fitted_params[:number_of_spikes]
            fit_means = fitted_params[number_of_spikes:]
            if return_threshold:
                return observed_threshold, sample_from_parent(weights, means, sample_size, total_clones, parent_population_size, total_observed_clones, estimated_n0, fit_weights, fit_means), start_weight, start_mean, observed_clone_size_distribution
            else:
                return sample_from_parent(weights, means, sample_size, total_clones, parent_population_size, total_observed_clones, estimated_n0, fit_weights, fit_means), start_weight, start_mean, observed_clone_size_distribution

        except ValueError as e:
            if verbose: 
                if very_verbose: 
                    print(e)
                    print(print_exc(file=stdout))
                print('%s: warning: Nan in fit' % MLE_filename)
            return 'Nan in fit', 0, 0, None


def sample_from_model(weights, means, sample_size, total_clones, return_unobserved_clones = False):
    """
    Returns the distribution of a given sample_size most likely to be
    observed, given weights, means, sample_size, and total_clones.
    Compare to output_resample, which I think does exactly the same
    thing, just with a different input.
    Note total_clones is the total number of clones in the *parent*;
    sample_size is the desired sample size of the output.
    """
    sample_size = int(sample_size) # in units of cells
    total_clones = int(total_clones) # Robust to user input as float

    # scale means to sample_size
    scaling_factor = sample_size / (total_clones * sum(w*m for w, m in zip(weights, means)))
    means = [m*scaling_factor for m in means]

    sample_distribution = mixed_distribution( list(zip(weights, means)) )
    observed_clone_size_distribution = {}
    clone_size = 1
    total_observed_clones = 0
    unobserved_clones = total_clones * sample_distribution.value_at_clone_size(0)
    clone_limit = total_clones - unobserved_clones - 1 # When we observe this many clones we can stop looking

    while ( total_observed_clones < clone_limit ):
        new_clones = total_clones * sample_distribution.value_at_clone_size(clone_size)
        observed_clone_size_distribution[clone_size] = int(round(new_clones))
        total_observed_clones += new_clones
        clone_size += 1

    if return_unobserved_clones: return observed_clone_size_distribution, unobserved_clones
    else: return observed_clone_size_distribution


def qD_from_parameters(weights, means, total_estimated_clones, q):
    """
    Used by qD_from_parameters_and_observed_distribution.
    Should add in an estimate from the true distribution for values
    above the upper limit.
    This is slightly awkward, because I am generating the results
    directly from the parameters.
    I need to calculate the observed clone size distribution, work out
    out which clones are larger than the observed cut off and then add
    these to the reconstructed parent distribution.
    """
    zipped_weights_and_means = list(zip(weights, means))
    mean_norm = 1.0 / ( sum(weight*mean for weight,mean in zipped_weights_and_means) * total_estimated_clones )
    # This is one way to think of it; another is as 1. / the total
    # number of cells, in arbitrary units (e.g., units of some
    # fraction of a cell)

    if q == 0.0:
        return total_estimated_clones

    elif q == 1.0:
        qD = -sum(weight * (mean * mean_norm) * log(mean * mean_norm) for weight, mean in zipped_weights_and_means)
        qD = exp(qD * total_estimated_clones)

    elif q == float('inf'):
        qD = 1.0 / max( (mean * mean_norm) for mean in means )

    else:
        qD = sum(weight * (mean * mean_norm)**q for weight, mean in zipped_weights_and_means)
        qD = qD * total_estimated_clones
        qD = qD ** (1.0/(1.0 - q))

    return qD


def qD_from_parameters_and_observed_distribution(weights, means, observed_clone_size_distribution, observed_threshold, q):
    """
    Returns qD. Total_estimated_clones to be passed to this function
    should NOT be the sum of observed clones + estimated_0. It should
    be the sum of all clones arising from the fit parameters. This
    version incorporates various speed ups over version 3.
    """
    max_clone_size = max(observed_clone_size_distribution.keys())
    fitted_distribution = mixed_distribution( list(zip(weights,means)) )

    obs_small_clones = sum( observed_clone_size_distribution[x] for x in range(1, observed_threshold) if x in observed_clone_size_distribution )
    distribution_norm = obs_small_clones / sum( fitted_distribution.value_at_clone_size(x) for x in range(1, observed_threshold) )

    total_estimated_clones_obs = distribution_norm # includes estimated_n0
    for x in range(1,observed_threshold):
        if x not in observed_clone_size_distribution:
            observed_clone_size_distribution[x] = 0

    fit_large_clones = {}
    unfitted_clones = {}
    # NB in the sum below, only take keys that are already in
    # observed_clone_size_distribution. Otherwise, as a defaultdict it
    # will create zero entries.
    for clone_size in range(observed_threshold, max(observed_clone_size_distribution.keys())+1):
        if clone_size in list(observed_clone_size_distribution.keys()):
            if clone_size > max_clone_size_for_which_factorials_can_be_converted_to_float: fit_large_clones[clone_size] = 0. # factorials get very big, very fast. No point in trying to calculate beyond a certain point (that is presumably far lower than the max here)
            else: fit_large_clones[clone_size] = distribution_norm * fitted_distribution.value_at_clone_size(clone_size)
            diff = observed_clone_size_distribution[clone_size] - fit_large_clones[clone_size]
            if diff > 0.:
                unfitted_clones[clone_size] = diff

    aug_total_estimated_clones = float( total_estimated_clones_obs + sum(unfitted_clones.values()) )
    scale_weights = (total_estimated_clones_obs / aug_total_estimated_clones)
    weights = [weight*scale_weights for weight in weights]
    aug_weights = weights + [(unfitted_clones[clone_size] / aug_total_estimated_clones) for clone_size in list(unfitted_clones.keys())]
    aug_means = means + [clone_size for clone_size in list(unfitted_clones.keys())]

    qD = qD_from_parameters(aug_weights, aug_means, aug_total_estimated_clones, q)

    if verbose: 
        print('Number of unfitted clones: %i' % len(unfitted_clones))
        print('aug_weights (should sum to 1.): %s' % sum(aug_weights))

    return qD


def make_error_bar_envelope(samples, q):
    """
    This function considers all examples of fits at constant true
    total clone and returns:
        
    error_envelope_x_vals
    error_envelope_y_vals
        
    The keys of error_envelope_x_vals and error_envelope_x_vals are
    the true qD of the samples which we are using in our error bar
    fits.
        
    For error_envelope_x_vals at a fixed true qD the values are an
    ordered list of sample sizes.
        
    For error_envelope_y_vals at a fixed true qD the values are
    max(abs(log(fitted_D / true_D))) at the sample size given by the
    corresponding error_envelope_x_vals entry. The max is taken over
    steepnesses (that is, distribution shape).
        
    abs_deviations
        
    a list of (sample_size, abs(log(fitted_D / true_D)) pairs.
    """
    error_envelope_x_vals = {}
    error_envelope_y_vals ={}
    abs_deviations = []

    for sample in samples:
        observed_clone_size_distribution = sample_from_model(
            sample.weights, sample.means, sample.sample_size, 
            sample.total_clones
            )
        if observed_clone_size_distribution == {}: # if empty, continue (adds no information)
            continue
        fitted_D = qD_from_parameters_and_observed_distribution(
            sample.fitted_weights, 
            sample.fitted_means, 
            observed_clone_size_distribution, 
            30, 
            q
            )
        true_D = qD_from_parameters(sample.weights, 
                                    sample.means, 
                                    sample.total_clones, 
                                    q
                                    )
        if fitted_D != 0. and true_D != 0.:
            abs_deviations.append(
                (sample.sample_size, abs( log(fitted_D / true_D) ), true_D)
                )

    abs_deviations = [d for d in abs_deviations if not isnan(d[1])]

    true_Ds = sorted(list(set([abs_dev[2] for abs_dev in abs_deviations])))

    for true_D in true_Ds:
        sorted_dev = [dev for dev in abs_deviations if dev[2] == true_D]
        sorted_dev = sorted(sorted_dev, key = lambda x: x[0])
        x_vals = []
        y_vals = []
        max_y_val = 0.
        for val in sorted_dev[::-1]:
            if val[1] > max_y_val:
                max_y_val = val[1]
                if x_vals != [] and val[0] == x_vals[-1]:
                    y_vals[-1] = val[1]
                else:
                    x_vals.append(val[0])
                    y_vals.append(val[1])

        x_vals = x_vals[::-1]
        y_vals = y_vals[::-1]

        # For purposes of interpolation, set the error at 0 sample size equal to the error at smallest available sample size
        if x_vals[0] != 0:
            x_vals = [0] + x_vals
            y_vals = [y_vals[0]] + y_vals

        error_envelope_x_vals[true_D] = x_vals
        error_envelope_y_vals[true_D] = y_vals

    return error_envelope_x_vals, error_envelope_y_vals, abs_deviations


def make_error_bar_file(error_bar_fits_directory, precomputed_error_bar_file, qs):

    time_0 = time()

    # Filehandling
    if isdir(error_bar_fits_directory):
        if not error_bar_fits_directory.endswith('/'):
            error_bar_fits_directory += '/'
    else:
        print("error: %s is not a directory. To make error-bar files, file_in must be a directory that contains the error bar fits. exiting..." % error_bar_fits_directory)
        exit()

    if isfile(precomputed_error_bar_file):
        print("error: precomputed error-bar file %s already exists. exiting..." % precomputed_error_bar_file)
        exit()
    MLE_filenames = listdir(error_bar_fits_directory) # This directory should contain the fits
    MLE_filenames = [i for i in MLE_filenames if i.endswith(".txt")]

    # Read in fitted data for error bars
    fitted_samples = {} # dict[filename] = sample_from_parent objects
    for MLE_filename in MLE_filenames:
        if verbose: print('processing %s' % MLE_filename)
        try:
            fitted_sample, start_weight, start_mean, observed_clone_size_distribution = read_sample_fit(error_bar_fits_directory + MLE_filename)
        except UnboundLocalError:
            if verbose: print('warning: invalid fit: %s skipping...' % MLE_filename)
            continue
        if fitted_sample not in ('Nan in fit', 'Bad fit'):
            fitted_samples[MLE_filename] = fitted_sample

    # actually make error bars and write to file
    z = [fitted_samples[MLE_filename] for MLE_filename in list(fitted_samples.keys())]
    # The keys of error_envelope_x_vals and error_envelope_x_vals are
    # the true 0D of the samples which we are using in our error bar
    # fits. For error_envelope_x_vals at a fixed true 0D the values
    # are an ordered list of sample sizes. For error_envelope_y_vals
    # at a fixed true 0D the values are max(abs(log(fitted_D /
    # true_D))) at the sample size given by the corresponding
    # error_envelope_x_vals entry. The max is taken over steepnesses
    # (that is, distribution shape).
    #
    # Note that error_bar_devs has a default value of q = 1.
    for q in qs:
        error_envelope_x_vals, error_envelope_y_vals, abs_deviations = make_error_bar_envelope(z, q)
        with open(precomputed_error_bar_file, 'a') as f:
            f.write("\n".join([
                        'error_envelope_x_vals_%s = %s' % (q, error_envelope_x_vals),
                        'error_envelope_y_vals_%s = %s' % (q, error_envelope_y_vals),
                        'abs_deviations_%s = %s\n' % (q, abs_deviations)
                        ])
                    )
        if verbose: print("%sD:\tdone (%s)" % (q, precomputed_error_bar_file))

    time_elapsed = time()-time_0
    return time_elapsed

# %% [markdown]
# ## 1.3 Functions for power tables

# %%
# 1.3 functions for power tables ======================================

def read_error_bar_file(error_bar_file, q=0):
    """
    error_bar_file should be a text file, as generated by make_error_bar_file
    containing values for error_envelope_x_vals and error_envelope_x_vals
    """
    with open(error_bar_file,'rU') as f:
        for line in f:
            if line.startswith("error_envelope_x_vals_%s" % q):
                # below was originally written for python 2
                # error_envelope_x_vals = literal_eval( strip(split(line, "=")[1]) )
                error_envelope_x_vals = literal_eval(  (line.split("=")).strip([1]))
            elif line.startswith("error_envelope_y_vals_%s" % q):
            	# below was originally written for python 2
            	# error_envelope_y_vals = literal_eval( strip(split(line, "=")[1]) )
                error_envelope_y_vals = literal_eval( (line.split("=")).strip([1]))

    return error_envelope_x_vals, error_envelope_y_vals


def eb(sample_size, true_total_clone, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, target):
    """
    This returns the log of high error with the given parameters.
    The actual error will be exp(eb_val) - true_total_clone
    exp is because error_envelope_y_vals made by compare_MLE_alpha_v7.py contains log(fitted/true) values.
    """
    available_total_clone_sizes = sorted(error_envelope_x_vals.keys())
    for i in range(len(available_total_clone_sizes)):
        if available_total_clone_sizes[i] >= true_total_clone: break

    denom = float(available_total_clone_sizes[i] - available_total_clone_sizes[i-1])
    weight_1 = (available_total_clone_sizes[i] - true_total_clone) / denom
    weight_0 = (true_total_clone - available_total_clone_sizes[i-1]) / denom

    interpolated_1 = interp(sample_size, error_envelope_x_vals[available_total_clone_sizes[i-1]], error_envelope_y_vals[available_total_clone_sizes[i-1]])
    interpolated_0 = interp(sample_size, error_envelope_x_vals[available_total_clone_sizes[i]], error_envelope_y_vals[available_total_clone_sizes[i]])

    eb_val = weight_1 * interpolated_1 + weight_0 * interpolated_0

    return number_of_error_bars*(exp(eb_val) - 1.) - target


def bisect_eb(eb, true_total_clone, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, target):
    """
    This finds a root of number_of_error_bars*(exp(eb) - 1.) - target = 0.
    by iterated bisection.
    """
    low = 0
    high = true_total_clone*10
    eb_low = eb(low, true_total_clone, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, target)
    if eb_low < 0.:
        available_total_clone_sizes = sorted(error_envelope_x_vals.keys())
        for i in range(len(available_total_clone_sizes)):
            if available_total_clone_sizes[i] >= true_total_clone:
                break
        return sorted(error_envelope_x_vals[available_total_clone_sizes[max(0,i-1)]])[1]

    eb_high = eb(high, true_total_clone, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, target)
    assert eb_low * eb_high <= 0.
    while high - low > 1:
        midpoint = (low + high) / 2.
        eb_midpoint = eb(midpoint, true_total_clone, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, target)
        if eb_low * eb_midpoint > 0.:
            low = midpoint
        else:
            high = midpoint
    return midpoint


def get_sample_size(number_of_clones, fold_difference, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars):
    """
    This returns the number of cells in a sample that produce the an
    error bar of max_error_bar for a given number_of_clones in the
    parent population.
    
    This is the inverse function of the calculation performed by
    error_bar_on_fit_qD
    
    Delta = (fold_difference - 1.0) * number_of_clones
    """
    target = fold_difference - 1.
    sample_size = bisect_eb(eb, number_of_clones, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, target)
    return sample_size


def get_sampling_limit(number_of_clones, min_number_of_doublets, fraction_small_clones):
    """
    This function returns the minimum number of cells required to
    reliably see doublets and triplets.
    
    The number of possible pairs of cells is sample_size**2/2
    
    Expected doublets = p * sample_size**2/2
    
    However, we need an effective sample size, given by the sample_size * fraction_of_small_clones
    where fraction_of_small_clones is the fraction of cells in small clones.    
        
    Expected doublets = p * (sample_size * fraction_of_small_clones)**2/2
        
    Where p is the probability that a pair of cells is are from the
    same clone, given that both cells are from small clones.
    
    Now estimate p = 1/number_of_small_clones, which is approximately
    1/number_of_clones.
    
    Expected doublets = (sample_size * fraction_of_small_clones)**2/ (2 * number_of_clones)
    We want to expect at least min_number_of_doublets.
        
    rearranging:
        
    sample_size = sqrt(2 * number_of_clones * min_number_of_doublets) / fraction_of_small_clones
    
    This is our sampling limit.
    """
    return int(round( sqrt(2.*min_number_of_doublets*number_of_clones) / fraction_small_clones ))


def get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones):
    minimum_cells = {}
    for fold_difference in list_of_fold_differences:
        for number_of_clones in list_of_number_of_clones:
            # Calculate the minimum number of cells required to reliably see a fold.
            fold_limit = get_sample_size(number_of_clones, fold_difference, error_envelope_x_vals, error_envelope_y_vals,  number_of_error_bars)
            # Calculate the minimum number of cells required to reliably see doublets and triplets
            sampling_limit = get_sampling_limit(number_of_clones, min_number_of_doublets, fraction_small_clones)
            # Take the more stringent result
            minimum_cells[number_of_clones, fold_difference] = int(round(max(fold_limit, sampling_limit)))

    return minimum_cells


def output_table(list_of_number_of_clones, list_of_fold_differences, error_bar_file, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_output = None):

    lines = []

    # Record variables used
    lines.append('# %s' % datetime.now().strftime('%c'))
    lines.append('# python %s' % ' '.join(argv))
    lines.append('error_bar_file = %s' % error_bar_file)
    lines.append('number_of_error_bars = %s' % number_of_error_bars)
    lines.append('min_number_of_doublets = %s' % min_number_of_doublets)
    lines.append('fraction_small_clones = %s' % fraction_small_clones)
    lines.append('q = %s\n' % q)

    # make header line
    line = "\t" + "\t".join([str(int(number_of_clones)) for number_of_clones in list_of_number_of_clones])
    lines.append(line)

    # iterate over lines
    for fold_difference in list_of_fold_differences:

        # iterate over cols within line
        line = str(fold_difference) + "\t" 
        line += "\t".join([str(minimum_cells[number_of_clones, fold_difference]) for number_of_clones in list_of_number_of_clones])
        lines.append(line)
        
    # output lines
    lines = "\n".join(lines)+"\n"
    if file_output:
        if isfile(file_output):
            print("warning: power table file %s already exists. Printing to stdout and exiting..." % file_output)
            print(lines)
            exit()
        with open(file_output, "a") as f:
            f.write(lines)
    elif verbose: print(lines)
    return

# %% [markdown]
# ## 1.4 Functions for d-number tables

# %%
# 1.4 functions for D-number tables ======================================

def qD_from_distribution(H, q):
    """
    Returns the qD given a distribution in the form of a dictionary H = { clone_size : clone number }
    """
    # H is a dictionary-like object
    N = float(sum( k*v for k, v in list(H.items()) )) # normalization factor
    H = dict( (k/N, v) for k, v in list(H.items()) ) # normalize key entries by N, making them probabilities
    if q == float("inf"): return 1./max(H.keys())
    elif q == 1.: return exp( -sum( v*k*log(k) for k, v in list(H.items()) if v != 0. ) )
    else: return sum( v*k**q for k, v in list(H.items()) )**(1./(1.-q))


def error_bar(sample_size, true_total_clone, error_envelope_x_vals_q, error_envelope_y_vals_q):
    """
    The function error_bar(sample_size, true_total_clone,
    error_envelope_x_vals, error_envelope_y_vals) returns the value of
    max(abs(fitted_D / true_D)) at the given sample size and given
    total_clones.  Since we only have values at a grid of true_D and a
    grid of sample size, this is calculated by interpolation. This
    will be an interpolation between
        
        error_bar(sample_size, true_total_clone1)
        
    and
        
        error_bar(sample_size, true_total_clone2)
        
    and then between sample sizes.
    """
    available_total_clone_sizes = sorted(error_envelope_x_vals_q.keys())
    if true_total_clone > available_total_clone_sizes[-1] or (true_total_clone < available_total_clone_sizes[0]):
        if verbose: print('Clone size out of range')
        return None
    for i in range(len(available_total_clone_sizes)):
        if available_total_clone_sizes[i] >= true_total_clone:
            break
                                                              
    weight_0 = (available_total_clone_sizes[i] - true_total_clone) / float(available_total_clone_sizes[i] - available_total_clone_sizes[i-1])
    weight_1 = (true_total_clone - available_total_clone_sizes[i-1]) / float(available_total_clone_sizes[i] - available_total_clone_sizes[i-1])

    interp_0 = interp(sample_size, error_envelope_x_vals_q[available_total_clone_sizes[i-1]], error_envelope_y_vals_q[available_total_clone_sizes[i-1]])
    interp_1 = interp(sample_size, error_envelope_x_vals_q[available_total_clone_sizes[i]], error_envelope_y_vals_q[available_total_clone_sizes[i]])
                                                              
    return weight_0*interp_0 + weight_1*interp_1


def abs_error(total_clones, sample_size, error_envelope_x_vals_q, error_envelope_y_vals_q,high_low_sign):
    """
    high_low_sign = +1 will return the upper limit on the number of
    reconstructed clones for 0D = total clones and given sample size.
    Dependence on q (as which D numbers, qD) is embodied in
    error_envelope_x_vals and error_envelope_y_vals. These must be
    calculated for each q, and the appropriate dictionary passed to
    the abs_error function.
    """
    error_bar_result = error_bar(sample_size, total_clones, error_envelope_x_vals_q, error_envelope_y_vals_q)
    if error_bar_result == None: # clone size out of range
        return None
    else: 
        return total_clones * exp(high_low_sign * error_bar_result ) # NB total_observed_clones is the sample size


def error_bar_on_fit_qD(sample_size, reconstructed_qD, error_envelope_x_vals_q, error_envelope_y_vals_q):

    step_size = (reconstructed_qD / 1000.0)

    # calculate lower limit
    n = 1; abs_error_result = float("inf") # initialization
    while abs_error_result >= reconstructed_qD:
        abs_error_result = abs_error((reconstructed_qD - n*step_size), sample_size, error_envelope_x_vals_q, error_envelope_y_vals_q, +1)
        if abs_error_result == None:
            lower_limit = 0.
            break
        n += 1
        lower_limit = reconstructed_qD - (n+1)*step_size

    # calculate upper limit
    n = 1; abs_error_result = 0. # initialization
    while abs_error_result <= reconstructed_qD:
        abs_error_result = abs_error((reconstructed_qD + n*step_size), sample_size, error_envelope_x_vals_q, error_envelope_y_vals_q, -1)
        if abs_error_result == None:
            upper_limit = float("inf")
            break
        n += 1
        upper_limit = reconstructed_qD + (n+1)*step_size

    return lower_limit, upper_limit


def output_table_of_D_numbers(precomputed_error_bar_file, D_number_output_file, infiles, qs = [0., 1., 2., float("inf")], write_to_disk = True ):
    """
    Returns a dictionary of dictionaries: file_q_qD_hash[file] = dict[q] : (obs_qD, recon_qD, recon_lower_limit, recon_qD_upper_limit)
    #
    If no precomputed_error_bar_file is given, then proceeds without error bars
    """
    # read in error-bar envelope variables
    if precomputed_error_bar_file:
        error_envelope_xs = {}
        error_envelope_ys = {}
        # with open(precomputed_error_bar_file,'rU') as f:
        with open(precomputed_error_bar_file) as f:
            for line in f:
            	# below was originally written for python 2
                # left_side, right_side = list(map(strip, split(line, "=")))
                # left_side, right_side = list(map(strip, line.split("=")))
                left_side, right_side = list(map(str.strip, line.split("=")))
                name, q = left_side.rsplit("_",1)
                q = float(q)
                if name == "error_envelope_x_vals":
                    error_envelope_xs[q] = literal_eval(right_side)
                elif name == "error_envelope_y_vals":
                    error_envelope_ys[q] = literal_eval(right_side)

    # initialize
    estimated_n0 = {}  # estimated_n0[infile] = estimated n0 for that file
    fitted_params = {} # fitted_params[infile] = final fitted params for that file
    observed_clone_size_distributions = {} # observed_clone_size_distributions[infile] = observed_clone_size_distribution for that file
    obs_qDs = defaultdict(dict) # obs_qDs[filename] = obs_qD{q: qD}
    observed_threshold = 30 # not recorded in files but needed
    
    # Read in observed_clone_size_distributions, fitted_parameters,
    # and n0s from MLE files (note similarity to read_sample_fit)
    for infile in infiles:
        obs_qD = {}
        # with open(infile,'rU') as MLE_file:
        with open(infile) as MLE_file:
            in_best_fit = False
            in_start_params = True
            for line in MLE_file:
                if line == "\n": 
                    in_start_params = False
                    continue
                # below was originally written for python 2    
                # try: left_side, right_side = list(map(strip, split(line, "=", 1)))
                # try: left_side, right_side = list(map(strip, line.split("=", 1)))
                try: left_side, right_side = list(map(str.strip, line.split("=", 1)))
                except: continue
                if in_start_params:
                    # read in observed_clone_size_distribution and threshold (if present) from the start of the file...
                    if left_side == "observed_clone_size_distribution": # This requires full clone distribution in fit file, including clones that are not explicitly fitted.
                        observed_clone_size_distribution = literal_eval(right_side)
                        observed_clone_size_distributions[infile] = observed_clone_size_distribution
                    elif left_side == "threshold":
                        threshold_in_file = literal_eval(right_side)
                        if not observed_threshold:
                            observed_threshold = threshold_in_file
                        elif observed_threshold != threshold_in_file:
                            print('error: all fit files in one table must use the same fitting threshold. Exiting...')
                            exit()
                elif line.startswith('='):
                    in_best_fit = not in_best_fit
                # ...and the best-fit parameters from later in the file
                elif in_best_fit:
                    if left_side == "fitted parameters":
                        fitted_params_try = literal_eval(right_side)
                    elif left_side == "estimated n0":
                        estimated_n0_try = literal_eval(right_side)
                        if not 1e-6 in fitted_params_try:
                            fitted_params[infile] = fitted_params_try
                            estimated_n0[infile] = estimated_n0_try

        # calculate observed qDs
        for q in qs: 
            obs_qD[q] = qD_from_distribution(observed_clone_size_distribution, q)
        obs_qDs[infile] = obs_qD
        #"""


    # write D-number table
    file_q_qD_hash = defaultdict(lambda : defaultdict(tuple) ) # file_q_qD_hash[file] = dict[q] : (obs_qD, recon_qD, recon_qD-, recon_qD+); for return

    # header line
    header_line = "sample_name\t" + "\t".join(["obs_%sD\test_%sD\test_%sD-\test_%sD+" % (q, q, q, q) for q in qs]) + "\n"
    if write_to_disk:
        with open(D_number_output_file, "w") as f:
            f.write("\n".join([
                        # double check
                        # "# python %s" % join(argv),
                        "# python %s" % ''.join(argv),
                        "# infiles = %s" % infiles,
                        "# observed_threshold = %s" % observed_threshold,
                        "# precomputed_error_bar_file = %s" % precomputed_error_bar_file,
                        header_line
                        ]))

    for infile in infiles:

        print(infile)
        # get sample_size (needed for error bars)
        if infile not in list(fitted_params.keys()): 
            print("Error: bad fit: either Recon failed to produce a good fit (check for a very small number in the fitted parameters), or else the input file was not a Recon output-format file. Skipping...")
            continue
        # weights = fitted_params[infile][:len(fitted_params[infile])/2]
        # means = fitted_params[infile][len(fitted_params[infile])/2:]

        weights = fitted_params[infile][:int(len(fitted_params[infile])/2)]
        means = fitted_params[infile][int(len(fitted_params[infile])/2):]
        observed_clone_size_distribution = observed_clone_size_distributions[infile]
        sample_size = sum(key*observed_clone_size_distribution[key] for key in observed_clone_size_distribution if key < observed_threshold)
        
        # get qD_obs, qD, qD-, qD+ for each q
        outline = [infile]
        for q in qs:
            q = float(q)
            obs_qD = obs_qDs[infile][q]
            recon_qD = qD_from_parameters_and_observed_distribution(weights, means, observed_clone_size_distribution, observed_threshold, q)
            try:
                lower_limit, upper_limit = error_bar_on_fit_qD(sample_size, recon_qD, error_envelope_xs[q], error_envelope_ys[q])
                lower_limit = max(lower_limit, obs_qD) # lower_limit can't be lower than the obs_qD
                upper_limit = 1.0164*upper_limit # (very minor) adjustment based on validation, to achieve 95% confidence internvals
            except: 
                lower_limit = ""
                upper_limit = ""
            outline += [obs_qD, recon_qD, lower_limit, upper_limit]
            file_q_qD_hash[infile][q] = (obs_qD, recon_qD, lower_limit, upper_limit)
                
        outline = list(map(str, outline))
        outline = "\t".join(outline)
        
        # write output to file (one write per infile)
        if write_to_disk:
            with open(D_number_output_file, 'a') as f:
                f.write(outline+"\n")

        if verbose: 
            print("infile:\t%s" % infile)
            print("weights:\t%s" % weights)
            print("means:\t%s" % means)
            print("observed_clone_size_distribution:\t%s" % observed_clone_size_distribution)
            print("sample_size:\t%s" % sample_size)
            print()
        
    return file_q_qD_hash


# 1.4 functions for resmapling ======================

def output_resample(fitfile, outfile, write_to_file = True):
    """
    Given a file that contains a fit (with fitted parameters, etc.),
    which recall describes a reconstructed overall population, this
    function outputs a sample of sample size sample_size that can be
    compared to the initial sample from which the reconstructed
    overall population was made. Also writes this to outfile.
    Note the resample is the same size as the original. This, and that
    it operates directly on a file as opposed to weights and means,
    distinguishes this function from sample_from_model().
    """
    largest_observed_clone, model, start_weight, start_mean, observed_clone_size_distribution = read_sample_fit(fitfile, return_threshold = True)  # see 1.2 above

    observed_clone_size_distribution = defaultdict(int, observed_clone_size_distribution)
    sample_distribution = mixed_distribution(list(zip(model.fitted_weights, model.fitted_means)))
    total_clones = model.total_clones
    total_observed_clones = 0
    unobserved_clones = model.estimated_n0

    if total_clones == None: total_clones = unobserved_clones + model.total_observed_clones

    # When we see this many clones we can stop looking. Equivalent to
    # total_clones - actual_n0. This makes more sense than
    # total_clones - estimated_n0, because that fixes the n0,
    # restricting room for the observed; whereas the uncertainty is in
    # the n0, so we should not restrict room for the observed in this
    # way.
    clone_limit = sum(observed_clone_size_distribution.values()) 

    resampled_clone_size_distribution = {}
    clone_size = 1
    while total_observed_clones < total_clones and clone_size <= largest_observed_clone:
        if clone_size > max_clone_size_for_which_factorials_can_be_converted_to_float: no_clones_at_this_size = 0
        else: no_clones_at_this_size = sample_distribution.value_at_clone_size(clone_size)
        new_clones = total_clones * no_clones_at_this_size
        if clone_size <= threshold: # add back large clones (since they were not fit anyway, and their frequency is well sampled)
            resampled_clone_size_distribution[clone_size] = int(round(new_clones))
        else: resampled_clone_size_distribution[clone_size] = observed_clone_size_distribution[clone_size]
        total_observed_clones += new_clones
        clone_size += 1


    header = "#clone_size\tno_clones"
    outlines = [header]
    resampled_clone_sizes = list(resampled_clone_size_distribution.keys())
    outlines += ["%i\t%i" % (i, resampled_clone_size_distribution[i]) for i in range(1, largest_observed_clone+1) if i in resampled_clone_sizes and resampled_clone_size_distribution[i] != 0]
    if write_to_file:
        with open(outfile, "w") as f: # write to disk
            f.write("\n".join(outlines) + "\n")
    return resampled_clone_size_distribution, observed_clone_size_distribution

# %% [markdown]
# ## 1.4 Functions for plotting resample

# %%
#  1.5 functions for plotting resample ======================================


def write_html_file(html_file):
    """
    Writes the bare-bones html that calls the javascript that creates the plots in d3.js.
    """
    with open(html_file, "w") as f:
        f.write("""
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="utf-8">
    <title>plot_clone_size_distribution</title>
    <link href='http://fonts.googleapis.com/css?family=Roboto' rel='stylesheet' type='text/css'>
    <link href="%s/style.css" rel="stylesheet" type="text/css" />
    <script type="text/javascript" src="%s/d3.js"></script>
  </head>
  <body>
    <script type="text/javascript" src="%s/plot_clone_size_distribution.js">
    </script>
  </body>
</html>
""" % (resource_path, resource_path, resource_path) )
        return


def customize_js(javascript_file, plotfile, x_max="false", y_max="false"):
    txt = open(javascript_file, "r").read()
    txt = txt.replace("X_MAX", str(x_max))
    txt = txt.replace("Y_MAX", y_max)
    txt = txt.replace("SUPPRESS_OBS_ZERO", "false")
    txt = txt.replace('var filename = "test.txt";', 'var filename = "%s";' % plotfile)
    javascript_outfile = javascript_file.replace("_ref", "")
    f = open(javascript_outfile, "w")
    f.write(txt)
    f.close()
    return


def round_up_to_the_nearest(x, unit=10):
    return int(unit * ceil(float(x)/unit))

def plot_resample(fitfile, plotfile, precomputed_error_bar_file, x_max = x_max, y_max = y_max, javascript_file = resource_path + "/" + javascript_file, q=0.):
# def plot_resample(fitfile, plotfile, precomputed_error_bar_file, x_max, y_max, javascript_file = resource_path + "/" + javascript_file, q=0.):
    """
    Note need javascript file plot_clone_size_distribution_ref.js as well as style.css and d3.js in current working directory.
    """
    # make sure plotfile includes full path (so the javascript file knows where to look for it)
    full_path = getcwd()
    # below two lines were originally written for python 2 
    # if not isabs(rsplit(javascript_file, "/", 1)[0]): javascript_file = full_path + "/" + javascript_file
    # if not isabs(rsplit(plotfile, "/", 1)[0]): plotfile = full_path + "/" + plotfile
    if not isabs(javascript_file.rsplit("/", 1)[0]): javascript_file = full_path + "/" + javascript_file
    if not isabs(plotfile.rsplit("/", 1)[0]): plotfile = full_path + "/" + plotfile
    # get datapoints for observed and resampled
    resampled_clone_size_distribution, observed_clone_size_distribution = output_resample(fitfile, None, False)
    # get estimated_n0
    fitted_sample, x, x, x = read_sample_fit(fitfile)
    estimated_n0 = fitted_sample.estimated_n0
    # get error bars on estimated_n0
    file_q_qD_hash = output_table_of_D_numbers(precomputed_error_bar_file, None, [fitfile], [q], False)
    obs_qD, recon_qD, recon_qD_lower_limit, recon_qD_upper_limit = file_q_qD_hash[fitfile][q]
    # apply error bars to estimated_n0
    lower_n0_error_bar = estimated_n0 - (recon_qD - recon_qD_lower_limit)
    lower_n0_error_bar = max(0.7, lower_n0_error_bar) # actually zero; did this to make it appear on the plot
    upper_n0_error_bar = estimated_n0 + (recon_qD_upper_limit - recon_qD)
    # get actual n0
    total_clones = fitted_sample.total_clones
    if total_clones:
        actual_n0 = total_clones - sum(observed_clone_size_distribution.values())
    else: actual_n0 = 0. # suppresses display (since y-axis is in log units)
    actual_n0 = max(actual_n0, 0.) # avoid negatives, which get plotted high
    # get clone sizes
    observed_clone_size_distribution = defaultdict(int, observed_clone_size_distribution) # so looking for a clone size that isn't there returns zero instead of an error
    resampled_clone_size_distribution = defaultdict(int, resampled_clone_size_distribution) # ditto
    clone_sizes = list(resampled_clone_size_distribution.keys()) + list(observed_clone_size_distribution.keys())
    clone_sizes = list(set(clone_sizes)) # uniques the clone_sizes
    clone_sizes = [i for i in clone_sizes if resampled_clone_size_distribution[i] != 0 or observed_clone_size_distribution[i] != 0]
    clone_sizes.sort()

    # make plotfile
    with open(plotfile, "w") as f:
        # write header
        header = "\t".join(["clone_size", "sample", "fit", "lower_limit", "upper_limit"])
        f.write(header+"\n")
        # write clone-size zero
        outline = [0, actual_n0, estimated_n0, lower_n0_error_bar, upper_n0_error_bar]
        outline = list(map(str, outline))
        outline = "\t".join(outline)
        f.write(outline+"\n")
        if verbose: 
            print(header)
            print(outline)
        # write other clone sizes
        for clone_size in clone_sizes:
            if clone_size == 0: continue # we already took care of zero
            outline = [clone_size, observed_clone_size_distribution[clone_size], resampled_clone_size_distribution[clone_size]]
            outline = list(map(str, outline))
            outline = "\t".join(outline)
            f.write(outline+"\n")
            if verbose: print(outline)

    # set x and y limits
    if not x_max: 
        x_max = max( round_up_to_the_nearest(max(clone_sizes), 10), 40 )
    if not y_max: 
        y_max = max(list(observed_clone_size_distribution.values())+list(resampled_clone_size_distribution.values())+[recon_qD_upper_limit])
        if y_max == float('inf'): y_max = max(list(observed_clone_size_distribution.values())+list(resampled_clone_size_distribution.values()))
        y_max = log(y_max, 10)
        y_max = round_up_to_the_nearest(y_max, 1)
        y_max = 10**y_max

    # update javascript
    customize_js(javascript_file, plotfile, str(x_max), str(y_max))

    # the absolute path to the .js and .css must be given in the html DONE
    # the absolute path to the plotfile must be given in plot_clone_size_distribution.js

    # Use wkhtmltopdf to convert the html to PDF and cpdf to crop the PDFs
    pdf_file = fitfile.replace(".txt", ".pdf")    
    html_file = fitfile.replace(".txt", ".html")
    write_html_file(html_file)
    print("  writing %s..." % pdf_file)
    command = "wkhtmltopdf '%s' '%s'" % (html_file, pdf_file)
    # x = getoutput(command)
    x = subprocess.getoutput(command)

    """
    Crop the result for easier use in graphics-layout programs
    (e.g. OmniGraffle). Note the parameters below (x, y, width,
    height, with the origin at the bottom left), were chosen for
    dimension_base = 500 in
    plot_clone_size_distribution_ref.js. Smaller values of
    dimension_base will result in white borders with these parameters.
    """
    command = 'cpdf -crop "38mm 185mm 112mm 95mm" \'%s\' -o \'%s\'' % (pdf_file, pdf_file)
    system(command)

    return


def get_upper_bound(fit_file, D_number_file, N, sample_size):
	"""
	U_max = R * w_min * m_min * N/S
	U_max: upper bound that we seek to calculate
	R:     Recon's (*)upper bound of) the overall species richness estimate (from D_number_file)
	N:     overall population size (from user)
	S:     sample size (from user)
	m_min: smallest clone (from fit_file)
	w_min: weight of smallest clone (from fit_file)
	fit_file is a Recon fit file. We read 
	"""
	#
	# Make sure N and sample_size were passed
	if N == None:
		print("error in get_upper_bound(): Please supply a total population size using the -N option. Exiting...")
		exit()
	if sample_size == None:
		print("error in get_upper_bound(): Please supply a sample size using the -ss or --sample_size option. Exiting...")
		exit()
	#
	# get m_min and w_min
	if not isfile(fit_file):
		print("error in get_upper_bound(): Cannot find fit_file %s . Exiting..." % fit_file)
		exit()
	if not isfile(D_number_file):
		print("error in get_upper_bound(): Cannot find D_number_file %s . Exiting..." % D_number_file)
		exit()
	with open(fit_file) as f:
		txt = f.read()
		final_parameters = txt.split("===========================================")[-2]
		del(txt)
		final_parameters = final_parameters.split("\n")
		for line in final_parameters:
			# below was originally written for python 2
			# try: left_side, right_side = list(map(strip, split(line, "=", 1)))
			# try: left_side, right_side = list(map(strip, line.split("=", 1)))
			try: left_side, right_side = list(map(str.strip, line.split("=", 1)))
			except: continue
			if left_side == "fitted parameters":
				weights_and_means_list = literal_eval(right_side)
		number_of_parameters = len(weights_and_means_list)
		weights = weights_and_means_list[:number_of_parameters/2]
		means = weights_and_means_list[number_of_parameters/2:]
		m_min, w_min = sorted(zip(means, weights))[0] # sorts from smallest to largest m, with associated w
	#
	# get R
	with open(D_number_file) as f:
		for line in f:
			if line.startswith("#"): continue # in case our keyword happens to be in a filename
			if line.startswith("sample_name"):
				# below was originally written for python 2
				# header = split(strip(line))
				# header = (line.strip()).split()
				header = (line.str.strip()).split()
				continue
			if line.split("\t")[0] in fit_file:
				# below was originally written for python 2
				# vals = split(strip(line))
				# vals = (line.strip()).split() 
				vals = (line.str.strip()).split() 
				break
		lookup_hash = {i:j for i, j in zip(header, vals)}
		R = float(lookup_hash["est_0.0D+"])
	#
	# float N and S
	N = float(N)
	S = float(sample_size)
	#
	# calculate U_max
	U_max = R * w_min * m_min * N/S
	#
	return U_max

# %% [markdown]
# # Executables

# %% [markdown]
# ## Sonia/TCRdb

# %% [markdown]
# #### 1 - SONIA 1

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_1all.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# ##### 1.1 df1-5 standard

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population

elif make_error_bars:
    print("making error-bar file...")
    print(make_error_bar_file(file_in, file_out, qs))

elif make_table_of_D_numbers:
    print("making table of D numbers...")
    output_table_of_D_numbers(precomputed_error_bar_file, file_out, list_of_filenames, qs)

elif make_power_table:
    print("making power table...")
    error_envelope_x_vals, error_envelope_y_vals = read_error_bar_file(file_in, q)
    minimum_cells = get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones)
    output_table(list_of_number_of_clones, list_of_fold_differences, file_out, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_out)

elif resample:
    print("resampling...")
    output_resample(file_in, file_out)

elif make_resample_plot:
    print("plotting resample...")
    plot_resample(file_in, file_out, precomputed_error_bar_file)

elif upper_bound:
	print("calculating strict upper limit U...")
	print(get_upper_bound(fit_file, D_number_file, N, sample_size))


else:
    print("""error: no option given. Options:
-R  --run_recon
-e  --make_error_bars
-p  --make_power_table
-T  --make_table_of_D_numbers
-r  --resample
-x  --make_resample_plot
exiting...
""")
    exit()
# Out:
# running recon on df_fill_in_test.tsv...
# /usr/local/lib/python3.9/dist-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# ([0.05, 0.0475, 0.045125, 0.04286875, 0.040725312500000006, 0.43387002511694217, 0.20394654742983467, 0.08157861897193386, 0.0027192872990644632, 0.0516664586822248], [0.06342727504755778, 0.002973153517854271, 0.005946307035708542, 0.011892614071417083, 0.023785228142834167, 0.04757045628566833, 0.06342727504755778, 0.142711368857005, 1.3954000510462712, 0.5074182003804623], 51468404, {1: 3552422, 2: 223562, 3: 68451, 4: 31801, 5: 17608, 6: 10986, 7: 7533, 8: 5237, 9: 4003, 10: 3025, 11: 2467, 12: 1959, 13: 1521, 14: 1286, 15: 1097, 16: 891, 17: 757, 18: 693, 19: 584, 20: 538, 21: 414, 22: 379, 23: 346, 24: 303, 25: 273, 26: 259, 27: 218, 29: 200, 28: 195, 30: 177, 31: 164, 32: 148, 33: 116, 35: 113, 34: 109, 37: 97, 36: 96, 38: 79, 39: 77, 40: 75, 42: 68, 41: 66, 44: 64, 45: 51, 43: 49, 46: 48, 47: 39, 48: 39, 50: 38, 57: 35, 52: 34, 49: 33, 51: 30, 54: 29, 55: 29, 56: 29, 53: 27, 60: 26, 63: 22, 68: 22, 62: 19, 69: 18, 58: 17, 61: 17, 59: 16, 75: 16, 66: 16, 71: 15, 65: 14, 70: 13, 67: 12, 72: 11, 80: 10, 74: 9, 87: 9, 95: 9, 78: 9, 76: 8, 85: 8, 83: 8, 88: 8, 90: 8, 81: 8, 102: 7, 64: 7, 86: 7, 73: 7, 104: 6, 93: 6, 98: 6, 97: 6, 82: 6, 84: 6, 96: 6, 89: 6, 77: 6, 79: 5, 100: 5, 106: 5, 109: 5, 111: 4, 92: 4, 94: 4, 139: 4, 91: 4, 114: 4, 120: 3, 132: 3, 128: 3, 124: 3, 116: 3, 163: 3, 110: 3, 99: 3, 112: 2, 127: 2, 141: 2, 180: 2, 133: 2, 101: 2, 131: 2, 113: 2, 200: 2, 107: 2, 123: 2, 121: 2, 115: 2, 118: 2, 186: 1, 173: 1, 167: 1, 169: 1, 197: 1, 172: 1, 187: 1, 178: 1, 182: 1, 157: 1, 181: 1, 202: 1, 251: 1, 129: 1, 152: 1, 146: 1, 142: 1, 138: 1, 136: 1, 135: 1, 134: 1, 130: 1, 126: 1, 125: 1, 117: 1, 108: 1, 105: 1, 103: 1, 277: 1}, None, -2346864.2923210952, 4.985384941101074)

# %% [markdown]
# ##### 1.2 df1-5 verbose = true

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population

elif make_error_bars:
    print("making error-bar file...")
    print(make_error_bar_file(file_in, file_out, qs))

elif make_table_of_D_numbers:
    print("making table of D numbers...")
    output_table_of_D_numbers(precomputed_error_bar_file, file_out, list_of_filenames, qs)

elif make_power_table:
    print("making power table...")
    error_envelope_x_vals, error_envelope_y_vals = read_error_bar_file(file_in, q)
    minimum_cells = get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones)
    output_table(list_of_number_of_clones, list_of_fold_differences, file_out, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_out)

elif resample:
    print("resampling...")
    output_resample(file_in, file_out)

elif make_resample_plot:
    print("plotting resample...")
    plot_resample(file_in, file_out, precomputed_error_bar_file)

elif upper_bound:
	print("calculating strict upper limit U...")
	print(get_upper_bound(fit_file, D_number_file, N, sample_size))


else:
    print("""error: no option given. Options:
-R  --run_recon
-e  --make_error_bars
-p  --make_power_table
-T  --make_table_of_D_numbers
-r  --resample
-x  --make_resample_plot
exiting...
""")
    exit()
# Out:
# Streaming output truncated to the last 5000 lines.
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0
 148, 33: 116, 35: 113, 34: 109, 37: 97, 36: 96, 38: 79, 39: 77, 40: 75, 42: 68, 41: 66, 44: 64, 45: 51, 43: 49, 46: 48, 47: 39, 48: 39, 50: 38, 57: 35, 52: 34, 49: 33, 51: 30, 54: 29, 55: 29, 56: 29, 53: 27, 60: 26, 63: 22, 68: 22, 62: 19, 69: 18, 58: 17, 61: 17, 59: 16, 75: 16, 66: 16, 71: 15, 65: 14, 70: 13, 67: 12, 72: 11, 80: 10, 74: 9, 87: 9, 95: 9, 78: 9, 76: 8, 85: 8, 83: 8, 88: 8, 90: 8, 81: 8, 102: 7, 64: 7, 86: 7, 73: 7, 104: 6, 93: 6, 98: 6, 97: 6, 82: 6, 84: 6, 96: 6, 89: 6, 77: 6, 79: 5, 100: 5, 106: 5, 109: 5, 111: 4, 92: 4, 94: 4, 139: 4, 91: 4, 114: 4, 120: 3, 132: 3, 128: 3, 124: 3, 116: 3, 163: 3, 110: 3, 99: 3, 112: 2, 127: 2, 141: 2, 180: 2, 133: 2, 101: 2, 131: 2, 113: 2, 200: 2, 107: 2, 123: 2, 121: 2, 115: 2, 118: 2, 186: 1, 173: 1, 167: 1, 169: 1, 197: 1, 172: 1, 187: 1, 178: 1, 182: 1, 157: 1, 181: 1, 202: 1, 251: 1, 129: 1, 152: 1, 146: 1, 142: 1, 138: 1, 136: 1, 135: 1, 134: 1, 130: 1, 126: 1, 125: 1, 117: 1, 108: 1, 105: 1, 103: 1, 277: 1}, None, -2346864.2923210952, 12.36983323097229)

# %%
# this is a very low percentage of the assumed amount of clones (6%)
# the log likelihood is super low and not increasing much over time. There needs to be more data for this analysis
100* 3941522/58262035
# Out:
# 6.7651636267081985

# %% [markdown]
# ##### 1.3 df1-5 very verbose = true

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population

elif make_error_bars:
    print("making error-bar file...")
    print(make_error_bar_file(file_in, file_out, qs))

elif make_table_of_D_numbers:
    print("making table of D numbers...")
    output_table_of_D_numbers(precomputed_error_bar_file, file_out, list_of_filenames, qs)

elif make_power_table:
    print("making power table...")
    error_envelope_x_vals, error_envelope_y_vals = read_error_bar_file(file_in, q)
    minimum_cells = get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones)
    output_table(list_of_number_of_clones, list_of_fold_differences, file_out, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_out)

elif resample:
    print("resampling...")
    output_resample(file_in, file_out)

elif make_resample_plot:
    print("plotting resample...")
    plot_resample(file_in, file_out, precomputed_error_bar_file)

elif upper_bound:
	print("calculating strict upper limit U...")
	print(get_upper_bound(fit_file, D_number_file, N, sample_size))


else:
    print("""error: no option given. Options:
-R  --run_recon
-e  --make_error_bars
-p  --make_power_table
-T  --make_table_of_D_numbers
-r  --resample
-x  --make_resample_plot
exiting...
""")
    exit()
# Out:
# running recon on df_fill_in_test.tsv...
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.06342727504755778]
# iteration 1
# old estimated n0	60154061
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.06342727504755778]
# new estimated n_0	60154061
# score_function 0.000000
# Log likelihood	-3910522.491696
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.06342727504755778]
# Final estimated_n0	60154061
# Log likelihood	-3910522.491696
# Observed clones	3941522.000000
# Observed clones + estimated clones	64095583.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.28542273771401]
# iteration 1
# old estimated n0	11924670
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.28542273771401]
# new estimated n_0	11924670
# score_function 0.000000
# Log likelihood	-2950742.221565
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.28542273771401]
# Final estimated_n0	11924670
# Log likelihood	-2950742.221565
# Observed clones	3941522.000000
# Observed clones + estimated clones	15866192.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.5074182003804623]
# iteration 1
# old estimated n0	5959189
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.5074182003804623]
# new estimated n_0	5959189
# score_function 0.000000
# Log likelihood	-2877506.814705
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.5074182003804623]
# Final estimated_n0	5959189
# Log likelihood	-2877506.814705
# Observed clones	3941522.000000
# Observed clones + estimated clones	9900711.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7294136630469144]
# iteration 1
# old estimated n0	3668069
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7294136630469144]
# new estimated n_0	3668069
# score_function 0.000000
# Log likelihood	-3019363.585850
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7294136630469144]
# Final estimated_n0	3668069
# Log likelihood	-3019363.585850
# Observed clones	3941522.000000
# Observed clones + estimated clones	7609591.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.9514091257133666]
# iteration 1
# old estimated n0	2478368
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.9514091257133666]
# new estimated n_0	2478368
# score_function 0.000000
# Log likelihood	-3268073.215696
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.9514091257133666]
# Final estimated_n0	2478368
# Log likelihood	-3268073.215696
# Observed clones	3941522.000000
# Observed clones + estimated clones	6419890.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.173404588379819]
# iteration 1
# old estimated n0	1764013
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.173404588379819]
# new estimated n_0	1764013
# score_function 0.000000
# Log likelihood	-3584717.664286
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.173404588379819]
# Final estimated_n0	1764013
# Log likelihood	-3584717.664286
# Observed clones	3941522.000000
# Observed clones + estimated clones	5705535.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.3954000510462712]
# iteration 1
# old estimated n0	1297182
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.3954000510462712]
# new estimated n_0	1297182
# score_function 0.000000
# Log likelihood	-3950640.409917
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.3954000510462712]
# Final estimated_n0	1297182
# Log likelihood	-3950640.409917
# Observed clones	3941522.000000
# Observed clones + estimated clones	5238704.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.25370910019023113]
# iteration 1
# old estimated n0	13639374
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.25370910019023113]
# new estimated n_0	13639374
# score_function 0.000000
# Log likelihood	-2995871.923970
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.25370910019023113]
# Final estimated_n0	13639374
# Log likelihood	-2995871.923970
# Observed clones	3941522.000000
# Observed clones + estimated clones	17580896.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.26956591895212056]
# iteration 1
# old estimated n0	12731285
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.26956591895212056]
# new estimated n_0	12731285
# score_function 0.000000
# Log likelihood	-2971641.596252
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.26956591895212056]
# Final estimated_n0	12731285
# Log likelihood	-2971641.596252
# Observed clones	3941522.000000
# Observed clones + estimated clones	16672807.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.06342727504755778, 0.5074182003804623]
# iteration 1
# old estimated n0	6396141
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population

elif make_error_bars:
    print("making error-bar file...")
    print(make_error_bar_file(file_in, file_out, qs))

elif make_table_of_D_numbers:
    print("making table of D numbers...")
    output_table_of_D_numbers(precomputed_error_bar_file, file_out, list_of_filenames, qs)

elif make_power_table:
    print("making power table...")
    error_envelope_x_vals, error_envelope_y_vals = read_error_bar_file(file_in, q)
    minimum_cells = get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones)
    output_table(list_of_number_of_clones, list_of_fold_differences, file_out, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_out)

elif resample:
    print("resampling...")
    output_resample(file_in, file_out)

elif make_resample_plot:
    print("plotting resample...")
    plot_resample(file_in, file_out, precomputed_error_bar_file)

elif upper_bound:
	print("calculating strict upper limit U...")
	print(get_upper_bound(fit_file, D_number_file, N, sample_size))


else:
    print("""error: no option given. Options:
-R  --run_recon
-e  --make_error_bars
-p  --make_power_table
-T  --make_table_of_D_numbers
-r  --resample
-x  --make_resample_plot
exiting...
""")
    exit()
# Out:
# running recon on df_fill_in_1all.tsv...
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.09587260570870364]
# iteration 1
# old estimated n0	515966480
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.09587260570870364]
# new estimated n_0	515966480
# score_function 0.000000
# Log likelihood	-107640219.006563
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.09587260570870364]
# Final estimated_n0	515966480
# Log likelihood	-107640219.006563
# Observed clones	52152541.000000
# Observed clones + estimated clones	568119021.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.43142672568916635]
# iteration 1
# old estimated n0	96238253
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.43142672568916635]
# new estimated n_0	96238253
# score_function 0.000000
# Log likelihood	-74883331.044286
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.43142672568916635]
# Final estimated_n0	96238253
# Log likelihood	-74883331.044286
# Observed clones	52152541.000000
# Observed clones + estimated clones	148390794.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7669808456696291]
# iteration 1
# old estimated n0	45016871
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7669808456696291]
# new estimated n_0	45016871
# score_function 0.000000
# Log likelihood	-68449072.098367
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7669808456696291]
# Final estimated_n0	45016871
# Log likelihood	-68449072.098367
# Observed clones	52152541.000000
# Observed clones + estimated clones	97169412.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.1025349656500916]
# iteration 1
# old estimated n0	25805835
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.1025349656500916]
# new estimated n_0	25805835
# score_function 0.000000
# Log likelihood	-68398977.896990
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.1025349656500916]
# Final estimated_n0	25805835
# Log likelihood	-68398977.896990
# Observed clones	52152541.000000
# Observed clones + estimated clones	77958376.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.4380890856305544]
# iteration 1
# old estimated n0	16159912
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.4380890856305544]
# new estimated n_0	16159912
# score_function 0.000000
# Log likelihood	-71511987.415563
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.4380890856305544]
# Final estimated_n0	16159912
# Log likelihood	-71511987.415563
# Observed clones	52152541.000000
# Observed clones + estimated clones	68312453.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.7736432056110172]
# iteration 1
# old estimated n0	10611808
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.7736432056110172]
# new estimated n_0	10611808
# score_function 0.000000
# Log likelihood	-76622996.567139
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.7736432056110172]
# Final estimated_n0	10611808
# Log likelihood	-76622996.567139
# Observed clones	52152541.000000
# Observed clones + estimated clones	62764349.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.10919732559148]
# iteration 1
# old estimated n0	7169104
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.10919732559148]
# new estimated n_0	7169104
# score_function 0.000000
# Log likelihood	-83167079.353911
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.10919732559148]
# Final estimated_n0	7169104
# Log likelihood	-83167079.353911
# Observed clones	52152541.000000
# Observed clones + estimated clones	59321645.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.5512674828250458]
# iteration 1
# old estimated n0	70590604
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.5512674828250458]
# new estimated n_0	70590604
# score_function 0.000000
# Log likelihood	-71427603.598690
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.5512674828250458]
# Final estimated_n0	70590604
# Log likelihood	-71427603.598690
# Observed clones	52152541.000000
# Observed clones + estimated clones	122743145.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6591241642473374]
# iteration 1
# old estimated n0	55638230
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6591241642473374]
# new estimated n_0	55638230
# score_function 0.000000
# Log likelihood	-69536116.366087
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6591241642473374]
# Final estimated_n0	55638230
# Log likelihood	-69536116.366087
# Observed clones	52152541.000000
# Observed clones + estimated clones	107790771.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.09587260570870364, 1.1025349656500916]
# iteration 1
# old estimated n0	29311352
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.09587260570870364, 1.1025349656500916]
# new estimated n_0	29311352
# score_function 0.000000
# Log likelihood	-68235783.201712
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.09587260570870364, 1.1025349656500916]
# Final estimated_n0	29311352
# Log likelihood	-68235783.201712
# Observed clones	52152541.000000
# Observed clones + estimated clones	81463893.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.09587260570870364, 1.1025349656500916]
# iteration 1
# old estimated n0	35507654
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.09587260570870364, 1.1025349656500916]
# new estimated n_0	35507654
# score_function 0.000000
# Log likelihood	-67951197.312409
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.09587260570870364, 1.1025349656500916]
# Final estimated_n0	35507654
# Log likelihood	-67951197.312409
# Observed clones	52152541.000000
# Observed clones + estimated clones	87660195.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.09587260570870364, 1.1025349656500916]
# iteration 1
# old estimated n0	42727379
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.09587260570870364, 1.1025349656500916]
# new estimated n_0	42727379
# score_function 0.000000
# Log likelihood	-67625809.145117
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.09587260570870364, 1.1025349656500916]
# Final estimated_n0	42727379
# Log likelihood	-67625809.145117
# Observed clones	52152541.000000
# Observed clones + estimated clones	94879920.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.09587260570870364, 1.1025349656500916]
# /usr/local/lib/python3.9/dist-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# Streaming output truncated to the last 5000 lines.
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05000000000000002, 0.1221428585, 0.4967142849000001, 0.016557142830000003, 0.18875142826200003, 0.07550057130480001, 0.0025166857101600014, 0.028690217095824005, 0.019126811397216007] [2.10919732559148, 0.04793630285435182, 0.09587260570870364, 2.10919732559148, 0.09587260570870364, 0.23968151427175907, 2.10919732559148, 0.21571336284458317, 1.1025349656500916]
# new estimated n_0	265595375
# score_function 0.000000
# Log likelihood	-54825689.635641
#
# Completed iteration of clone sizes
# Fitted weights	[0.05000000000000002, 0.1221428585, 0.4967142849000001, 0.016557142830000003, 0.18875142826200003, 0.07550057130480001, 0.0025166857101600014, 0.028690217095824005, 0.019126811397216007]
# Fitted means	[2.10919732559148, 0.04793630285435182, 0.09587260570870364, 2.10919732559148, 0.09587260570870364, 0.23968151427175907, 2.10919732559148, 0.21571336284458317, 1.1025349656500916]
# Final estimated_n0	265595375
# Log likelihood	-54825689.635641
# Observed clones	52152541.000000
# Observed clones + estimated clones	317747916.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.11204081738775508, 0.4556326515673469, 0.015187755052244898, 0.17314040759559182, 0.06925616303823673, 0.002308538767941225, 0.026317341954529956, 0.01754489463635331, 2.10919732559148, 0.04793630285435182, 0.09587260570870364, 2.10919732559148, 0.09587260570870364, 0.23968151427175907, 2.10919732559148, 0.21571336284458317, 1.1025349656500916]
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
file_in = ['df_fill_in_2all.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 2.1 verbose = true

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population

elif make_error_bars:
    print("making error-bar file...")
    print(make_error_bar_file(file_in, file_out, qs))

elif make_table_of_D_numbers:
    print("making table of D numbers...")
    output_table_of_D_numbers(precomputed_error_bar_file, file_out, list_of_filenames, qs)

elif make_power_table:
    print("making power table...")
    error_envelope_x_vals, error_envelope_y_vals = read_error_bar_file(file_in, q)
    minimum_cells = get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones)
    output_table(list_of_number_of_clones, list_of_fold_differences, file_out, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_out)

elif resample:
    print("resampling...")
    output_resample(file_in, file_out)

elif make_resample_plot:
    print("plotting resample...")
    plot_resample(file_in, file_out, precomputed_error_bar_file)

elif upper_bound:
	print("calculating strict upper limit U...")
	print(get_upper_bound(fit_file, D_number_file, N, sample_size))


else:
    print("""error: no option given. Options:
-R  --run_recon
-e  --make_error_bars
-p  --make_power_table
-T  --make_table_of_D_numbers
-r  --resample
-x  --make_resample_plot
exiting...
""")
    exit()
# Out:
# running recon on df_fill_in_2all.tsv...
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.05568764273622112]
# iteration 1
# old estimated n0	14894062
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.05568764273622112]
# new estimated n_0	14894062
# score_function 0.000000
# Log likelihood	-405826.590062
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.05568764273622112]
# Final estimated_n0	14894062
# Log likelihood	-405826.590062
# Observed clones	852972.000000
# Observed clones + estimated clones	15747034.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.2505943923129951]
# iteration 1
# old estimated n0	2995005
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.2505943923129951]
# new estimated n_0	2995005
# score_function 0.000000
# Log likelihood	-346599.626876
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.2505943923129951]
# Final estimated_n0	2995005
# Log likelihood	-346599.626876
# Observed clones	852972.000000
# Observed clones + estimated clones	3847977.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.44550114188976897]
# iteration 1
# old estimated n0	1519661
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.44550114188976897]
# new estimated n_0	1519661
# score_function 0.000000
# Log likelihood	-379268.312161
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.44550114188976897]
# Final estimated_n0	1519661
# Log likelihood	-379268.312161
# Observed clones	852972.000000
# Observed clones + estimated clones	2372633.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6404078914665429]
# iteration 1
# old estimated n0	950615
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6404078914665429]
# new estimated n_0	950615
# score_function 0.000000
# Log likelihood	-435016.857279
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6404078914665429]
# Final estimated_n0	950615
# Log likelihood	-435016.857279
# Observed clones	852972.000000
# Observed clones + estimated clones	1803587.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.8353146410433168]
# iteration 1
# old estimated n0	653327
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.8353146410433168]
# new estimated n_0	653327
# score_function 0.000000
# Log likelihood	-502746.806643
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.8353146410433168]
# Final estimated_n0	653327
# Log likelihood	-502746.806643
# Observed clones	852972.000000
# Observed clones + estimated clones	1506299.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.0302213906200908]
# iteration 1
# old estimated n0	473414
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.0302213906200908]
# new estimated n_0	473414
# score_function 0.000000
# Log likelihood	-578461.804603
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.0302213906200908]
# Final estimated_n0	473414
# Log likelihood	-578461.804603
# Observed clones	852972.000000
# Observed clones + estimated clones	1326386.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.2251281401968648]
# iteration 1
# old estimated n0	354713
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.2251281401968648]
# new estimated n_0	354713
# score_function 0.000000
# Log likelihood	-660239.833894
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.2251281401968648]
# Final estimated_n0	354713
# Log likelihood	-660239.833894
# Observed clones	852972.000000
# Observed clones + estimated clones	1207685.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.12529719615649754]
# iteration 1
# old estimated n0	6389799
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.12529719615649754]
# new estimated n_0	6389799
# score_function 0.000000
# Log likelihood	-358069.310523
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.12529719615649754]
# Final estimated_n0	6389799
# Log likelihood	-358069.310523
# Observed clones	852972.000000
# Observed clones + estimated clones	7242771.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.12529719615649754]
# iteration 1
# old estimated n0	6389799
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.12529719615649754]
# new estimated n_0	6389799
# score_function 0.000000
# Log likelihood	-358069.310523
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.12529719615649754]
# Final estimated_n0	6389799
# Log likelihood	-358069.310523
# Observed clones	852972.000000
# Observed clones + estimated clones	7242771.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.05568764273622112, 0.2505943923129951]
# iteration 1
# old estimated n0	3146096
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.05568764273622112, 0.2505943923129951]
# new estimated n_0	3146096
# score_function 0.000000
# Log likelihood	-346069.595458
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.05568764273622112, 0.2505943923129951]
# Final estimated_n0	3146096
# Log likelihood	-346069.595458
# Observed clones	852972.000000
# Observed clones + estimated clones	3999068.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.05568764273622112, 0.2505943923129951]
# iteration 1
# old estimated n0	3409075
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.05568764273622112, 0.2505943923129951]
# new estimated n_0	3409075
# score_function 0.000000
# Log likelihood	-345164.517462
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.05568764273622112, 0.2505943923129951]
# Final estimated_n0	3409075
# Log likelihood	-345164.517462
# Observed clones	852972.000000
# Observed clones + estimated clones	4262047.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.05568764273622112, 0.2505943923129951]
# iteration 1
# old estimated n0	3709076
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.05568764273622112, 0.2505943923129951]
# new estimated n_0	3709076
# score_function 0.000000
# Log likelihood	-344159.856566
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.05568764273622112, 0.2505943923129951]
# Final estimated_n0	3709076
# Log likelihood	-344159.856566
# Observed clones	852972.000000
# Observed clones + estimated clones	4562048.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.05568764273622112, 0.2505943923129951]
# iteration 1
# old estimated n0	4054509
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.05568764273622112, 0.2505943923129951]
# new estimated n_0	4054509
# score_function 0.000000
# Log likelihood	-343041.147823
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.05568764273622112, 0.2505943923129951]
# Final estimated_n0	4054509
# Log likelihood	-343041.147823
# Observed clones	852972.000000
# Observed clones + estimated clones	4907481.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.05568764273622112, 0.2505943923129951]
# iteration 1
# old estimated n0	4456539
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429]
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_tcr.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 3.1 verbose = True

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population

elif make_error_bars:
    print("making error-bar file...")
    print(make_error_bar_file(file_in, file_out, qs))

elif make_table_of_D_numbers:
    print("making table of D numbers...")
    output_table_of_D_numbers(precomputed_error_bar_file, file_out, list_of_filenames, qs)

elif make_power_table:
    print("making power table...")
    error_envelope_x_vals, error_envelope_y_vals = read_error_bar_file(file_in, q)
    minimum_cells = get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones)
    output_table(list_of_number_of_clones, list_of_fold_differences, file_out, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_out)

elif resample:
    print("resampling...")
    output_resample(file_in, file_out)

elif make_resample_plot:
    print("plotting resample...")
    plot_resample(file_in, file_out, precomputed_error_bar_file)

elif upper_bound:
	print("calculating strict upper limit U...")
	print(get_upper_bound(fit_file, D_number_file, N, sample_size))


else:
    print("""error: no option given. Options:
-R  --run_recon
-e  --make_error_bars
-p  --make_power_table
-T  --make_table_of_D_numbers
-r  --resample
-x  --make_resample_plot
exiting...
""")
    exit()
# Out:
# Streaming output truncated to the last 5000 lines.
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [141.90716747215802, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-202563.611050
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[141.90716747215802, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-202563.611050
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 141.90716747215802, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [141.90716747215802, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-208777.729674
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[141.90716747215802, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-208777.729674
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 141.90716747215802, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [141.90716747215802, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-216108.828293
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[141.90716747215802, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-216108.828293
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-180749.462938
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-180749.462938
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-184278.382417
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-184278.382417
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-188140.979210
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-188140.979210
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-192407.008029
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-192407.008029
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-197170.676864
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-197170.676864
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-202563.611050
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-202563.611050
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-208777.729674
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-208777.729674
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 168.75446942635008, 19.176644252994326]
# iteration 1
# old estimated n0	0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [168.75446942635008, 19.176644252994326]
# new estimated n_0	0
# score_function 0.000000
# Log likelihood	-216108.828293
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[168.75446942635008, 19.176644252994326]
# Final estimated_n0	0
# Log likelihood	-216108.828293
# Observed clones	142770.000000
# Observed clones + estimated clones	142770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 3.835328850598865, 19.176644252994326]
# iteration 1
# old estimated n0	254
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [3.835328850598865, 19.176644252994326]
# new estimated n_0	254
# score_function 0.000000
# Log likelihood	-147538.643723
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[3.835328850598865, 19.176644252994326]
# Final estimated_n0	254
# Log likelihood	-147538.643723
# Observed clones	142770.000000
# Observed clones + estimated clones	143024.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.32499999999999996, 0.675, 5.752993275898298, 19.176644252994326]
# iteration 1
# old estimated n0	42
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.32499999999999996, 0.675] [5.752993275898298, 19.176644252994326]
# new estimated n_0	42
# score_function 0.000000
# Log likelihood	-142395.064088
#
# Completed iteration of clone sizes
# Fitted weights	[0.32499999999999996, 0.675]
# Fitted means	[5.752993275898298, 19.176644252994326]
# Final estimated_n0	42
# Log likelihood	-142395.064088
# Observed clones	142770.000000
# Observed clones + estimated clones	142812.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.2714285755, 0.6785714245, 7.67065770119773, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	6
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.2714285755, 0.6785714245] [7.67065770119773, 7.67065770119773, 19.176644252994326]
# new estimated n_0	6
# score_function 0.000000
# Log likelihood	-140097.318076
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.2714285755, 0.6785714245]
# Fitted means	[7.67065770119773, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	6
# Log likelihood	-140097.318076
# Observed clones	142770.000000
# Observed clones + estimated clones	142776.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.24897959516326526, 0.6224489748367347, 7.67065770119773, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	7
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.2489795951632653, 0.6224489748367348] [7.67065770119773, 7.67065770119773, 19.176644252994326]
# new estimated n_0	7
# score_function 0.000000
# Log likelihood	-140299.095358
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.2489795951632653, 0.6224489748367348]
# Fitted means	[7.67065770119773, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	7
# Log likelihood	-140299.095358
# Observed clones	142770.000000
# Observed clones + estimated clones	142777.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.22653061482653059, 0.5663265251734694, 7.67065770119773, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	8
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.22653061482653059, 0.5663265251734694] [7.67065770119773, 7.67065770119773, 19.176644252994326]
# new estimated n_0	8
# score_function 0.000000
# Log likelihood	-140905.838752
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.22653061482653059, 0.5663265251734694]
# Fitted means	[7.67065770119773, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	8
# Log likelihood	-140905.838752
# Observed clones	142770.000000
# Observed clones + estimated clones	142778.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.20408163448979588, 0.5102040755102041, 7.67065770119773, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	9
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.20408163448979588, 0.5102040755102041] [7.67065770119773, 7.67065770119773, 19.176644252994326]
# new estimated n_0	9
# score_function 0.000000
# Log likelihood	-141902.199689
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.20408163448979588, 0.5102040755102041]
# Fitted means	[7.67065770119773, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	9
# Log likelihood	-141902.199689
# Observed clones	142770.000000
# Observed clones + estimated clones	142779.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.1816326570102041, 0.45408163298979587, 7.67065770119773, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	10
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.1816326570102041, 0.45408163298979587] [7.67065770119773, 7.67065770119773, 19.176644252994326]
# new estimated n_0	10
# score_function 0.000000
# Log likelihood	-143300.850090
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.1816326570102041, 0.45408163298979587]
# Fitted means	[7.67065770119773, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	10
# Log likelihood	-143300.850090
# Observed clones	142770.000000
# Observed clones + estimated clones	142780.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0
000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.20408163448979588, 0.5102040755102041, 34.51795965538979, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	4
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.20408163448979588, 0.5102040755102041] [34.51795965538979, 7.67065770119773, 19.176644252994326]
# new estimated n_0	4
# score_function 0.000000
# Log likelihood	-149772.274796
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.20408163448979588, 0.5102040755102041]
# Fitted means	[34.51795965538979, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	4
# Log likelihood	-149772.274796
# Observed clones	142770.000000
# Observed clones + estimated clones	142774.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.1816326570102041, 0.45408163298979587, 34.51795965538979, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.1816326570102041, 0.45408163298979587] [34.51795965538979, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-153392.517889
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.1816326570102041, 0.45408163298979587]
# Fitted means	[34.51795965538979, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-153392.517889
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.1591836766734694, 0.3979591833265306, 34.51795965538979, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.1591836766734694, 0.3979591833265306] [34.51795965538979, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-157560.576541
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.1591836766734694, 0.3979591833265306]
# Fitted means	[34.51795965538979, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-157560.576541
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.13673469633673468, 0.3418367336632653, 34.51795965538979, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.13673469633673468, 0.3418367336632653] [34.51795965538979, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-162417.108090
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.13673469633673468, 0.3418367336632653]
# Fitted means	[34.51795965538979, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-162417.108090
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.114285716, 0.285714284, 34.51795965538979, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	2
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.114285716, 0.285714284] [34.51795965538979, 7.67065770119773, 19.176644252994326]
# new estimated n_0	2
# score_function 0.000000
# Log likelihood	-168184.082348
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.114285716, 0.285714284]
# Fitted means	[34.51795965538979, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	2
# Log likelihood	-168184.082348
# Observed clones	142770.000000
# Observed clones + estimated clones	142772.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.2714285755, 0.6785714245, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	5
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.2714285755, 0.6785714245] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	5
# score_function 0.000000
# Log likelihood	-142298.178429
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.2714285755, 0.6785714245]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	5
# Log likelihood	-142298.178429
# Observed clones	142770.000000
# Observed clones + estimated clones	142775.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.24897959516326526, 0.6224489748367347, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	5
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.2489795951632653, 0.6224489748367348] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	5
# score_function 0.000000
# Log likelihood	-145827.487926
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.2489795951632653, 0.6224489748367348]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	5
# Log likelihood	-145827.487926
# Observed clones	142770.000000
# Observed clones + estimated clones	142775.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.22653061482653059, 0.5663265251734694, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	4
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.22653061482653059, 0.5663265251734694] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	4
# score_function 0.000000
# Log likelihood	-149690.467211
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.22653061482653059, 0.5663265251734694]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	4
# Log likelihood	-149690.467211
# Observed clones	142770.000000
# Observed clones + estimated clones	142774.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.20408163448979588, 0.5102040755102041, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	4
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.20408163448979588, 0.5102040755102041] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	4
# score_function 0.000000
# Log likelihood	-153956.868517
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.20408163448979588, 0.5102040755102041]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	4
# Log likelihood	-153956.868517
# Observed clones	142770.000000
# Observed clones + estimated clones	142774.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.1816326570102041, 0.45408163298979587, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.1816326570102041, 0.45408163298979587] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-158720.896124
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.1816326570102041, 0.45408163298979587]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-158720.896124
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.1591836766734694, 0.3979591833265306, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.1591836766734694, 0.3979591833265306] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-164114.169568
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.1591836766734694, 0.3979591833265306]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-164114.169568
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.13673469633673468, 0.3418367336632653, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.13673469633673468, 0.3418367336632653] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-170328.598331
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.13673469633673468, 0.3418367336632653]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-170328.598331
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.114285716, 0.285714284, 61.36526160958184, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	2
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.114285716, 0.285714284] [61.36526160958184, 7.67065770119773, 19.176644252994326]
# new estimated n_0	2
# score_function 0.000000
# Log likelihood	-177659.960815
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.114285716, 0.285714284]
# Fitted means	[61.36526160958184, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	2
# Log likelihood	-177659.960815
# Observed clones	142770.000000
# Observed clones + estimated clones	142772.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.2714285755, 0.6785714245, 88.21256356377388, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	5
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.2714285755, 0.6785714245] [88.21256356377388, 7.67065770119773, 19.176644252994326]
# new estimated n_0	5
# score_function 0.000000
# Log likelihood	-142298.199474
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.2714285755, 0.6785714245]
# Fitted means	[88.21256356377388, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	5
# Log likelihood	-142298.199474
# Observed clones	142770.000000
# Observed clones + estimated clones	142775.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.24897959516326526, 0.6224489748367347, 88.21256356377388, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	5
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.2489795951632653, 0.6224489748367348] [88.21256356377388, 7.67065770119773, 19.176644252994326]
# new estimated n_0	5
# score_function 0.000000
# Log likelihood	-145827.546920
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.2489795951632653, 0.6224489748367348]
# Fitted means	[88.21256356377388, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	5
# Log likelihood	-145827.546920
# Observed clones	142770.000000
# Observed clones + estimated clones	142775.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.22653061482653059, 0.5663265251734694, 88.21256356377388, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	4
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.22653061482653059, 0.5663265251734694] [88.21256356377388, 7.67065770119773, 19.176644252994326]
# new estimated n_0	4
# score_function 0.000000
# Log likelihood	-149690.571675
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.22653061482653059, 0.5663265251734694]
# Fitted means	[88.21256356377388, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	4
# Log likelihood	-149690.571675
# Observed clones	142770.000000
# Observed clones + estimated clones	142774.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.20408163448979588, 0.5102040755102041, 88.21256356377388, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	4
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.20408163448979588, 0.5102040755102041] [88.21256356377388, 7.67065770119773, 19.176644252994326]
# new estimated n_0	4
# score_function 0.000000
# Log likelihood	-153957.028453
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.20408163448979588, 0.5102040755102041]
# Fitted means	[88.21256356377388, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	4
# Log likelihood	-153957.028453
# Observed clones	142770.000000
# Observed clones + estimated clones	142774.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.1816326570102041, 0.45408163298979587, 88.21256356377388, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.1816326570102041, 0.45408163298979587] [88.21256356377388, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-158721.125241
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.1816326570102041, 0.45408163298979587]
# Fitted means	[88.21256356377388, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-158721.125241
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0
000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.20408163448979588, 0.5102040755102041, 115.05986551796596, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	4
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.20408163448979588, 0.5102040755102041] [115.05986551796596, 7.67065770119773, 19.176644252994326]
# new estimated n_0	4
# score_function 0.000000
# Log likelihood	-153957.028453
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.20408163448979588, 0.5102040755102041]
# Fitted means	[115.05986551796596, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	4
# Log likelihood	-153957.028453
# Observed clones	142770.000000
# Observed clones + estimated clones	142774.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.1816326570102041, 0.45408163298979587, 115.05986551796596, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.1816326570102041, 0.45408163298979587] [115.05986551796596, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-158721.125241
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.1816326570102041, 0.45408163298979587]
# Fitted means	[115.05986551796596, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-158721.125241
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.1591836766734694, 0.3979591833265306, 115.05986551796596, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.1591836766734694, 0.3979591833265306] [115.05986551796596, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-164114.487376
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.1591836766734694, 0.3979591833265306]
# Fitted means	[115.05986551796596, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-164114.487376
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.13673469633673468, 0.3418367336632653, 115.05986551796596, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	3
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.13673469633673468, 0.3418367336632653] [115.05986551796596, 7.67065770119773, 19.176644252994326]
# new estimated n_0	3
# score_function 0.000000
# Log likelihood	-170329.033945
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.13673469633673468, 0.3418367336632653]
# Fitted means	[115.05986551796596, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	3
# Log likelihood	-170329.033945
# Observed clones	142770.000000
# Observed clones + estimated clones	142773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.114285716, 0.285714284, 115.05986551796596, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	2
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.114285716, 0.285714284] [115.05986551796596, 7.67065770119773, 19.176644252994326]
# new estimated n_0	2
# score_function 0.000000
# Log likelihood	-177660.560504
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.114285716, 0.285714284]
# Fitted means	[115.05986551796596, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	2
# Log likelihood	-177660.560504
# Observed clones	142770.000000
# Observed clones + estimated clones	142772.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.2714285755, 0.6785714245, 141.90716747215802, 7.67065770119773, 19.176644252994326]
# iteration 1
# old estimated n0	5
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.2714285755, 0.6785714245] [141.90716747215802, 7.67065770119773, 19.176644252994326]
# new estimated n_0	5
# score_function 0.000000
# Log likelihood	-142298.199474
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.2714285755, 0.6785714245]
# Fitted means	[141.90716747215802, 7.67065770119773, 19.176644252994326]
# Final estimated_n0	5
# Log likelihood	-142298.199474
# Observed clones	142770.000000
# Observed clones + estimated clones	142775.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif_10_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 4.1 verbose = True

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population

elif make_error_bars:
    print("making error-bar file...")
    print(make_error_bar_file(file_in, file_out, qs))

elif make_table_of_D_numbers:
    print("making table of D numbers...")
    output_table_of_D_numbers(precomputed_error_bar_file, file_out, list_of_filenames, qs)

elif make_power_table:
    print("making power table...")
    error_envelope_x_vals, error_envelope_y_vals = read_error_bar_file(file_in, q)
    minimum_cells = get_minimum_cells(list_of_number_of_clones, list_of_fold_differences, error_envelope_x_vals, error_envelope_y_vals, number_of_error_bars, min_number_of_doublets, fraction_small_clones)
    output_table(list_of_number_of_clones, list_of_fold_differences, file_out, number_of_error_bars, min_number_of_doublets, fraction_small_clones, minimum_cells, q, file_out)

elif resample:
    print("resampling...")
    output_resample(file_in, file_out)

elif make_resample_plot:
    print("plotting resample...")
    plot_resample(file_in, file_out, precomputed_error_bar_file)

elif upper_bound:
	print("calculating strict upper limit U...")
	print(get_upper_bound(fit_file, D_number_file, N, sample_size))


else:
    print("""error: no option given. Options:
-R  --run_recon
-e  --make_error_bars
-p  --make_power_table
-T  --make_table_of_D_numbers
-r  --resample
-x  --make_resample_plot
exiting...
""")
    exit()
# Out:
# running recon on df_fill_in_unif_10_000.tsv...
# 1.5460234556502516e-09
# 14311 9382.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.05329354082285227]
# iteration 1
# old estimated n0	171395
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.05329354082285227]
# new estimated n_0	171395
# score_function 0.000000
# Log likelihood	-2503.342607
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.05329354082285227]
# Final estimated_n0	171395
# Log likelihood	-2503.342607
# Observed clones	9382.000000
# Observed clones + estimated clones	180777.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.23982093370283522]
# iteration 1
# old estimated n0	34617
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.23982093370283522]
# new estimated n_0	34617
# score_function 0.000000
# Log likelihood	-2470.184967
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.23982093370283522]
# Final estimated_n0	34617
# Log likelihood	-2470.184967
# Observed clones	9382.000000
# Observed clones + estimated clones	43999.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.4263483265828182]
# iteration 1
# old estimated n0	17647
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.4263483265828182]
# new estimated n_0	17647
# score_function 0.000000
# Log likelihood	-3038.088206
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.4263483265828182]
# Final estimated_n0	17647
# Log likelihood	-3038.088206
# Observed clones	9382.000000
# Observed clones + estimated clones	27029.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6128757194628011]
# iteration 1
# old estimated n0	11093
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6128757194628011]
# new estimated n_0	11093
# score_function 0.000000
# Log likelihood	-3764.239799
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6128757194628011]
# Final estimated_n0	11093
# Log likelihood	-3764.239799
# Observed clones	9382.000000
# Observed clones + estimated clones	20475.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.799403112342784]
# iteration 1
# old estimated n0	7664
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.799403112342784]
# new estimated n_0	7664
# score_function 0.000000
# Log likelihood	-4577.153784
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.799403112342784]
# Final estimated_n0	7664
# Log likelihood	-4577.153784
# Observed clones	9382.000000
# Observed clones + estimated clones	17046.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.985930505222767]
# iteration 1
# old estimated n0	5584
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.985930505222767]
# new estimated n_0	5584
# score_function 0.000000
# Log likelihood	-5451.012595
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.985930505222767]
# Final estimated_n0	5584
# Log likelihood	-5451.012595
# Observed clones	9382.000000
# Observed clones + estimated clones	14966.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.17245789810275]
# iteration 1
# old estimated n0	4207
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.17245789810275]
# new estimated n_0	4207
# score_function 0.000000
# Log likelihood	-6373.319699
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.17245789810275]
# Final estimated_n0	4207
# Log likelihood	-6373.319699
# Observed clones	9382.000000
# Observed clones + estimated clones	13589.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.11991046685141761]
# iteration 1
# old estimated n0	73644
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.11991046685141761]
# new estimated n_0	73644
# score_function 0.000000
# Log likelihood	-2319.197608
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0
000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	65851
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	65851
# score_function 0.000000
# Log likelihood	-2337.649137
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	65851
# Log likelihood	-2337.649137
# Observed clones	9382.000000
# Observed clones + estimated clones	75233.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	56180
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	56180
# score_function 0.000000
# Log likelihood	-2419.526488
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	56180
# Log likelihood	-2419.526488
# Observed clones	9382.000000
# Observed clones + estimated clones	65562.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	48713
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	48713
# score_function 0.000000
# Log likelihood	-2509.521334
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	48713
# Log likelihood	-2509.521334
# Observed clones	9382.000000
# Observed clones + estimated clones	58095.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	42772
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	42772
# score_function 0.000000
# Log likelihood	-2593.480561
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	42772
# Log likelihood	-2593.480561
# Observed clones	9382.000000
# Observed clones + estimated clones	52154.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	37934
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	37934
# score_function 0.000000
# Log likelihood	-2668.666855
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	37934
# Log likelihood	-2668.666855
# Observed clones	9382.000000
# Observed clones + estimated clones	47316.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	33917
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	33917
# score_function 0.000000
# Log likelihood	-2735.228140
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	33917
# Log likelihood	-2735.228140
# Observed clones	9382.000000
# Observed clones + estimated clones	43299.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	30529
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	30529
# score_function 0.000000
# Log likelihood	-2794.069180
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	30529
# Log likelihood	-2794.069180
# Observed clones	9382.000000
# Observed clones + estimated clones	39911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.4263483265828182, 0.11991046685141761]
# iteration 1
# old estimated n0	27633
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.4263483265828182, 0.11991046685141761]
# new estimated n_0	27633
# score_function 0.000000
# Log likelihood	-2846.215353
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.4263483265828182, 0.11991046685141761]
# Final estimated_n0	27633
# Log likelihood	-2846.215353
# Observed clones	9382.000000
# Observed clones + estimated clones	37015.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.6128757194628011, 0.11991046685141761]
# iteration 1
# old estimated n0	62643
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.6128757194628011, 0.11991046685141761]
# new estimated n_0	62643
# score_function 0.000000
# Log likelihood	-2406.424805
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.799403112342784, 0.11991046685141761]
# Final estimated_n0	46055
# Log likelihood	-2932.268314
# Observed clones	9382.000000
# Observed clones + estimated clones	55437.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.799403112342784, 0.11991046685141761]
# iteration 1
# old estimated n0	36697
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.799403112342784, 0.11991046685141761]
# new estimated n_0	36697
# score_function 0.000000
# Log likelihood	-3269.477663
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.799403112342784, 0.11991046685141761]
# Final estimated_n0	36697
# Log likelihood	-3269.477663
# Observed clones	9382.000000
# Observed clones + estimated clones	46079.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.799403112342784, 0.11991046685141761]
# iteration 1
# old estimated n0	30043
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.799403112342784, 0.11991046685141761]
# new estimated n_0	30043
# score_function 0.000000
# Log likelihood	-3535.159902
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.799403112342784, 0.11991046685141761]
# Final estimated_n0	30043
# Log likelihood	-3535.159902
# Observed clones	9382.000000
# Observed clones + estimated clones	39425.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.799403112342784, 0.11991046685141761]
# iteration 1
# old estimated n0	25068
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.799403112342784, 0.11991046685141761]
# new estimated n_0	25068
# score_function 0.000000
# Log likelihood	-3747.092471
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.799403112342784, 0.11991046685141761]
# Final estimated_n0	25068
# Log likelihood	-3747.092471
# Observed clones	9382.000000
# Observed clones + estimated clones	34450.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.799403112342784, 0.11991046685141761]
# iteration 1
# old estimated n0	21207
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.799403112342784, 0.11991046685141761]
# new estimated n_0	21207
# score_function 0.000000
# Log likelihood	-3919.253840
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.799403112342784, 0.11991046685141761]
# Final estimated_n0	21207
# Log likelihood	-3919.253840
# Observed clones	9382.000000
# Observed clones + estimated clones	30589.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.799403112342784, 0.11991046685141761]
# iteration 1
# old estimated n0	18125
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.799403112342784, 0.11991046685141761]
# new estimated n_0	18125
# score_function 0.000000
# Log likelihood	-4061.564465
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.799403112342784, 0.11991046685141761]
# Final estimated_n0	18125
# Log likelihood	-4061.564465
# Observed clones	9382.000000
# Observed clones + estimated clones	27507.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.799403112342784, 0.11991046685141761]
# iteration 1
# old estimated n0	15607
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.799403112342784, 0.11991046685141761]
# new estimated n_0	15607
# score_function 0.000000
# Log likelihood	-4181.031151
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.799403112342784, 0.11991046685141761]
# Final estimated_n0	15607
# Log likelihood	-4181.031151
# Observed clones	9382.000000
# Observed clones + estimated clones	24989.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	58263
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	58263
# score_function 0.000000
# Log likelihood	-2665.061268
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	58263
# Log likelihood	-2665.061268
# Observed clones	9382.000000
# Observed clones + estimated clones	67645.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	43010
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	43010
# score_function 0.000000
# Log likelihood	-3278.806005
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	43010
# Log likelihood	-3278.806005
# Observed clones	9382.000000
# Observed clones + estimated clones	52392.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	33370
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	33370
# score_function 0.000000
# Log likelihood	-3750.703048
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	33370
# Log likelihood	-3750.703048
# Observed clones	9382.000000
# Observed clones + estimated clones	42752.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	26726
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	26726
# score_function 0.000000
# Log likelihood	-4110.522206
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	26726
# Log likelihood	-4110.522206
# Observed clones	9382.000000
# Observed clones + estimated clones	36108.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	21870
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	21870
# score_function 0.000000
# Log likelihood	-4391.482815
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	21870
# Log likelihood	-4391.482815
# Observed clones	9382.000000
# Observed clones + estimated clones	31252.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	18164
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	18164
# score_function 0.000000
# Log likelihood	-4616.259222
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	18164
# Log likelihood	-4616.259222
# Observed clones	9382.000000
# Observed clones + estimated clones	27546.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	15245
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	15245
# score_function 0.000000
# Log likelihood	-4799.927868
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	15245
# Log likelihood	-4799.927868
# Observed clones	9382.000000
# Observed clones + estimated clones	24627.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.985930505222767, 0.11991046685141761]
# iteration 1
# old estimated n0	12885
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.985930505222767, 0.11991046685141761]
# new estimated n_0	12885
# score_function 0.000000
# Log likelihood	-4952.719812
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.985930505222767, 0.11991046685141761]
# Final estimated_n0	12885
# Log likelihood	-4952.719812
# Observed clones	9382.000000
# Observed clones + estimated clones	22267.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	56749
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	56749
# score_function 0.000000
# Log likelihood	-2830.912577
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	56749
# Log likelihood	-2830.912577
# Observed clones	9382.000000
# Observed clones + estimated clones	66131.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	40726
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	40726
# score_function 0.000000
# Log likelihood	-3653.420920
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	40726
# Log likelihood	-3653.420920
# Observed clones	9382.000000
# Observed clones + estimated clones	50108.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	30953
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	30953
# score_function 0.000000
# Log likelihood	-4262.683757
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	30953
# Log likelihood	-4262.683757
# Observed clones	9382.000000
# Observed clones + estimated clones	40335.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	24370
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	24370
# score_function 0.000000
# Log likelihood	-4718.689091
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	24370
# Log likelihood	-4718.689091
# Observed clones	9382.000000
# Observed clones + estimated clones	33752.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	19634
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	19634
# score_function 0.000000
# Log likelihood	-5070.679295
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	19634
# Log likelihood	-5070.679295
# Observed clones	9382.000000
# Observed clones + estimated clones	29016.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	16064
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	16064
# score_function 0.000000
# Log likelihood	-5350.061961
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	16064
# Log likelihood	-5350.061961
# Observed clones	9382.000000
# Observed clones + estimated clones	25446.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	13276
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	13276
# score_function 0.000000
# Log likelihood	-5577.031355
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	13276
# Log likelihood	-5577.031355
# Observed clones	9382.000000
# Observed clones + estimated clones	22658.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.17245789810275, 0.11991046685141761]
# iteration 1
# old estimated n0	11039
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.17245789810275, 0.11991046685141761]
# new estimated n_0	11039
# score_function 0.000000
# Log likelihood	-5765.009481
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.17245789810275, 0.11991046685141761]
# Final estimated_n0	11039
# Log likelihood	-5765.009481
# Observed clones	9382.000000
# Observed clones + estimated clones	20421.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.059955233425708805, 0.11991046685141761]
# iteration 1
# old estimated n0	75708
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.059955233425708805, 0.11991046685141761]
# new estimated n_0	75708
# score_function 0.000000
# Log likelihood	-2319.812218
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.059955233425708805, 0.11991046685141761]
# Final estimated_n0	75708
# Log likelihood	-2319.812218
# Observed clones	9382.000000
# Observed clones + estimated clones	85090.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.05662438712428054, 0.11991046685141761]
# iteration 1
# old estimated n0	75829
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.05662438712428054, 0.11991046685141761]
# new estimated n_0	75829
# score_function 0.000000
# Log likelihood	-2319.811043
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.05662438712428054, 0.11991046685141761]
# Final estimated_n0	75829
# Log likelihood	-2319.811043
# Observed clones	9382.000000
# Observed clones + estimated clones	85211.000000
# === END FIT ===
#
# ([1.0], [0.11991046685141761], 73644, {1: 8792, 2: 564, 3: 24, 4: 2}, None, -2319.19760774148, 1.5505383014678955)

# %% [markdown]
# ### Uniform 100,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif_100_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 5.1 Verbose = True

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_unif_100_000.tsv...
# 2.9124949091787086e-07
# 69413 57295.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.08726764988218867]
# iteration 1
# old estimated n0	628313
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.08726764988218867]
# new estimated n_0	628313
# score_function 0.000000
# Log likelihood	-144360.442718
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.08726764988218867]
# Final estimated_n0	628313
# Log likelihood	-144360.442718
# Observed clones	57295.000000
# Observed clones + estimated clones	685608.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.39270442446984904]
# iteration 1
# old estimated n0	119121
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.39270442446984904]
# new estimated n_0	119121
# score_function 0.000000
# Log likelihood	-89228.326297
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.39270442446984904]
# Final estimated_n0	119121
# Log likelihood	-89228.326297
# Observed clones	57295.000000
# Observed clones + estimated clones	176416.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6981411990575094]
# iteration 1
# old estimated n0	56727
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6981411990575094]
# new estimated n_0	56727
# score_function 0.000000
# Log likelihood	-74198.590932
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6981411990575094]
# Final estimated_n0	56727
# Log likelihood	-74198.590932
# Observed clones	57295.000000
# Observed clones + estimated clones	114022.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.0035779736451695]
# iteration 1
# old estimated n0	33156
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.0035779736451695]
# new estimated n_0	33156
# score_function 0.000000
# Log likelihood	-68676.374825
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.0035779736451695]
# Final estimated_n0	33156
# Log likelihood	-68676.374825
# Observed clones	57295.000000
# Observed clones + estimated clones	90451.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.6144515228204905]
# iteration 1
# old estimated n0	14234
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.6144515228204905]
# new estimated n_0	14234
# score_function 0.000000
# Log likelihood	-69581.408627
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.6144515228204905]
# Final estimated_n0	14234
# Log likelihood	-69581.408627
# Observed clones	57295.000000
# Observed clones + estimated clones	71529.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.9198882974081508]
# iteration 1
# old estimated n0	9844
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.9198882974081508]
# new estimated n_0	9844
# score_function 0.000000
# Log likelihood	-73383.290862
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.9198882974081508]
# Final estimated_n0	9844
# Log likelihood	-73383.290862
# Observed clones	57295.000000
# Observed clones + estimated clones	67139.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.654507374116415]
# iteration 1
# old estimated n0	61995
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.654507374116415]
# new estimated n_0	61995
# score_function 0.000000
# Log likelihood	-75564.871265
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.654507374116415]
# Final estimated_n0	61995
# Log likelihood	-75564.871265
# Observed clones	57295.000000
# Observed clones + estimated clones	119290.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.8290426738807923]
# iteration 1
# old estimated n0	44376
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.8290426738807923]
# new estimated n_0	44376
# score_function 0.000000
# Log likelihood	-71082.363782
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.8290426738807923]
# Final estimated_n0	44376
# Log likelihood	-71082.363782
# Observed clones	57295.000000
# Observed clones + estimated clones	101671.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	24837
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	24837
# score_function 0.000000
# Log likelihood	-67702.507400
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	24837
# Log likelihood	-67702.507400
# Observed clones	57295.000000
# Observed clones + estimated clones	82132.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	31286
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	31286
# score_function 0.000000
# Log likelihood	-67660.471755
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	31286
# Log likelihood	-67660.471755
# Observed clones	57295.000000
# Observed clones + estimated clones	88581.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	38833
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	38833
# score_function 0.000000
# Log likelihood	-67618.649863
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	38833
# Log likelihood	-67618.649863
# Observed clones	57295.000000
# Observed clones + estimated clones	96128.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	47786
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	47786
# score_function 0.000000
# Log likelihood	-67579.337417
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	47786
# Log likelihood	-67579.337417
# Observed clones	57295.000000
# Observed clones + estimated clones	105081.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	58579
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	58579
# score_function 0.000000
# Log likelihood	-67546.794340
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	58579
# Log likelihood	-67546.794340
# Observed clones	57295.000000
# Observed clones + estimated clones	115874.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	71842
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	71842
# score_function 0.000000
# Log likelihood	-67529.039327
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	71842
# Log likelihood	-67529.039327
# Observed clones	57295.000000
# Observed clones + estimated clones	129137.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	88534
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	88534
# score_function 0.000000
# Log likelihood	-67541.657676
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	88534
# Log likelihood	-67541.657676
# Observed clones	57295.000000
# Observed clones + estimated clones	145829.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	110182
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.08726764988218867, 1.30901474823283]
# new estimated n_0	110182
# score_function 0.000000
# Log likelihood	-67616.529516
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.08726764988218867, 1.30901474823283]
# Final estimated_n0	110182
# Log likelihood	-67616.529516
# Observed clones	57295.000000
# Observed clones + estimated clones	167477.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	23441
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	23441
# score_function 0.000000
# Log likelihood	-67665.137172
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	23441
# Log likelihood	-67665.137172
# Observed clones	57295.000000
# Observed clones + estimated clones	80736.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	27233
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	27233
# score_function 0.000000
# Log likelihood	-67589.240478
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	27233
# Log likelihood	-67589.240478
# Observed clones	57295.000000
# Observed clones + estimated clones	84528.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	31398
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	31398
# score_function 0.000000
# Log likelihood	-67552.163113
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	31398
# Log likelihood	-67552.163113
# Observed clones	57295.000000
# Observed clones + estimated clones	88693.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	35995
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	35995
# score_function 0.000000
# Log likelihood	-67568.166546
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	35995
# Log likelihood	-67568.166546
# Observed clones	57295.000000
# Observed clones + estimated clones	93290.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	41095
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	41095
# score_function 0.000000
# Log likelihood	-67657.230640
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	41095
# Log likelihood	-67657.230640
# Observed clones	57295.000000
# Observed clones + estimated clones	98390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	46784
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	46784
# score_function 0.000000
# Log likelihood	-67848.007909
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	46784
# Log likelihood	-67848.007909
# Observed clones	57295.000000
# Observed clones + estimated clones	104079.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	53172
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	53172
# score_function 0.000000
# Log likelihood	-68182.820442
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	53172
# Log likelihood	-68182.820442
# Observed clones	57295.000000
# Observed clones + estimated clones	110467.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.39270442446984904, 1.30901474823283]
# iteration 1
# old estimated n0	60395
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.39270442446984904, 1.30901474823283]
# new estimated n_0	60395
# score_function 0.000000
# Log likelihood	-68726.630005
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.39270442446984904, 1.30901474823283]
# Final estimated_n0	60395
# Log likelihood	-68726.630005
# Observed clones	57295.000000
# Observed clones + estimated clones	117690.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	22443
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	22443
# score_function 0.000000
# Log likelihood	-67672.135031
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	22443
# Log likelihood	-67672.135031
# Observed clones	57295.000000
# Observed clones + estimated clones	79738.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	24476
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	24476
# score_function 0.000000
# Log likelihood	-67609.698905
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	24476
# Log likelihood	-67609.698905
# Observed clones	57295.000000
# Observed clones + estimated clones	81771.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	26616
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	26616
# score_function 0.000000
# Log likelihood	-67585.375693
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	26616
# Log likelihood	-67585.375693
# Observed clones	57295.000000
# Observed clones + estimated clones	83911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	28871
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	28871
# score_function 0.000000
# Log likelihood	-67607.016239
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	28871
# Log likelihood	-67607.016239
# Observed clones	57295.000000
# Observed clones + estimated clones	86166.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	31251
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	31251
# score_function 0.000000
# Log likelihood	-67684.559457
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	31251
# Log likelihood	-67684.559457
# Observed clones	57295.000000
# Observed clones + estimated clones	88546.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	33765
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	33765
# score_function 0.000000
# Log likelihood	-67830.820431
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	33765
# Log likelihood	-67830.820431
# Observed clones	57295.000000
# Observed clones + estimated clones	91060.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	36427
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	36427
# score_function 0.000000
# Log likelihood	-68062.701432
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	36427
# Log likelihood	-68062.701432
# Observed clones	57295.000000
# Observed clones + estimated clones	93722.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.6981411990575094, 1.30901474823283]
# iteration 1
# old estimated n0	39249
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.6981411990575094, 1.30901474823283]
# new estimated n_0	39249
# score_function 0.000000
# Log likelihood	-68403.146600
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.6981411990575094, 1.30901474823283]
# Final estimated_n0	39249
# Log likelihood	-68403.146600
# Observed clones	57295.000000
# Observed clones + estimated clones	96544.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	21723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	21723
# score_function 0.000000
# Log likelihood	-67697.451087
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	21723
# Log likelihood	-67697.451087
# Observed clones	57295.000000
# Observed clones + estimated clones	79018.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	22558
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	22558
# score_function 0.000000
# Log likelihood	-67658.860120
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	22558
# Log likelihood	-67658.860120
# Observed clones	57295.000000
# Observed clones + estimated clones	79853.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	23410
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	23410
# score_function 0.000000
# Log likelihood	-67634.373688
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	23410
# Log likelihood	-67634.373688
# Observed clones	57295.000000
# Observed clones + estimated clones	80705.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	24281
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	24281
# score_function 0.000000
# Log likelihood	-67625.412985
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	24281
# Log likelihood	-67625.412985
# Observed clones	57295.000000
# Observed clones + estimated clones	81576.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	25171
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	25171
# score_function 0.000000
# Log likelihood	-67633.616052
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	25171
# Log likelihood	-67633.616052
# Observed clones	57295.000000
# Observed clones + estimated clones	82466.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	26081
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	26081
# score_function 0.000000
# Log likelihood	-67660.887397
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	26081
# Log likelihood	-67660.887397
# Observed clones	57295.000000
# Observed clones + estimated clones	83376.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	27011
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	27011
# score_function 0.000000
# Log likelihood	-67709.464048
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	27011
# Log likelihood	-67709.464048
# Observed clones	57295.000000
# Observed clones + estimated clones	84306.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.0035779736451695, 1.30901474823283]
# iteration 1
# old estimated n0	27962
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.0035779736451695, 1.30901474823283]
# new estimated n_0	27962
# score_function 0.000000
# Log likelihood	-67782.005724
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.0035779736451695, 1.30901474823283]
# Final estimated_n0	27962
# Log likelihood	-67782.005724
# Observed clones	57295.000000
# Observed clones + estimated clones	85257.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.30901474823283, 1.30901474823283]
# iteration 1
# old estimated n0	21201
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.30901474823283, 1.30901474823283]
# new estimated n_0	21201
# score_function 0.000000
# Log likelihood	-67728.777713
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.30901474823283, 1.30901474823283]
# Final estimated_n0	21201
# Log likelihood	-67728.777713
# Observed clones	57295.000000
# Observed clones + estimated clones	78496.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	20820
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	20820
# score_function 0.000000
# Log likelihood	-67760.993234
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	20820
# Log likelihood	-67760.993234
# Observed clones	57295.000000
# Observed clones + estimated clones	78115.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	20230
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	20230
# score_function 0.000000
# Log likelihood	-67829.699653
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	20230
# Log likelihood	-67829.699653
# Observed clones	57295.000000
# Observed clones + estimated clones	77525.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	19648
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	19648
# score_function 0.000000
# Log likelihood	-67918.196815
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	19648
# Log likelihood	-67918.196815
# Observed clones	57295.000000
# Observed clones + estimated clones	76943.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	19075
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	19075
# score_function 0.000000
# Log likelihood	-68024.355520
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	19075
# Log likelihood	-68024.355520
# Observed clones	57295.000000
# Observed clones + estimated clones	76370.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	18511
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	18511
# score_function 0.000000
# Log likelihood	-68146.444910
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	18511
# Log likelihood	-68146.444910
# Observed clones	57295.000000
# Observed clones + estimated clones	75806.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	17955
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	17955
# score_function 0.000000
# Log likelihood	-68283.028358
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	17955
# Log likelihood	-68283.028358
# Observed clones	57295.000000
# Observed clones + estimated clones	75250.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	17407
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	17407
# score_function 0.000000
# Log likelihood	-68432.894271
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	17407
# Log likelihood	-68432.894271
# Observed clones	57295.000000
# Observed clones + estimated clones	74702.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.6144515228204905, 1.30901474823283]
# iteration 1
# old estimated n0	16867
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.6144515228204905, 1.30901474823283]
# new estimated n_0	16867
# score_function 0.000000
# Log likelihood	-68595.007956
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.6144515228204905, 1.30901474823283]
# Final estimated_n0	16867
# Log likelihood	-68595.007956
# Observed clones	57295.000000
# Observed clones + estimated clones	74162.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	20542
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	20542
# score_function 0.000000
# Log likelihood	-67795.223956
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	20542
# Log likelihood	-67795.223956
# Observed clones	57295.000000
# Observed clones + estimated clones	77837.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	19530
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	19530
# score_function 0.000000
# Log likelihood	-67982.972891
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	19530
# Log likelihood	-67982.972891
# Observed clones	57295.000000
# Observed clones + estimated clones	76825.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	18543
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	18543
# score_function 0.000000
# Log likelihood	-68249.908523
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	18543
# Log likelihood	-68249.908523
# Observed clones	57295.000000
# Observed clones + estimated clones	75838.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	17582
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	17582
# score_function 0.000000
# Log likelihood	-68580.099098
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	17582
# Log likelihood	-68580.099098
# Observed clones	57295.000000
# Observed clones + estimated clones	74877.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	16645
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	16645
# score_function 0.000000
# Log likelihood	-68963.047639
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	16645
# Log likelihood	-68963.047639
# Observed clones	57295.000000
# Observed clones + estimated clones	73940.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	15730
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	15730
# score_function 0.000000
# Log likelihood	-69391.321096
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	15730
# Log likelihood	-69391.321096
# Observed clones	57295.000000
# Observed clones + estimated clones	73025.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	14839
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	14839
# score_function 0.000000
# Log likelihood	-69859.418744
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	14839
# Log likelihood	-69859.418744
# Observed clones	57295.000000
# Observed clones + estimated clones	72134.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.9198882974081508, 1.30901474823283]
# iteration 1
# old estimated n0	13968
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.9198882974081508, 1.30901474823283]
# new estimated n_0	13968
# score_function 0.000000
# Log likelihood	-70363.149418
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.9198882974081508, 1.30901474823283]
# Final estimated_n0	13968
# Log likelihood	-70363.149418
# Observed clones	57295.000000
# Observed clones + estimated clones	71263.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.043633824941094336, 1.30901474823283]
# iteration 1
# old estimated n0	77335
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.043633824941094336, 1.30901474823283]
# new estimated n_0	77335
# score_function 0.000000
# Log likelihood	-67572.662433
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.043633824941094336, 1.30901474823283]
# Final estimated_n0	77335
# Log likelihood	-67572.662433
# Observed clones	57295.000000
# Observed clones + estimated clones	134630.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.482142855, 0.517857145, 0.06545073741164151, 1.30901474823283]
# iteration 1
# old estimated n0	82949
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.482142855, 0.517857145] [0.06545073741164151, 1.30901474823283]
# new estimated n_0	82949
# score_function 0.000000
# Log likelihood	-67531.259171
#
# Completed iteration of clone sizes
# Fitted weights	[0.482142855, 0.517857145]
# Fitted means	[0.06545073741164151, 1.30901474823283]
# Final estimated_n0	82949
# Log likelihood	-67531.259171
# Observed clones	57295.000000
# Observed clones + estimated clones	140244.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 0.08726764988218867, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	77305
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [0.08726764988218867, 0.08726764988218867, 1.30901474823283]
# new estimated n_0	77305
# score_function 0.000000
# Log likelihood	-67528.870080
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[0.08726764988218867, 0.08726764988218867, 1.30901474823283]
# Final estimated_n0	77305
# Log likelihood	-67528.870080
# Observed clones	57295.000000
# Observed clones + estimated clones	134600.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.3859183642244898, 0.4855102057755102, 0.08726764988218867, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	86888
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.38591836422448983, 0.48551020577551024] [0.08726764988218867, 0.08726764988218867, 1.30901474823283]
# new estimated n_0	86888
# score_function 0.000000
# Log likelihood	-67538.675621
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 0.043633824941094336, 0.08726764988218867, 1.30901474823283]
# iteration 1
# old estimated n0	77954
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [0.043633824941094336, 0.08726764988218867, 1.30901474823283]
# new estimated n_0	77954
# score_function 0.000000
# Log likelihood	-67528.317169
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[0.043633824941094336, 0.08726764988218867, 1.30901474823283]
# Final estimated_n0	77954
# Log likelihood	-67528.317169
# Observed clones	57295.000000
# Observed clones + estimated clones	135249.000000
# === END FIT ===
#
# ([0.44285714, 0.55714286], [0.08726764988218867, 1.30901474823283], 71842, {1: 30166, 2: 16482, 3: 7042, 4: 2579, 5: 785, 6: 193, 7: 41, 8: 5, 9: 2}, None, -67529.03932674859, 2.702735662460327)

# %% [markdown]
# ### Uniform 1,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif_1_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 6.1 Verbose = True

# %%
test1 = pd.read_csv('df_fill_in_unif_1_000_000.tsv', sep='\t', header=None)

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_unif_1_000_000.tsv...
# 96327 96324.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.5190814334952868]
# iteration 1
# old estimated n0	141463
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.5190814334952868]
# new estimated n_0	141463
# score_function 0.000000
# Log likelihood	-2332160.416817
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.5190814334952868]
# Final estimated_n0	141463
# Log likelihood	-2332160.416817
# Observed clones	96324.000000
# Observed clones + estimated clones	237787.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.3358664507287905]
# iteration 1
# old estimated n0	10308
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.3358664507287905]
# new estimated n_0	10308
# score_function 0.000000
# Log likelihood	-1083030.487869
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.3358664507287905]
# Final estimated_n0	10308
# Log likelihood	-1083030.487869
# Observed clones	96324.000000
# Observed clones + estimated clones	106632.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 4.152651467962294]
# iteration 1
# old estimated n0	1538
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [4.152651467962294]
# new estimated n_0	1538
# score_function 0.000000
# Log likelihood	-691903.931450
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[4.152651467962294]
# Final estimated_n0	1538
# Log likelihood	-691903.931450
# Observed clones	96324.000000
# Observed clones + estimated clones	97862.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 5.969436485195797]
# iteration 1
# old estimated n0	247
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [5.969436485195797]
# new estimated n_0	247
# score_function 0.000000
# Log likelihood	-505848.716953
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[5.969436485195797]
# Final estimated_n0	247
# Log likelihood	-505848.716953
# Observed clones	96324.000000
# Observed clones + estimated clones	96571.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 7.786221502429301]
# iteration 1
# old estimated n0	40
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [7.786221502429301]
# new estimated n_0	40
# score_function 0.000000
# Log likelihood	-415740.318183
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[7.786221502429301]
# Final estimated_n0	40
# Log likelihood	-415740.318183
# Observed clones	96324.000000
# Observed clones + estimated clones	96364.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 9.603006519662806]
# iteration 1
# old estimated n0	7
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [9.603006519662806]
# new estimated n_0	7
# score_function 0.000000
# Log likelihood	-381336.525618
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[9.603006519662806]
# Final estimated_n0	7
# Log likelihood	-381336.525618
# Observed clones	96324.000000
# Observed clones + estimated clones	96331.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 11.41979153689631]
# iteration 1
# old estimated n0	1
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [11.41979153689631]
# new estimated n_0	1
# score_function 0.000000
# Log likelihood	-383285.001844
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[11.41979153689631]
# Final estimated_n0	1
# Log likelihood	-383285.001844
# Observed clones	96324.000000
# Observed clones + estimated clones	96325.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 4.801503259831403]
# iteration 1
# old estimated n0	798
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [4.801503259831403]
# new estimated n_0	798
# score_function 0.000000
# Log likelihood	-610186.376606
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[4.801503259831403]
# Final estimated_n0	798
# Log likelihood	-610186.376606
# Observed clones	96324.000000
# Observed clones + estimated clones	97122.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 8.110647398363856]
# iteration 1
# old estimated n0	29
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [8.110647398363856]
# new estimated n_0	29
# score_function 0.000000
# Log likelihood	-406236.321587
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[8.110647398363856]
# Final estimated_n0	29
# Log likelihood	-406236.321587
# Observed clones	96324.000000
# Observed clones + estimated clones	96353.000000
# === END FIT ===
#
# ([], [], 0, {4: 5171, 6: 5149, 3: 5148, 8: 5101, 5: 5067, 1: 5064, 2: 5061, 9: 5024, 7: 5018, 12: 5006, 10: 5002, 11: 4952, 13: 4862, 14: 4707, 15: 4490, 16: 4072, 17: 3744, 18: 3149, 19: 2634, 20: 2172, 21: 1722, 22: 1312, 23: 954, 24: 676, 25: 429, 26: 262, 27: 167, 28: 88, 29: 60, 30: 32, 31: 18, 32: 5, 33: 3, 34: 3}, None, 1.0, 0.13356232643127441)

# %% [markdown]
# ### Uniform 3,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif_3_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 7.1 Verbose = True

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# Streaming output truncated to the last 5000 lines.
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.
# %% [markdown]
# ## Mixed Poisson Distribution 1

# %% [markdown]
# ### Mixed Poisson 10,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp_10000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 8.1 Verbose = True

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp_10000.tsv...
# 14748 9564.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.05227938101212881]
# iteration 1
# old estimated n0	178200
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.05227938101212881]
# new estimated n_0	178200
# score_function 0.000000
# Log likelihood	-1845.275154
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.05227938101212881]
# Final estimated_n0	178200
# Log likelihood	-1845.275154
# Observed clones	9564.000000
# Observed clones + estimated clones	187764.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.23525721455457965]
# iteration 1
# old estimated n0	36059
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.23525721455457965]
# new estimated n_0	36059
# score_function 0.000000
# Log likelihood	-2085.453481
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.23525721455457965]
# Final estimated_n0	36059
# Log likelihood	-2085.453481
# Observed clones	9564.000000
# Observed clones + estimated clones	45623.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.4182350480970305]
# iteration 1
# old estimated n0	18418
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.4182350480970305]
# new estimated n_0	18418
# score_function 0.000000
# Log likelihood	-2757.154028
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.4182350480970305]
# Final estimated_n0	18418
# Log likelihood	-2757.154028
# Observed clones	9564.000000
# Observed clones + estimated clones	27982.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6012128816394813]
# iteration 1
# old estimated n0	11602
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6012128816394813]
# new estimated n_0	11602
# score_function 0.000000
# Log likelihood	-3547.931906
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6012128816394813]
# Final estimated_n0	11602
# Log likelihood	-3547.931906
# Observed clones	9564.000000
# Observed clones + estimated clones	21166.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7841907151819322]
# iteration 1
# old estimated n0	8033
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7841907151819322]
# new estimated n_0	8033
# score_function 0.000000
# Log likelihood	-4407.292016
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7841907151819322]
# Final estimated_n0	8033
# Log likelihood	-4407.292016
# Observed clones	9564.000000
# Observed clones + estimated clones	17597.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.9671685487243831]
# iteration 1
# old estimated n0	5866
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.9671685487243831]
# new estimated n_0	5866
# score_function 0.000000
# Log likelihood	-5316.937532
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.9671685487243831]
# Final estimated_n0	5866
# Log likelihood	-5316.937532
# Observed clones	9564.000000
# Observed clones + estimated clones	15430.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.1501463822668339]
# iteration 1
# old estimated n0	4431
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.1501463822668339]
# new estimated n_0	4431
# score_function 0.000000
# Log likelihood	-6267.949896
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.1501463822668339]
# Final estimated_n0	4431
# Log likelihood	-6267.949896
# Observed clones	9564.000000
# Observed clones + estimated clones	13995.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.026139690506064406]
# iteration 1
# old estimated n0	361119
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.026139690506064406]
# new estimated n_0	361119
# score_function 0.000000
# Log likelihood	-2021.670483
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.026139690506064406]
# Final estimated_n0	361119
# Log likelihood	-2021.670483
# Observed clones	9564.000000
# Observed clones + estimated clones	370683.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.026139690506064406]
# iteration 1
# old estimated n0	361119
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.026139690506064406]
# new estimated n_0	361119
# score_function 0.000000
# Log likelihood	-2021.670483
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.026139690506064406]
# Final estimated_n0	361119
# Log likelihood	-2021.670483
# Observed clones	9564.000000
# Observed clones + estimated clones	370683.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.05227938101212881, 0.05227938101212881]
# iteration 1
# old estimated n0	178200
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.05227938101212881, 0.05227938101212881]
# new estimated n_0	178200
# score_function 0.000000
# Log likelihood	-1845.275154
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.05227938101212881, 0.05227938101212881]
# Final estimated_n0	178200
# Log likelihood	-1845.275154
# Observed clones	9564.000000
# Observed clones + estimated clones	187764.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.05227938101212881, 0.05227938101212881]
# iteration 1
# old estimated n0	178200
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.05227938101212881, 0.05227938101212881]
# new estimated n_0	178200
# score_function 0.000000
# Log likelihood	-1845.275154
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.05227938101212881, 0.05227938101212881]
# Final estimated_n0	178200
# Log likelihood	-1845.275154
# Observed clones	9564.000000
# Observed clones + estimated clones	187764.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.05227938101212881, 0.05227938101212881]
# iteration 1
# old estimated n0	178200
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.05227938101212881, 0.05227938101212881]
# new estimated n_0	178200
# score_function 0.000000
# Log likelihood	-1845.275154
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.05227938101212881, 0.05227938101212881]
# Final estimated_n0	178200
# Log likelihood	-1845.275154
# Observed clones	9564.000000
# Observed clones + estimated clones	187764.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.05227938101212881, 0.05227938101212881]
# iteration 1
# old estimated n0	178200
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.05227938101212881, 0.05227938101212881]
# new estimated n_0	178200
# score_function 0.000000
# Log likelihood	-1845.275154
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.05227938101212881, 0.05227938101212881]
# Final estimated_n0	178200
# Log likelihood	-1845.275154
# Observed clones	9564.000000
# Observed clones + estimated clones	187764.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.05227938101212881, 0.05227938101212881]
# iteration 1
# old estimated n0	178200
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.05227938101212881, 0.05227938101212881]
# new estimated n_0	178200
# score_function 0.000000
# Log likelihood	-1845.275154
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.05227938101212881, 0.05227938101212881]
# Final estimated_n0	178200
# Log likelihood	-1845.275154
# Observed clones	9564.000000
# Observed clones + estimated clones	187764.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.05227938101212881, 0.05227938101212881]
# iteration 1
# old estimated n0	178200
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.05227938101212881, 0.05227938101212881]
# new estimated n_0	178200
# score_function 0.000000
# Log likelihood	-1845.275154
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.05227938101212881, 0.05227938101212881]
# Final estimated_n0	178200
# Log likelihood	-1845.275154
# Observed clones	9564.000000
# Observed clones + estimated clones	187764.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143,
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.23525721455457965, 0.05227938101212881]
# Final estimated_n0	61977
# Log likelihood	-1986.479036
# Observed clones	9564.000000
# Observed clones + estimated clones	71541.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.23525721455457965, 0.05227938101212881]
# iteration 1
# old estimated n0	55874
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.23525721455457965, 0.05227938101212881]
# new estimated n_0	55874
# score_function 0.000000
# Log likelihood	-2008.651460
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.23525721455457965, 0.05227938101212881]
# Final estimated_n0	55874
# Log likelihood	-2008.651460
# Observed clones	9564.000000
# Observed clones + estimated clones	65438.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	136498
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.4182350480970305, 0.05227938101212881]
# new estimated n_0	136498
# score_function 0.000000
# Log likelihood	-1863.235877
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.4182350480970305, 0.05227938101212881]
# Final estimated_n0	136498
# Log likelihood	-1863.235877
# Observed clones	9564.000000
# Observed clones + estimated clones	146062.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	98709
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.4182350480970305, 0.05227938101212881]
# new estimated n_0	98709
# score_function 0.000000
# Log likelihood	-2079.338947
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.4182350480970305, 0.05227938101212881]
# Final estimated_n0	98709
# Log likelihood	-2079.338947
# Observed clones	9564.000000
# Observed clones + estimated clones	108273.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	76455
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.4182350480970305, 0.05227938101212881]
# new estimated n_0	76455
# score_function 0.000000
# Log likelihood	-2243.865977
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.4182350480970305, 0.05227938101212881]
# Final estimated_n0	76455
# Log likelihood	-2243.865977
# Observed clones	9564.000000
# Observed clones + estimated clones	86019.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	61789
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.4182350480970305, 0.05227938101212881]
# new estimated n_0	61789
# score_function 0.000000
# Log likelihood	-2363.166661
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.4182350480970305, 0.05227938101212881]
# Final estimated_n0	61789
# Log likelihood	-2363.166661
# Observed clones	9564.000000
# Observed clones + estimated clones	71353.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	51395
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.4182350480970305, 0.05227938101212881]
# new estimated n_0	51395
# score_function 0.000000
# Log likelihood	-2452.264031
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.4182350480970305, 0.05227938101212881]
# Final estimated_n0	51395
# Log likelihood	-2452.264031
# Observed clones	9564.000000
# Observed clones + estimated clones	60959.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	43645
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.4182350480970305, 0.05227938101212881]
# new estimated n_0	43645
# score_function 0.000000
# Log likelihood	-2520.984474
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.4182350480970305, 0.05227938101212881]
# Final estimated_n0	43645
# Log likelihood	-2520.984474
# Observed clones	9564.000000
# Observed clones + estimated clones	53209.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	37643
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.4182350480970305, 0.05227938101212881]
# new estimated n_0	37643
# score_function 0.000000
# Log likelihood	-2575.478475
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.4182350480970305, 0.05227938101212881]
# Final estimated_n0	37643
# Log likelihood	-2575.478475
# Observed clones	9564.000000
# Observed clones + estimated clones	47207.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.4182350480970305, 0.05227938101212881]
# iteration 1
# old estimated n0	32858
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4]
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.08928571499999999, 0.910714285] [0.13069845253032203, 0.05227938101212881]
# new estimated n_0	157267
# score_function 0.000000
# Log likelihood	-1807.659298
#
# Completed iteration of clone sizes
# Fitted weights	[0.08928571499999999, 0.910714285]
# Fitted means	[0.13069845253032203, 0.05227938101212881]
# Final estimated_n0	157267
# Log likelihood	-1807.659298
# Observed clones	9564.000000
# Observed clones + estimated clones	166831.000000
# === END FIT ===
#
# ([1.0], [0.05227938101212881], 178200, {1: 9141, 2: 410, 3: 13}, None, -1845.2751544430394, 2.3973886966705322)

# %% [markdown]
# ### Mixed Poisson 100,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp_100000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 9.1 Verbose = True

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp_100000.tsv...
# 84498 65949.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.07581616097287298]
# iteration 1
# old estimated n0	837296
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.07581616097287298]
# new estimated n_0	837296
# score_function 0.000000
# Log likelihood	-117536.141055
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.07581616097287298]
# Final estimated_n0	837296
# Log likelihood	-117536.141055
# Observed clones	65949.000000
# Observed clones + estimated clones	903245.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.34117272437792845]
# iteration 1
# old estimated n0	162198
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.34117272437792845]
# new estimated n_0	162198
# score_function 0.000000
# Log likelihood	-75374.547091
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.34117272437792845]
# Final estimated_n0	162198
# Log likelihood	-75374.547091
# Observed clones	65949.000000
# Observed clones + estimated clones	228147.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6065292877829839]
# iteration 1
# old estimated n0	79070
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6065292877829839]
# new estimated n_0	79070
# score_function 0.000000
# Log likelihood	-65221.083952
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6065292877829839]
# Final estimated_n0	79070
# Log likelihood	-65221.083952
# Observed clones	65949.000000
# Observed clones + estimated clones	145019.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.1372424145930946]
# iteration 1
# old estimated n0	31135
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.1372424145930946]
# new estimated n_0	31135
# score_function 0.000000
# Log likelihood	-63824.877082
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.1372424145930946]
# Final estimated_n0	31135
# Log likelihood	-63824.877082
# Observed clones	65949.000000
# Observed clones + estimated clones	97084.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.4025989779981503]
# iteration 1
# old estimated n0	21512
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.4025989779981503]
# new estimated n_0	21512
# score_function 0.000000
# Log likelihood	-67237.231366
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.4025989779981503]
# Final estimated_n0	21512
# Log likelihood	-67237.231366
# Observed clones	65949.000000
# Observed clones + estimated clones	87461.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.6679555414032057]
# iteration 1
# old estimated n0	15332
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.6679555414032057]
# new estimated n_0	15332
# score_function 0.000000
# Log likelihood	-72242.259911
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.6679555414032057]
# Final estimated_n0	15332
# Log likelihood	-72242.259911
# Observed clones	65949.000000
# Observed clones + estimated clones	81281.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.4359429255940196]
# iteration 1
# old estimated n0	120693
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.4359429255940196]
# new estimated n_0	120693
# score_function 0.000000
# Log likelihood	-70354.741249
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.4359429255940196]
# Final estimated_n0	120693
# Log likelihood	-70354.741249
# Observed clones	65949.000000
# Observed clones + estimated clones	186642.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.786592670093557]
# iteration 1
# old estimated n0	55146
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.786592670093557]
# new estimated n_0	55146
# score_function 0.000000
# Log likelihood	-62990.475288
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.786592670093557]
# Final estimated_n0	55146
# Log likelihood	-62990.475288
# Observed clones	65949.000000
# Observed clones + estimated clones	121095.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	52580
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	52580
# score_function 0.000000
# Log likelihood	-62697.108076
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	52580
# Log likelihood	-62697.108076
# Observed clones	65949.000000
# Observed clones + estimated clones	118529.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	61756
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	61756
# score_function 0.000000
# Log likelihood	-62727.667071
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	61756
# Log likelihood	-62727.667071
# Observed clones	65949.000000
# Observed clones + estimated clones	127705.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	72472
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	72472
# score_function 0.000000
# Log likelihood	-62769.012457
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	72472
# Log likelihood	-62769.012457
# Observed clones	65949.000000
# Observed clones + estimated clones	138421.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	85151
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	85151
# score_function 0.000000
# Log likelihood	-62825.901569
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	85151
# Log likelihood	-62825.901569
# Observed clones	65949.000000
# Observed clones + estimated clones	151100.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	100387
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	100387
# score_function 0.000000
# Log likelihood	-62905.865271
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	100387
# Log likelihood	-62905.865271
# Observed clones	65949.000000
# Observed clones + estimated clones	166336.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	119041
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	119041
# score_function 0.000000
# Log likelihood	-63021.346891
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	119041
# Log likelihood	-63021.346891
# Observed clones	65949.000000
# Observed clones + estimated clones	184990.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	142406
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	142406
# score_function 0.000000
# Log likelihood	-63194.022037
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	142406
# Log likelihood	-63194.022037
# Observed clones	65949.000000
# Observed clones + estimated clones	208355.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.07581616097287298, 0.8718858511880392]
# iteration 1
# old estimated n0	172527
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.07581616097287298, 0.8718858511880392]
# new estimated n_0	172527
# score_function 0.000000
# Log likelihood	-63464.261378
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.07581616097287298, 0.8718858511880392]
# Final estimated_n0	172527
# Log likelihood	-63464.261378
# Observed clones	65949.000000
# Observed clones + estimated clones	238476.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	50322
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	50322
# score_function 0.000000
# Log likelihood	-62717.871279
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	50322
# Log likelihood	-62717.871279
# Observed clones	65949.000000
# Observed clones + estimated clones	116271.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	55237
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	55237
# score_function 0.000000
# Log likelihood	-62798.488225
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	55237
# Log likelihood	-62798.488225
# Observed clones	65949.000000
# Observed clones + estimated clones	121186.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	60586
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	60586
# score_function 0.000000
# Log likelihood	-62915.537060
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	60586
# Log likelihood	-62915.537060
# Observed clones	65949.000000
# Observed clones + estimated clones	126535.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	66429
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	66429
# score_function 0.000000
# Log likelihood	-63079.622956
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	66429
# Log likelihood	-63079.622956
# Observed clones	65949.000000
# Observed clones + estimated clones	132378.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	72837
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	72837
# score_function 0.000000
# Log likelihood	-63305.094457
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	72837
# Log likelihood	-63305.094457
# Observed clones	65949.000000
# Observed clones + estimated clones	138786.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	79898
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	79898
# score_function 0.000000
# Log likelihood	-63611.761455
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	79898
# Log likelihood	-63611.761455
# Observed clones	65949.000000
# Observed clones + estimated clones	145847.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	87715
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	87715
# score_function 0.000000
# Log likelihood	-64027.660531
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	87715
# Log likelihood	-64027.660531
# Observed clones	65949.000000
# Observed clones + estimated clones	153664.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.34117272437792845, 0.8718858511880392]
# iteration 1
# old estimated n0	96418
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.34117272437792845, 0.8718858511880392]
# new estimated n_0	96418
# score_function 0.000000
# Log likelihood	-64593.732071
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.34117272437792845, 0.8718858511880392]
# Final estimated_n0	96418
# Log likelihood	-64593.732071
# Observed clones	65949.000000
# Observed clones + estimated clones	162367.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	48648
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	48648
# score_function 0.000000
# Log likelihood	-62703.833690
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	48648
# Log likelihood	-62703.833690
# Observed clones	65949.000000
# Observed clones + estimated clones	114597.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	50672
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	50672
# score_function 0.000000
# Log likelihood	-62750.382396
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	50672
# Log likelihood	-62750.382396
# Observed clones	65949.000000
# Observed clones + estimated clones	116621.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	52768
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	52768
# score_function 0.000000
# Log likelihood	-62813.252616
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	52768
# Log likelihood	-62813.252616
# Observed clones	65949.000000
# Observed clones + estimated clones	118717.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	54941
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	54941
# score_function 0.000000
# Log likelihood	-62894.723062
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	54941
# Log likelihood	-62894.723062
# Observed clones	65949.000000
# Observed clones + estimated clones	120890.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	57195
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	57195
# score_function 0.000000
# Log likelihood	-62997.476273
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	57195
# Log likelihood	-62997.476273
# Observed clones	65949.000000
# Observed clones + estimated clones	123144.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	59534
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	59534
# score_function 0.000000
# Log likelihood	-63124.697907
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	59534
# Log likelihood	-63124.697907
# Observed clones	65949.000000
# Observed clones + estimated clones	125483.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	61964
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	61964
# score_function 0.000000
# Log likelihood	-63280.210025
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	61964
# Log likelihood	-63280.210025
# Observed clones	65949.000000
# Observed clones + estimated clones	127913.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.6065292877829839, 0.8718858511880392]
# iteration 1
# old estimated n0	64490
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.6065292877829839, 0.8718858511880392]
# new estimated n_0	64490
# score_function 0.000000
# Log likelihood	-63468.654936
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.6065292877829839, 0.8718858511880392]
# Final estimated_n0	64490
# Log likelihood	-63468.654936
# Observed clones	65949.000000
# Observed clones + estimated clones	130439.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.8718858511880392, 0.8718858511880392]
# iteration 1
# old estimated n0	47397
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.8718858511880392, 0.8718858511880392]
# new estimated n_0	47397
# score_function 0.000000
# Log likelihood	-62681.805618
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.8718858511880392, 0.8718858511880392]
# Final estimated_n0	47397
# Log likelihood	-62681.805618
# Observed clones	65949.000000
# Observed clones + estimated clones	113346.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	46456
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	46456
# score_function 0.000000
# Log likelihood	-62674.808271
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	46456
# Log likelihood	-62674.808271
# Observed clones	65949.000000
# Observed clones + estimated clones	112405.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	45007
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	45007
# score_function 0.000000
# Log likelihood	-62684.790300
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	45007
# Log likelihood	-62684.790300
# Observed clones	65949.000000
# Observed clones + estimated clones	110956.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	43596
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	43596
# score_function 0.000000
# Log likelihood	-62717.203882
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	43596
# Log likelihood	-62717.203882
# Observed clones	65949.000000
# Observed clones + estimated clones	109545.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	42220
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	42220
# score_function 0.000000
# Log likelihood	-62769.067363
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	42220
# Log likelihood	-62769.067363
# Observed clones	65949.000000
# Observed clones + estimated clones	108169.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	40878
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	40878
# score_function 0.000000
# Log likelihood	-62837.943944
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	40878
# Log likelihood	-62837.943944
# Observed clones	65949.000000
# Observed clones + estimated clones	106827.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	39570
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	39570
# score_function 0.000000
# Log likelihood	-62921.805174
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	39570
# Log likelihood	-62921.805174
# Observed clones	65949.000000
# Observed clones + estimated clones	105519.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	38292
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	38292
# score_function 0.000000
# Log likelihood	-63018.938076
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	38292
# Log likelihood	-63018.938076
# Observed clones	65949.000000
# Observed clones + estimated clones	104241.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	37046
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.1372424145930946, 0.8718858511880392]
# new estimated n_0	37046
# score_function 0.000000
# Log likelihood	-63127.879256
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	37046
# Log likelihood	-63127.879256
# Observed clones	65949.000000
# Observed clones + estimated clones	102995.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	45744
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	45744
# score_function 0.000000
# Log likelihood	-62700.454372
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	45744
# Log likelihood	-62700.454372
# Observed clones	65949.000000
# Observed clones + estimated clones	111693.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	43242
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	43242
# score_function 0.000000
# Log likelihood	-62822.094335
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	43242
# Log likelihood	-62822.094335
# Observed clones	65949.000000
# Observed clones + estimated clones	109191.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	40849
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	40849
# score_function 0.000000
# Log likelihood	-63028.638857
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	40849
# Log likelihood	-63028.638857
# Observed clones	65949.000000
# Observed clones + estimated clones	106798.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	38560
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	38560
# score_function 0.000000
# Log likelihood	-63299.606842
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	38560
# Log likelihood	-63299.606842
# Observed clones	65949.000000
# Observed clones + estimated clones	104509.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	36366
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	36366
# score_function 0.000000
# Log likelihood	-63621.153578
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	36366
# Log likelihood	-63621.153578
# Observed clones	65949.000000
# Observed clones + estimated clones	102315.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	34262
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	34262
# score_function 0.000000
# Log likelihood	-63983.305131
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	34262
# Log likelihood	-63983.305131
# Observed clones	65949.000000
# Observed clones + estimated clones	100211.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	32243
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	32243
# score_function 0.000000
# Log likelihood	-64378.572007
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	32243
# Log likelihood	-64378.572007
# Observed clones	65949.000000
# Observed clones + estimated clones	98192.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.4025989779981503, 0.8718858511880392]
# iteration 1
# old estimated n0	30304
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.4025989779981503, 0.8718858511880392]
# new estimated n_0	30304
# score_function 0.000000
# Log likelihood	-64801.161652
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.4025989779981503, 0.8718858511880392]
# Final estimated_n0	30304
# Log likelihood	-64801.161652
# Observed clones	65949.000000
# Observed clones + estimated clones	96253.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	45205
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	45205
# score_function 0.000000
# Log likelihood	-62770.851365
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	45205
# Log likelihood	-62770.851365
# Observed clones	65949.000000
# Observed clones + estimated clones	111154.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	41926
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	41926
# score_function 0.000000
# Log likelihood	-63120.598819
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	41926
# Log likelihood	-63120.598819
# Observed clones	65949.000000
# Observed clones + estimated clones	107875.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	38835
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	38835
# score_function 0.000000
# Log likelihood	-63636.954924
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	38835
# Log likelihood	-63636.954924
# Observed clones	65949.000000
# Observed clones + estimated clones	104784.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	35916
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	35916
# score_function 0.000000
# Log likelihood	-64267.180739
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	35916
# Log likelihood	-64267.180739
# Observed clones	65949.000000
# Observed clones + estimated clones	101865.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	33155
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	33155
# score_function 0.000000
# Log likelihood	-64980.524352
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	33155
# Log likelihood	-64980.524352
# Observed clones	65949.000000
# Observed clones + estimated clones	99104.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	30540
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	30540
# score_function 0.000000
# Log likelihood	-65756.987430
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	30540
# Log likelihood	-65756.987430
# Observed clones	65949.000000
# Observed clones + estimated clones	96489.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	28060
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	28060
# score_function 0.000000
# Log likelihood	-66582.710262
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	28060
# Log likelihood	-66582.710262
# Observed clones	65949.000000
# Observed clones + estimated clones	94009.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.6679555414032057, 0.8718858511880392]
# iteration 1
# old estimated n0	25703
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.6679555414032057, 0.8718858511880392]
# new estimated n_0	25703
# score_function 0.000000
# Log likelihood	-67447.672845
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.6679555414032057, 0.8718858511880392]
# Final estimated_n0	25703
# Log likelihood	-67447.672845
# Observed clones	65949.000000
# Observed clones + estimated clones	91652.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.4359429255940196, 0.8718858511880392]
# iteration 1
# old estimated n0	49667
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.4359429255940196, 0.8718858511880392]
# new estimated n_0	49667
# score_function 0.000000
# Log likelihood	-62715.445562
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.4359429255940196, 0.8718858511880392]
# Final estimated_n0	49667
# Log likelihood	-62715.445562
# Observed clones	65949.000000
# Observed clones + estimated clones	115616.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.325, 0.675, 0.6539143883910294, 0.8718858511880392]
# iteration 1
# old estimated n0	54234
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.325, 0.675] [0.6539143883910294, 0.8718858511880392]
# new estimated n_0	54234
# score_function 0.000000
# Log likelihood	-62883.179305
#
# Completed iteration of clone sizes
# Fitted weights	[0.325, 0.675]
# Fitted means	[0.6539143883910294, 0.8718858511880392]
# Final estimated_n0	54234
# Log likelihood	-62883.179305
# Observed clones	65949.000000
# Observed clones + estimated clones	120183.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.07581616097287298, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	51602
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.07581616097287298, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	51602
# score_function 0.000000
# Log likelihood	-62686.798398
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.07581616097287298, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	51602
# Log likelihood	-62686.798398
# Observed clones	65949.000000
# Observed clones + estimated clones	117551.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 0.07581616097287298, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	60714
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.04357142850000001, 0.8278571415] [0.07581616097287298, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	60714
# score_function 0.000000
# Log likelihood	-62711.500168
#
# Completed iteration of clone sizes
# ...
# iteration 1
# old estimated n0	44875
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	44875
# score_function 0.000000
# Log likelihood	-62714.694960
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	44875
# Log likelihood	-62714.694960
# Observed clones	65949.000000
# Observed clones + estimated clones	110824.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	42480
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.04357142850000001, 0.8278571415] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	42480
# score_function 0.000000
# Log likelihood	-62858.110277
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.04357142850000001, 0.8278571415]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	42480
# Log likelihood	-62858.110277
# Observed clones	65949.000000
# Observed clones + estimated clones	108429.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.039642857000000004, 0.7532142829999999, 1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	40185
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.039642857000000004, 0.7532142829999999] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	40185
# score_function 0.000000
# Log likelihood	-63077.139574
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.039642857000000004, 0.7532142829999999]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	40185
# Log likelihood	-63077.139574
# Observed clones	65949.000000
# Observed clones + estimated clones	106134.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.0357142855, 0.6785714245, 1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	37986
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.0357142855, 0.6785714245] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	37986
# score_function 0.000000
# Log likelihood	-63354.351326
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.0357142855, 0.6785714245]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	37986
# Log likelihood	-63354.351326
# Observed clones	65949.000000
# Observed clones + estimated clones	103935.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.0317857145, 0.6039285755, 1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	35876
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.0317857145, 0.6039285755] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	35876
# score_function 0.000000
# Log likelihood	-63677.710458
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.0317857145, 0.6039285755]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	35876
# Log likelihood	-63677.710458
# Observed clones	65949.000000
# Observed clones + estimated clones	101825.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.027857143, 0.529285717, 1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	33850
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.027857143, 0.529285717] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	33850
# score_function 0.000000
# Log likelihood	-64038.421122
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.027857143, 0.529285717]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	33850
# Log likelihood	-64038.421122
# Observed clones	65949.000000
# Observed clones + estimated clones	99799.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.023928571500000002, 0.4546428585, 1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	31904
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.023928571500000002, 0.4546428585] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	31904
# score_function 0.000000
# Log likelihood	-64429.806537
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.023928571500000002, 0.4546428585]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	31904
# Log likelihood	-64429.806537
# Observed clones	65949.000000
# Observed clones + estimated clones	97853.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.020000000000000004, 0.38, 1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	30031
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.020000000000000004, 0.38] [1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	30031
# score_function 0.000000
# Log likelihood	-64846.657824
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.020000000000000004, 0.38]
# Fitted means	[1.4025989779981503, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	30031
# Log likelihood	-64846.657824
# Observed clones	65949.000000
# Observed clones + estimated clones	95980.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	44344
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	44344
# score_function 0.000000
# Log likelihood	-62795.382593
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	44344
# Log likelihood	-62795.382593
# Observed clones	65949.000000
# Observed clones + estimated clones	110293.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	41181
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.04357142850000001, 0.8278571415] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	41181
# score_function 0.000000
# Log likelihood	-63172.564633
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.04357142850000001, 0.8278571415]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	41181
# Log likelihood	-63172.564633
# Observed clones	65949.000000
# Observed clones + estimated clones	107130.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.039642857000000004, 0.7532142829999999, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	38195
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.039642857000000004, 0.7532142829999999] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	38195
# score_function 0.000000
# Log likelihood	-63702.154019
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.039642857000000004, 0.7532142829999999]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	38195
# Log likelihood	-63702.154019
# Observed clones	65949.000000
# Observed clones + estimated clones	104144.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.0357142855, 0.6785714245, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	35371
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.0357142855, 0.6785714245] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	35371
# score_function 0.000000
# Log likelihood	-64337.408840
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.0357142855, 0.6785714245]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	35371
# Log likelihood	-64337.408840
# Observed clones	65949.000000
# Observed clones + estimated clones	101320.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.0317857145, 0.6039285755, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	32696
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.0317857145, 0.6039285755] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	32696
# score_function 0.000000
# Log likelihood	-65050.551839
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.0317857145, 0.6039285755]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	32696
# Log likelihood	-65050.551839
# Observed clones	65949.000000
# Observed clones + estimated clones	98645.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.027857143, 0.529285717, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	30158
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.027857143, 0.529285717] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	30158
# score_function 0.000000
# Log likelihood	-65823.304977
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.027857143, 0.529285717]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	30158
# Log likelihood	-65823.304977
# Observed clones	65949.000000
# Observed clones + estimated clones	96107.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.023928571500000002, 0.4546428585, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	27748
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.023928571500000002, 0.4546428585] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	27748
# score_function 0.000000
# Log likelihood	-66642.892870
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.023928571500000002, 0.4546428585]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	27748
# Log likelihood	-66642.892870
# Observed clones	65949.000000
# Observed clones + estimated clones	93697.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.020000000000000004, 0.38, 1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	25456
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.020000000000000004, 0.38] [1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	25456
# score_function 0.000000
# Log likelihood	-67500.018356
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.020000000000000004, 0.38]
# Fitted means	[1.6679555414032057, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	25456
# Log likelihood	-67500.018356
# Observed clones	65949.000000
# Observed clones + estimated clones	91405.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.4359429255940196, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	48736
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.4359429255940196, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	48736
# score_function 0.000000
# Log likelihood	-62699.564808
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.4359429255940196, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	48736
# Log likelihood	-62699.564808
# Observed clones	65949.000000
# Observed clones + estimated clones	114685.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.08928571499999999, 0.04553571425, 0.8651785707499999, 0.6539143883910294, 1.1372424145930946, 0.8718858511880392]
# iteration 1
# old estimated n0	48311
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.089285715, 0.045535714250000005, 0.86517857075] [0.6539143883910294, 1.1372424145930946, 0.8718858511880392]
# new estimated n_0	48311
# score_function 0.000000
# Log likelihood	-62699.295845
#
# Completed iteration of clone sizes
# Fitted weights	[0.089285715, 0.045535714250000005, 0.86517857075]
# Fitted means	[0.6539143883910294, 1.1372424145930946, 0.8718858511880392]
# Final estimated_n0	48311
# Log likelihood	-62699.295845
# Observed clones	65949.000000
# Observed clones + estimated clones	114260.000000
# === END FIT ===
#
# ([0.05, 0.95], [1.1372424145930946, 0.8718858511880392], 46456, {1: 39731, 2: 19671, 3: 5427, 4: 966, 5: 143, 6: 10, 7: 1}, None, -62674.80827098018, 2.9191572666168213)

# %% [markdown]
# ### Mixed Poisson 300,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp_300000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

# %%
# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %% [markdown]
# #### 10.1 Verbose = True

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp_300000.tsv...
# 103164 98289.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.15261117724262127]
# iteration 1
# old estimated n0	596154
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.15261117724262127]
# new estimated n_0	596154
# score_function 0.000000
# Log likelihood	-592619.785913
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.15261117724262127]
# Final estimated_n0	596154
# Log likelihood	-592619.785913
# Observed clones	98289.000000
# Observed clones + estimated clones	694443.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6867502975917956]
# iteration 1
# old estimated n0	99559
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6867502975917956]
# new estimated n_0	99559
# score_function 0.000000
# Log likelihood	-317309.417039
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6867502975917956]
# Final estimated_n0	99559
# Log likelihood	-317309.417039
# Observed clones	98289.000000
# Observed clones + estimated clones	197848.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.2208894179409702]
# iteration 1
# old estimated n0	41122
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.2208894179409702]
# new estimated n_0	41122
# score_function 0.000000
# Log likelihood	-231608.556133
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.2208894179409702]
# Final estimated_n0	41122
# Log likelihood	-231608.556133
# Observed clones	98289.000000
# Observed clones + estimated clones	139411.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.7550285382901443]
# iteration 1
# old estimated n0	20547
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.7550285382901443]
# new estimated n_0	20547
# score_function 0.000000
# Log likelihood	-190931.616908
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.7550285382901443]
# Final estimated_n0	20547
# Log likelihood	-190931.616908
# Observed clones	98289.000000
# Observed clones + estimated clones	118836.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.289167658639319]
# iteration 1
# old estimated n0	11085
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.289167658639319]
# new estimated n_0	11085
# score_function 0.000000
# Log likelihood	-171875.700316
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.289167658639319]
# Final estimated_n0	11085
# Log likelihood	-171875.700316
# Observed clones	98289.000000
# Observed clones + estimated clones	109374.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 3.3574458993376677]
# iteration 1
# old estimated n0	3546
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [3.3574458993376677]
# new estimated n_0	3546
# score_function 0.000000
# Log likelihood	-168997.590282
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[3.3574458993376677]
# Final estimated_n0	3546
# Log likelihood	-168997.590282
# Observed clones	98289.000000
# Observed clones + estimated clones	101835.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.4116533894942467]
# iteration 1
# old estimated n0	31678
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.4116533894942467]
# new estimated n_0	31678
# score_function 0.000000
# Log likelihood	-213698.108614
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.4116533894942467]
# Final estimated_n0	31678
# Log likelihood	-213698.108614
# Observed clones	98289.000000
# Observed clones + estimated clones	129967.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.3845496444159573]
# iteration 1
# old estimated n0	9974
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.3845496444159573]
# new estimated n_0	9974
# score_function 0.000000
# Log likelihood	-170007.428656
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.3845496444159573]
# Final estimated_n0	9974
# Log likelihood	-170007.428656
# Observed clones	98289.000000
# Observed clones + estimated clones	108263.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	10844
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	10844
# score_function 0.000000
# Log likelihood	-166233.585627
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	10844
# Log likelihood	-166233.585627
# Observed clones	98289.000000
# Observed clones + estimated clones	109133.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	19021
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	19021
# score_function 0.000000
# Log likelihood	-166783.385789
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	19021
# Log likelihood	-166783.385789
# Observed clones	98289.000000
# Observed clones + estimated clones	117310.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	28524
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	28524
# score_function 0.000000
# Log likelihood	-167478.552485
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	28524
# Log likelihood	-167478.552485
# Observed clones	98289.000000
# Observed clones + estimated clones	126813.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	39701
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	39701
# score_function 0.000000
# Log likelihood	-168368.694858
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	39701
# Log likelihood	-168368.694858
# Observed clones	98289.000000
# Observed clones + estimated clones	137990.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	53040
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	53040
# score_function 0.000000
# Log likelihood	-169526.782632
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	53040
# Log likelihood	-169526.782632
# Observed clones	98289.000000
# Observed clones + estimated clones	151329.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	69233
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	69233
# score_function 0.000000
# Log likelihood	-171064.220214
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	69233
# Log likelihood	-171064.220214
# Observed clones	98289.000000
# Observed clones + estimated clones	167522.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	89307
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	89307
# score_function 0.000000
# Log likelihood	-173159.145879
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	89307
# Log likelihood	-173159.145879
# Observed clones	98289.000000
# Observed clones + estimated clones	187596.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.15261117724262127, 2.8233067789884934]
# iteration 1
# old estimated n0	114846
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.15261117724262127, 2.8233067789884934]
# new estimated n_0	114846
# score_function 0.000000
# Log likelihood	-176113.778335
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.15261117724262127, 2.8233067789884934]
# Final estimated_n0	114846
# Log likelihood	-176113.778335
# Observed clones	98289.000000
# Observed clones + estimated clones	213135.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	8733
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	8733
# score_function 0.000000
# Log likelihood	-166675.984659
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	8733
# Log likelihood	-166675.984659
# Observed clones	98289.000000
# Observed clones + estimated clones	107022.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	12957
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	12957
# score_function 0.000000
# Log likelihood	-168107.682828
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	12957
# Log likelihood	-168107.682828
# Observed clones	98289.000000
# Observed clones + estimated clones	111246.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	17528
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	17528
# score_function 0.000000
# Log likelihood	-169925.001788
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	17528
# Log likelihood	-169925.001788
# Observed clones	98289.000000
# Observed clones + estimated clones	115817.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	22490
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	22490
# score_function 0.000000
# Log likelihood	-172195.809474
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	22490
# Log likelihood	-172195.809474
# Observed clones	98289.000000
# Observed clones + estimated clones	120779.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	27897
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	27897
# score_function 0.000000
# Log likelihood	-175015.377968
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	27897
# Log likelihood	-175015.377968
# Observed clones	98289.000000
# Observed clones + estimated clones	126186.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	33811
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	33811
# score_function 0.000000
# Log likelihood	-178519.014561
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	33811
# Log likelihood	-178519.014561
# Observed clones	98289.000000
# Observed clones + estimated clones	132100.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	40306
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	40306
# score_function 0.000000
# Log likelihood	-182903.903637
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	40306
# Log likelihood	-182903.903637
# Observed clones	98289.000000
# Observed clones + estimated clones	138595.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.6867502975917956, 2.8233067789884934]
# iteration 1
# old estimated n0	47473
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.6867502975917956, 2.8233067789884934]
# new estimated n_0	47473
# score_function 0.000000
# Log likelihood	-188469.155080
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.6867502975917956, 2.8233067789884934]
# Final estimated_n0	47473
# Log likelihood	-188469.155080
# Observed clones	98289.000000
# Observed clones + estimated clones	145762.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	7533
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	7533
# score_function 0.000000
# Log likelihood	-166581.455864
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	7533
# Log likelihood	-166581.455864
# Observed clones	98289.000000
# Observed clones + estimated clones	105822.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	9685
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	9685
# score_function 0.000000
# Log likelihood	-167815.110037
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	9685
# Log likelihood	-167815.110037
# Observed clones	98289.000000
# Observed clones + estimated clones	107974.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	11926
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	11926
# score_function 0.000000
# Log likelihood	-169350.412556
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	11926
# Log likelihood	-169350.412556
# Observed clones	98289.000000
# Observed clones + estimated clones	110215.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	14261
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	14261
# score_function 0.000000
# Log likelihood	-171220.242812
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	14261
# Log likelihood	-171220.242812
# Observed clones	98289.000000
# Observed clones + estimated clones	112550.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	16698
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	16698
# score_function 0.000000
# Log likelihood	-173471.050087
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	16698
# Log likelihood	-173471.050087
# Observed clones	98289.000000
# Observed clones + estimated clones	114987.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	19243
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	19243
# score_function 0.000000
# Log likelihood	-176167.330544
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	19243
# Log likelihood	-176167.330544
# Observed clones	98289.000000
# Observed clones + estimated clones	117532.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	21903
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	21903
# score_function 0.000000
# Log likelihood	-179399.214308
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	21903
# Log likelihood	-179399.214308
# Observed clones	98289.000000
# Observed clones + estimated clones	120192.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.2208894179409702, 2.8233067789884934]
# iteration 1
# old estimated n0	24687
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.2208894179409702, 2.8233067789884934]
# new estimated n_0	24687
# score_function 0.000000
# Log likelihood	-183295.687574
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.2208894179409702, 2.8233067789884934]
# Final estimated_n0	24687
# Log likelihood	-183295.687574
# Observed clones	98289.000000
# Observed clones + estimated clones	122976.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	6842
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	6842
# score_function 0.000000
# Log likelihood	-166310.424629
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	6842
# Log likelihood	-166310.424629
# Observed clones	98289.000000
# Observed clones + estimated clones	105131.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	7855
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	7855
# score_function 0.000000
# Log likelihood	-167005.919408
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	7855
# Log likelihood	-167005.919408
# Observed clones	98289.000000
# Observed clones + estimated clones	106144.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	8887
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	8887
# score_function 0.000000
# Log likelihood	-167852.715061
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	8887
# Log likelihood	-167852.715061
# Observed clones	98289.000000
# Observed clones + estimated clones	107176.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	9939
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	9939
# score_function 0.000000
# Log likelihood	-168861.420176
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	9939
# Log likelihood	-168861.420176
# Observed clones	98289.000000
# Observed clones + estimated clones	108228.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	11012
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	11012
# score_function 0.000000
# Log likelihood	-170046.244882
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	11012
# Log likelihood	-170046.244882
# Observed clones	98289.000000
# Observed clones + estimated clones	109301.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	12107
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	12107
# score_function 0.000000
# Log likelihood	-171425.880559
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	12107
# Log likelihood	-171425.880559
# Observed clones	98289.000000
# Observed clones + estimated clones	110396.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	13224
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	13224
# score_function 0.000000
# Log likelihood	-173024.868966
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	13224
# Log likelihood	-173024.868966
# Observed clones	98289.000000
# Observed clones + estimated clones	111513.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.7550285382901443, 2.8233067789884934]
# iteration 1
# old estimated n0	14364
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.7550285382901443, 2.8233067789884934]
# new estimated n_0	14364
# score_function 0.000000
# Log likelihood	-174875.768029
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.7550285382901443, 2.8233067789884934]
# Final estimated_n0	14364
# Log likelihood	-174875.768029
# Observed clones	98289.000000
# Observed clones + estimated clones	112653.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	6442
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	6442
# score_function 0.000000
# Log likelihood	-166065.574967
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	6442
# Log likelihood	-166065.574967
# Observed clones	98289.000000
# Observed clones + estimated clones	104731.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	6811
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	6811
# score_function 0.000000
# Log likelihood	-166288.970699
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	6811
# Log likelihood	-166288.970699
# Observed clones	98289.000000
# Observed clones + estimated clones	105100.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	7182
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	7182
# score_function 0.000000
# Log likelihood	-166551.110963
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	7182
# Log likelihood	-166551.110963
# Observed clones	98289.000000
# Observed clones + estimated clones	105471.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	7557
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	7557
# score_function 0.000000
# Log likelihood	-166853.415590
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	7557
# Log likelihood	-166853.415590
# Observed clones	98289.000000
# Observed clones + estimated clones	105846.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	7934
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	7934
# score_function 0.000000
# Log likelihood	-167197.578333
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	7934
# Log likelihood	-167197.578333
# Observed clones	98289.000000
# Observed clones + estimated clones	106223.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	8313
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	8313
# score_function 0.000000
# Log likelihood	-167585.606848
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	8313
# Log likelihood	-167585.606848
# Observed clones	98289.000000
# Observed clones + estimated clones	106602.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	8696
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	8696
# score_function 0.000000
# Log likelihood	-168019.874614
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	8696
# Log likelihood	-168019.874614
# Observed clones	98289.000000
# Observed clones + estimated clones	106985.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 2.289167658639319, 2.8233067789884934]
# iteration 1
# old estimated n0	9081
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [2.289167658639319, 2.8233067789884934]
# new estimated n_0	9081
# score_function 0.000000
# Log likelihood	-168503.190030
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[2.289167658639319, 2.8233067789884934]
# Final estimated_n0	9081
# Log likelihood	-168503.190030
# Observed clones	98289.000000
# Observed clones + estimated clones	107370.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 2.8233067789884934, 2.8233067789884934]
# iteration 1
# old estimated n0	6208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [2.8233067789884934, 2.8233067789884934]
# new estimated n_0	6208
# score_function 0.000000
# Log likelihood	-165943.039236
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[2.8233067789884934, 2.8233067789884934]
# Final estimated_n0	6208
# Log likelihood	-165943.039236
# Observed clones	98289.000000
# Observed clones + estimated clones	104497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	6072
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	6072
# score_function 0.000000
# Log likelihood	-165974.406125
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	6072
# Log likelihood	-165974.406125
# Observed clones	98289.000000
# Observed clones + estimated clones	104361.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	5858
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	5858
# score_function 0.000000
# Log likelihood	-166052.426894
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	5858
# Log likelihood	-166052.426894
# Observed clones	98289.000000
# Observed clones + estimated clones	104147.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	5645
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	5645
# score_function 0.000000
# Log likelihood	-166164.158284
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	5645
# Log likelihood	-166164.158284
# Observed clones	98289.000000
# Observed clones + estimated clones	103934.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	5433
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	5433
# score_function 0.000000
# Log likelihood	-166308.301805
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	5433
# Log likelihood	-166308.301805
# Observed clones	98289.000000
# Observed clones + estimated clones	103722.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	5222
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	5222
# score_function 0.000000
# Log likelihood	-166483.830523
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	5222
# Log likelihood	-166483.830523
# Observed clones	98289.000000
# Observed clones + estimated clones	103511.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	5012
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	5012
# score_function 0.000000
# Log likelihood	-166689.944966
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	5012
# Log likelihood	-166689.944966
# Observed clones	98289.000000
# Observed clones + estimated clones	103301.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	4803
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	4803
# score_function 0.000000
# Log likelihood	-166926.041510
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	4803
# Log likelihood	-166926.041510
# Observed clones	98289.000000
# Observed clones + estimated clones	103092.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 3.3574458993376677, 2.8233067789884934]
# iteration 1
# old estimated n0	4595
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [3.3574458993376677, 2.8233067789884934]
# new estimated n_0	4595
# score_function 0.000000
# Log likelihood	-167191.689860
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[3.3574458993376677, 2.8233067789884934]
# Final estimated_n0	4595
# Log likelihood	-167191.689860
# Observed clones	98289.000000
# Observed clones + estimated clones	102884.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.4116533894942467, 2.8233067789884934]
# iteration 1
# old estimated n0	14242
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.4116533894942467, 2.8233067789884934]
# new estimated n_0	14242
# score_function 0.000000
# Log likelihood	-172295.240264
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.4116533894942467, 2.8233067789884934]
# Final estimated_n0	14242
# Log likelihood	-172295.240264
# Observed clones	98289.000000
# Observed clones + estimated clones	112531.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.207142855, 0.7928571449999999, 2.11748008424137, 2.8233067789884934]
# iteration 1
# old estimated n0	7629
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714285500000001, 0.792857145] [2.11748008424137, 2.8233067789884934]
# new estimated n_0	7629
# score_function 0.000000
# Log likelihood	-166908.584455
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714285500000001, 0.792857145]
# Fitted means	[2.11748008424137, 2.8233067789884934]
# Final estimated_n0	7629
# Log likelihood	-166908.584455
# Observed clones	98289.000000
# Observed clones + estimated clones	105918.000000
# === END FIT ===
#
# ([1.0], [2.8233067789884934], 6208, {3: 29221, 2: 25039, 4: 20460, 1: 10564, 5: 9203, 6: 2947, 7: 704, 8: 131, 9: 18, 10: 2}, None, -165943.03923594975, 0.9837958812713623)

# %% [markdown]
# ## Uniform Distribution 2

# %% [markdown]
# ### Uniform 10,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_10_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_unif1_10_000.tsv...
# 15638 9927.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.05036768409388537]
# iteration 1
# old estimated n0	192169
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.05036768409388537]
# new estimated n_0	192169
# score_function 0.000000
# Log likelihood	-519.802650
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.05036768409388537]
# Final estimated_n0	192169
# Log likelihood	-519.802650
# Observed clones	9927.000000
# Observed clones + estimated clones	202096.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.22665457842248415]
# iteration 1
# old estimated n0	39022
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.22665457842248415]
# new estimated n_0	39022
# score_function 0.000000
# Log likelihood	-1305.195473
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.22665457842248415]
# Final estimated_n0	39022
# Log likelihood	-1305.195473
# Observed clones	9927.000000
# Observed clones + estimated clones	48949.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.40294147275108294]
# iteration 1
# old estimated n0	20005
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.40294147275108294]
# new estimated n_0	20005
# score_function 0.000000
# Log likelihood	-2184.020394
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.40294147275108294]
# Final estimated_n0	20005
# Log likelihood	-2184.020394
# Observed clones	9927.000000
# Observed clones + estimated clones	29932.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.5792283670796817]
# iteration 1
# old estimated n0	12651
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.5792283670796817]
# new estimated n_0	12651
# score_function 0.000000
# Log likelihood	-3103.849534
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.5792283670796817]
# Final estimated_n0	12651
# Log likelihood	-3103.849534
# Observed clones	9927.000000
# Observed clones + estimated clones	22578.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7555152614082805]
# iteration 1
# old estimated n0	8795
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7555152614082805]
# new estimated n_0	8795
# score_function 0.000000
# Log likelihood	-4056.051219
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7555152614082805]
# Final estimated_n0	8795
# Log likelihood	-4056.051219
# Observed clones	9927.000000
# Observed clones + estimated clones	18722.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.9318021557368793]
# iteration 1
# old estimated n0	6450
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.9318021557368793]
# new estimated n_0	6450
# score_function 0.000000
# Log likelihood	-5037.324916
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.9318021557368793]
# Final estimated_n0	6450
# Log likelihood	-5037.324916
# Observed clones	9927.000000
# Observed clones + estimated clones	16377.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.108089050065478]
# iteration 1
# old estimated n0	4894
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.108089050065478]
# new estimated n_0	4894
# score_function 0.000000
# Log likelihood	-6045.883743
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.108089050065478]
# Final estimated_n0	4894
# Log likelihood	-6045.883743
# Observed clones	9927.000000
# Observed clones + estimated clones	14821.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.025183842046942684]
# iteration 1
# old estimated n0	389239
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.025183842046942684]
# new estimated n_0	389239
# score_function 0.000000
# Log likelihood	-444.615420
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.025183842046942684]
# Final estimated_n0	389239
# Log likelihood	-444.615420
# Observed clones	9927.000000
# Observed clones + estimated clones	399166.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.025183842046942684]
# iteration 1
# old estimated n0	389239
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.025183842046942684]
# new estimated n_0	389239
# score_function 0.000000
# Log likelihood	-444.615420
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.025183842046942684]
# Final estimated_n0	389239
# Log likelihood	-444.615420
# Observed clones	9927.000000
# Observed clones + estimated clones	399166.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	370681
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	370681
# score_function 0.000000
# Log likelihood	-449.894822
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	370681
# Log likelihood	-449.894822
# Observed clones	9927.000000
# Observed clones + estimated clones	380608.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	344769
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	344769
# score_function 0.000000
# Log likelihood	-458.138726
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	344769
# Log likelihood	-458.138726
# Observed clones	9927.000000
# Observed clones + estimated clones	354696.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	322160
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	322160
# score_function 0.000000
# Log likelihood	-466.021338
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	322160
# Log likelihood	-466.021338
# Observed clones	9927.000000
# Observed clones + estimated clones	332087.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	302260
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	302260
# score_function 0.000000
# Log likelihood	-473.406570
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	302260
# Log likelihood	-473.406570
# Observed clones	9927.000000
# Observed clones + estimated clones	312187.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	284611
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	284611
# score_function 0.000000
# Log likelihood	-480.261701
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	284611
# Log likelihood	-480.261701
# Observed clones	9927.000000
# Observed clones + estimated clones	294538.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	268850
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	268850
# score_function 0.000000
# Log likelihood	-486.599288
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	268850
# Log likelihood	-486.599288
# Observed clones	9927.000000
# Observed clones + estimated clones	278777.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	254691
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	254691
# score_function 0.000000
# Log likelihood	-492.451021
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	254691
# Log likelihood	-492.451021
# Observed clones	9927.000000
# Observed clones + estimated clones	264618.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.05036768409388537, 0.025183842046942684]
# iteration 1
# old estimated n0	241900
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.05036768409388537, 0.025183842046942684]
# new estimated n_0	241900
# score_function 0.000000
# Log likelihood	-497.855472
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.05036768409388537, 0.025183842046942684]
# Final estimated_n0	241900
# Log likelihood	-497.855472
# Observed clones	9927.000000
# Observed clones + estimated clones	251827.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.22665457842248415, 0.025183842046942684]
# iteration 1
# old estimated n0	284066
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.22665457842248415, 0.025183842046942684]
# new estimated n_0	284066
# score_function 0.000000
# Log likelihood	-654.680078
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.22665457842248415, 0.025183842046942684]
# Final estimated_n0	284066
# Log likelihood	-654.680078
# Observed clones	9927.000000
# Observed clones + estimated clones	293993.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.22665457842248415, 0.025183842046942684]
# iteration 1
# old estimated n0	197983
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.22665457842248415, 0.025183842046942684]
# new estimated n_0	197983
# score_function 0.000000
# Log likelihood	-869.282020
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.22665457842248415, 0.025183842046942684]
# Final estimated_n0	197983
# Log likelihood	-869.282020
# Observed clones	9927.000000
# Observed clones + estimated clones	207910.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714,
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.108089050065478, 0.025183842046942684]
# new estimated n_0	22045
# score_function 0.000000
# Log likelihood	-5700.131204
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.108089050065478, 0.025183842046942684]
# Final estimated_n0	22045
# Log likelihood	-5700.131204
# Observed clones	9927.000000
# Observed clones + estimated clones	31972.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.108089050065478, 0.025183842046942684]
# iteration 1
# old estimated n0	17559
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.108089050065478, 0.025183842046942684]
# new estimated n_0	17559
# score_function 0.000000
# Log likelihood	-5789.361726
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.108089050065478, 0.025183842046942684]
# Final estimated_n0	17559
# Log likelihood	-5789.361726
# Observed clones	9927.000000
# Observed clones + estimated clones	27486.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.108089050065478, 0.025183842046942684]
# iteration 1
# old estimated n0	14177
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.108089050065478, 0.025183842046942684]
# new estimated n_0	14177
# score_function 0.000000
# Log likelihood	-5857.188657
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.108089050065478, 0.025183842046942684]
# Final estimated_n0	14177
# Log likelihood	-5857.188657
# Observed clones	9927.000000
# Observed clones + estimated clones	24104.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.012591921023471342, 0.025183842046942684]
# iteration 1
# old estimated n0	399408
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.012591921023471342, 0.025183842046942684]
# new estimated n_0	399408
# score_function 0.000000
# Log likelihood	-443.946616
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.012591921023471342, 0.025183842046942684]
# Final estimated_n0	399408
# Log likelihood	-443.946616
# Observed clones	9927.000000
# Observed clones + estimated clones	409335.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.012591921023471342, 0.025183842046942684]
# iteration 1
# old estimated n0	399408
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.012591921023471342, 0.025183842046942684]
# new estimated n_0	399408
# score_function 0.000000
# Log likelihood	-443.946616
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.012591921023471342, 0.025183842046942684]
# Final estimated_n0	399408
# Log likelihood	-443.946616
# Observed clones	9927.000000
# Observed clones + estimated clones	409335.000000
# === END FIT ===
#
# ([1.0], [0.025183842046942684], 389239, {1: 9854, 2: 73}, None, -444.61542002952046, 2.2379250526428223)

# %% [markdown]
# ### Uniform 100,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_100_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_unif1_100_000.tsv...
# 142981 93765.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.053324801365114916]
# iteration 1
# old estimated n0	1711909
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.053324801365114916]
# new estimated n_0	1711909
# score_function 0.000000
# Log likelihood	-25238.953009
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.053324801365114916]
# Final estimated_n0	1711909
# Log likelihood	-25238.953009
# Observed clones	93765.000000
# Observed clones + estimated clones	1805674.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.23996160614301712]
# iteration 1
# old estimated n0	345741
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.23996160614301712]
# new estimated n_0	345741
# score_function 0.000000
# Log likelihood	-24824.777526
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.23996160614301712]
# Final estimated_n0	345741
# Log likelihood	-24824.777526
# Observed clones	93765.000000
# Observed clones + estimated clones	439506.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.4265984109209193]
# iteration 1
# old estimated n0	176238
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.4265984109209193]
# new estimated n_0	176238
# score_function 0.000000
# Log likelihood	-30472.448118
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.4265984109209193]
# Final estimated_n0	176238
# Log likelihood	-30472.448118
# Observed clones	93765.000000
# Observed clones + estimated clones	270003.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6132352156988214]
# iteration 1
# old estimated n0	110782
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6132352156988214]
# new estimated n_0	110782
# score_function 0.000000
# Log likelihood	-37714.442609
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6132352156988214]
# Final estimated_n0	110782
# Log likelihood	-37714.442609
# Observed clones	93765.000000
# Observed clones + estimated clones	204547.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7998720204767238]
# iteration 1
# old estimated n0	76527
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7998720204767238]
# new estimated n_0	76527
# score_function 0.000000
# Log likelihood	-45829.557802
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7998720204767238]
# Final estimated_n0	76527
# Log likelihood	-45829.557802
# Observed clones	93765.000000
# Observed clones + estimated clones	170292.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.986508825254626]
# iteration 1
# old estimated n0	55751
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.986508825254626]
# new estimated n_0	55751
# score_function 0.000000
# Log likelihood	-54557.345083
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.986508825254626]
# Final estimated_n0	55751
# Log likelihood	-54557.345083
# Observed clones	93765.000000
# Observed clones + estimated clones	149516.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.1731456300325283]
# iteration 1
# old estimated n0	42007
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.1731456300325283]
# new estimated n_0	42007
# score_function 0.000000
# Log likelihood	-63771.757601
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.1731456300325283]
# Final estimated_n0	42007
# Log likelihood	-63771.757601
# Observed clones	93765.000000
# Observed clones + estimated clones	135772.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.11998080307150856]
# iteration 1
# old estimated n0	735555
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.11998080307150856]
# new estimated n_0	735555
# score_function 0.000000
# Log likelihood	-23352.928297
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.11998080307150856]
# Final estimated_n0	735555
# Log likelihood	-23352.928297
# Observed clones	93765.000000
# Observed clones + estimated clones	829320.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.11998080307150856]
# iteration 1
# old estimated n0	735555
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.11998080307150856]
# new estimated n_0	735555
# score_function 0.000000
# Log likelihood	-23352.928297
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.11998080307150856]
# Final estimated_n0	735555
# Log likelihood	-23352.928297
# Observed clones	93765.000000
# Observed clones + estimated clones	829320.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	758599
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	758599
# score_function 0.000000
# Log likelihood	-23359.571080
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	758599
# Log likelihood	-23359.571080
# Observed clones	93765.000000
# Observed clones + estimated clones	852364.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	797517
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	797517
# score_function 0.000000
# Log likelihood	-23373.317585
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	797517
# Log likelihood	-23373.317585
# Observed clones	93765.000000
# Observed clones + estimated clones	891282.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	840159
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	840159
# score_function 0.000000
# Log likelihood	-23392.172509
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	840159
# Log likelihood	-23392.172509
# Observed clones	93765.000000
# Observed clones + estimated clones	933924.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	887086
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	887086
# score_function 0.000000
# Log likelihood	-23417.741008
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	887086
# Log likelihood	-23417.741008
# Observed clones	93765.000000
# Observed clones + estimated clones	980851.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	938979
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	938979
# score_function 0.000000
# Log likelihood	-23452.237665
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	938979
# Log likelihood	-23452.237665
# Observed clones	93765.000000
# Observed clones + estimated clones	1032744.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	996670
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	996670
# score_function 0.000000
# Log likelihood	-23498.777664
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	996670
# Log likelihood	-23498.777664
# Observed clones	93765.000000
# Observed clones + estimated clones	1090435.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	1061186
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	1061186
# score_function 0.000000
# Log likelihood	-23561.844449
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	1061186
# Log likelihood	-23561.844449
# Observed clones	93765.000000
# Observed clones + estimated clones	1154951.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.053324801365114916, 0.11998080307150856]
# iteration 1
# old estimated n0	1133818
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.053324801365114916, 0.11998080307150856]
# new estimated n_0	1133818
# score_function 0.000000
# Log likelihood	-23648.070555
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.053324801365114916, 0.11998080307150856]
# Final estimated_n0	1133818
# Log likelihood	-23648.070555
# Observed clones	93765.000000
# Observed clones + estimated clones	1227583.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	700339
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	700339
# score_function 0.000000
# Log likelihood	-23329.757552
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	700339
# Log likelihood	-23329.757552
# Observed clones	93765.000000
# Observed clones + estimated clones	794104.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	650664
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	650664
# score_function 0.000000
# Log likelihood	-23374.533327
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	650664
# Log likelihood	-23374.533327
# Observed clones	93765.000000
# Observed clones + estimated clones	744429.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	606838
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	606838
# score_function 0.000000
# Log likelihood	-23473.507393
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	606838
# Log likelihood	-23473.507393
# Observed clones	93765.000000
# Observed clones + estimated clones	700603.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	567885
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	567885
# score_function 0.000000
# Log likelihood	-23599.995425
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	567885
# Log likelihood	-23599.995425
# Observed clones	93765.000000
# Observed clones + estimated clones	661650.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	533036
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	533036
# score_function 0.000000
# Log likelihood	-23739.713914
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	533036
# Log likelihood	-23739.713914
# Observed clones	93765.000000
# Observed clones + estimated clones	626801.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	501674
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	501674
# score_function 0.000000
# Log likelihood	-23884.555079
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	501674
# Log likelihood	-23884.555079
# Observed clones	93765.000000
# Observed clones + estimated clones	595439.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	473301
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	473301
# score_function 0.000000
# Log likelihood	-24029.784784
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	473301
# Log likelihood	-24029.784784
# Observed clones	93765.000000
# Observed clones + estimated clones	567066.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	447509
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.23996160614301712, 0.11998080307150856]
# new estimated n_0	447509
# score_function 0.000000
# Log likelihood	-24172.617711
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	447509
# Log likelihood	-24172.617711
# Observed clones	93765.000000
# Observed clones + estimated clones	541274.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	657719
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	657719
# score_function 0.000000
# Log likelihood	-23514.915776
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	657719
# Log likelihood	-23514.915776
# Observed clones	93765.000000
# Observed clones + estimated clones	751484.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	561131
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	561131
# score_function 0.000000
# Log likelihood	-24317.617661
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	561131
# Log likelihood	-24317.617661
# Observed clones	93765.000000
# Observed clones + estimated clones	654896.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	486544
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	486544
# score_function 0.000000
# Log likelihood	-25208.976364
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	486544
# Log likelihood	-25208.976364
# Observed clones	93765.000000
# Observed clones + estimated clones	580309.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	427209
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	427209
# score_function 0.000000
# Log likelihood	-26043.028872
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	427209
# Log likelihood	-26043.028872
# Observed clones	93765.000000
# Observed clones + estimated clones	520974.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	378882
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	378882
# score_function 0.000000
# Log likelihood	-26790.969445
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	378882
# Log likelihood	-26790.969445
# Observed clones	93765.000000
# Observed clones + estimated clones	472647.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	338760
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	338760
# score_function 0.000000
# Log likelihood	-27453.641032
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	338760
# Log likelihood	-27453.641032
# Observed clones	93765.000000
# Observed clones + estimated clones	432525.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	304917
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	304917
# score_function 0.000000
# Log likelihood	-28039.756885
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	304917
# Log likelihood	-28039.756885
# Observed clones	93765.000000
# Observed clones + estimated clones	398682.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.4265984109209193, 0.11998080307150856]
# iteration 1
# old estimated n0	275986
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.4265984109209193, 0.11998080307150856]
# new estimated n_0	275986
# score_function 0.000000
# Log likelihood	-28559.375510
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.4265984109209193, 0.11998080307150856]
# Final estimated_n0	275986
# Log likelihood	-28559.375510
# Observed clones	93765.000000
# Observed clones + estimated clones	369751.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	625680
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	625680
# score_function 0.000000
# Log likelihood	-24185.530665
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	625680
# Log likelihood	-24185.530665
# Observed clones	93765.000000
# Observed clones + estimated clones	719445.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	501706
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	501706
# score_function 0.000000
# Log likelihood	-26454.351735
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	501706
# Log likelihood	-26454.351735
# Observed clones	93765.000000
# Observed clones + estimated clones	595471.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	414178
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	414178
# score_function 0.000000
# Log likelihood	-28518.882147
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	414178
# Log likelihood	-28518.882147
# Observed clones	93765.000000
# Observed clones + estimated clones	507943.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	349083
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	349083
# score_function 0.000000
# Log likelihood	-30244.507848
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	349083
# Log likelihood	-30244.507848
# Observed clones	93765.000000
# Observed clones + estimated clones	442848.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	298778
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	298778
# score_function 0.000000
# Log likelihood	-31676.508262
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	298778
# Log likelihood	-31676.508262
# Observed clones	93765.000000
# Observed clones + estimated clones	392543.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	258736
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	258736
# score_function 0.000000
# Log likelihood	-32873.842228
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	258736
# Log likelihood	-32873.842228
# Observed clones	93765.000000
# Observed clones + estimated clones	352501.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	226106
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	226106
# score_function 0.000000
# Log likelihood	-33885.804113
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	226106
# Log likelihood	-33885.804113
# Observed clones	93765.000000
# Observed clones + estimated clones	319871.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.6132352156988214, 0.11998080307150856]
# iteration 1
# old estimated n0	199006
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.6132352156988214, 0.11998080307150856]
# new estimated n_0	199006
# score_function 0.000000
# Log likelihood	-34750.508564
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.6132352156988214, 0.11998080307150856]
# Final estimated_n0	199006
# Log likelihood	-34750.508564
# Observed clones	93765.000000
# Observed clones + estimated clones	292771.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	601099
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	601099
# score_function 0.000000
# Log likelihood	-25304.243638
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	601099
# Log likelihood	-25304.243638
# Observed clones	93765.000000
# Observed clones + estimated clones	694864.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	460012
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	460012
# score_function 0.000000
# Log likelihood	-29408.698816
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	460012
# Log likelihood	-29408.698816
# Observed clones	93765.000000
# Observed clones + estimated clones	553777.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	366549
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	366549
# score_function 0.000000
# Log likelihood	-32771.423321
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	366549
# Log likelihood	-32771.423321
# Observed clones	93765.000000
# Observed clones + estimated clones	460314.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	300078
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	300078
# score_function 0.000000
# Log likelihood	-35422.808627
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	300078
# Log likelihood	-35422.808627
# Observed clones	93765.000000
# Observed clones + estimated clones	393843.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	250382
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	250382
# score_function 0.000000
# Log likelihood	-37538.581743
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	250382
# Log likelihood	-37538.581743
# Observed clones	93765.000000
# Observed clones + estimated clones	344147.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	211823
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	211823
# score_function 0.000000
# Log likelihood	-39257.701959
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	211823
# Log likelihood	-39257.701959
# Observed clones	93765.000000
# Observed clones + estimated clones	305588.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	181033
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	181033
# score_function 0.000000
# Log likelihood	-40678.969561
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	181033
# Log likelihood	-40678.969561
# Observed clones	93765.000000
# Observed clones + estimated clones	274798.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.7998720204767238, 0.11998080307150856]
# iteration 1
# old estimated n0	155880
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.7998720204767238, 0.11998080307150856]
# new estimated n_0	155880
# score_function 0.000000
# Log likelihood	-41872.230019
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.7998720204767238, 0.11998080307150856]
# Final estimated_n0	155880
# Log likelihood	-41872.230019
# Observed clones	93765.000000
# Observed clones + estimated clones	249645.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	581943
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	581943
# score_function 0.000000
# Log likelihood	-26746.337320
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	581943
# Log likelihood	-26746.337320
# Observed clones	93765.000000
# Observed clones + estimated clones	675708.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	429605
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	429605
# score_function 0.000000
# Log likelihood	-32861.712737
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	429605
# Log likelihood	-32861.712737
# Observed clones	93765.000000
# Observed clones + estimated clones	523370.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	333320
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	333320
# score_function 0.000000
# Log likelihood	-37571.231693
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	333320
# Log likelihood	-37571.231693
# Observed clones	93765.000000
# Observed clones + estimated clones	427085.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	266957
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	266957
# score_function 0.000000
# Log likelihood	-41164.118028
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	266957
# Log likelihood	-41164.118028
# Observed clones	93765.000000
# Observed clones + estimated clones	360722.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	218444
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	218444
# score_function 0.000000
# Log likelihood	-43970.366335
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	218444
# Log likelihood	-43970.366335
# Observed clones	93765.000000
# Observed clones + estimated clones	312209.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	181433
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	181433
# score_function 0.000000
# Log likelihood	-46215.843752
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	181433
# Log likelihood	-46215.843752
# Observed clones	93765.000000
# Observed clones + estimated clones	275198.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	152267
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	152267
# score_function 0.000000
# Log likelihood	-48050.891533
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	152267
# Log likelihood	-48050.891533
# Observed clones	93765.000000
# Observed clones + estimated clones	246032.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.986508825254626, 0.11998080307150856]
# iteration 1
# old estimated n0	128691
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.986508825254626, 0.11998080307150856]
# new estimated n_0	128691
# score_function 0.000000
# Log likelihood	-49577.590942
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.986508825254626, 0.11998080307150856]
# Final estimated_n0	128691
# Log likelihood	-49577.590942
# Observed clones	93765.000000
# Observed clones + estimated clones	222456.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	566832
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	566832
# score_function 0.000000
# Log likelihood	-28395.600118
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	566832
# Log likelihood	-28395.600118
# Observed clones	93765.000000
# Observed clones + estimated clones	660597.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	406800
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	406800
# score_function 0.000000
# Log likelihood	-36597.711068
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	406800
# Log likelihood	-36597.711068
# Observed clones	93765.000000
# Observed clones + estimated clones	500565.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	309184
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	309184
# score_function 0.000000
# Log likelihood	-42680.762873
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	309184
# Log likelihood	-42680.762873
# Observed clones	93765.000000
# Observed clones + estimated clones	402949.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	243428
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	243428
# score_function 0.000000
# Log likelihood	-47235.611468
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	243428
# Log likelihood	-47235.611468
# Observed clones	93765.000000
# Observed clones + estimated clones	337193.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	196122
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	196122
# score_function 0.000000
# Log likelihood	-50752.332622
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	196122
# Log likelihood	-50752.332622
# Observed clones	93765.000000
# Observed clones + estimated clones	289887.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	160456
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	160456
# score_function 0.000000
# Log likelihood	-53544.070929
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	160456
# Log likelihood	-53544.070929
# Observed clones	93765.000000
# Observed clones + estimated clones	254221.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	132605
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	132605
# score_function 0.000000
# Log likelihood	-55812.323769
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	132605
# Log likelihood	-55812.323769
# Observed clones	93765.000000
# Observed clones + estimated clones	226370.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.1731456300325283, 0.11998080307150856]
# iteration 1
# old estimated n0	110254
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.1731456300325283, 0.11998080307150856]
# new estimated n_0	110254
# score_function 0.000000
# Log likelihood	-57691.072909
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.1731456300325283, 0.11998080307150856]
# Final estimated_n0	110254
# Log likelihood	-57691.072909
# Observed clones	93765.000000
# Observed clones + estimated clones	204019.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.05999040153575428, 0.11998080307150856]
# iteration 1
# old estimated n0	756166
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.05999040153575428, 0.11998080307150856]
# new estimated n_0	756166
# score_function 0.000000
# Log likelihood	-23359.658227
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.05999040153575428, 0.11998080307150856]
# Final estimated_n0	756166
# Log likelihood	-23359.658227
# Observed clones	93765.000000
# Observed clones + estimated clones	849931.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.056657601450434594, 0.11998080307150856]
# iteration 1
# old estimated n0	757379
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.056657601450434594, 0.11998080307150856]
# new estimated n_0	757379
# score_function 0.000000
# Log likelihood	-23359.637069
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.056657601450434594, 0.11998080307150856]
# Final estimated_n0	757379
# Log likelihood	-23359.637069
# Observed clones	93765.000000
# Observed clones + estimated clones	851144.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.053324801365114916, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	723223
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.053324801365114916, 0.23996160614301712, 0.11998080307150856]
# new estimated n_0	723223
# score_function 0.000000
# Log likelihood	-23329.569726
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.053324801365114916, 0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	723223
# Log likelihood	-23329.569726
# Observed clones	93765.000000
# Observed clones + estimated clones	816988.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 0.053324801365114916, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	761976
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# ...
# iteration 1
# old estimated n0	559518
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.986508825254626, 0.23996160614301712, 0.11998080307150856]
# new estimated n_0	559518
# score_function 0.000000
# Log likelihood	-26794.452372
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.986508825254626, 0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	559518
# Log likelihood	-26794.452372
# Observed clones	93765.000000
# Observed clones + estimated clones	653283.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 0.986508825254626, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	417145
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.04357142850000001, 0.8278571415] [0.986508825254626, 0.23996160614301712, 0.11998080307150856]
# new estimated n_0	417145
# score_function 0.000000
# Log likelihood	-32759.591454
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.04357142850000001, 0.8278571415]
# Fitted means	[0.986508825254626, 0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	417145
# Log likelihood	-32759.591454
# Observed clones	93765.000000
# Observed clones + estimated clones	510910.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0
000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.023928571500000002, 0.4546428585, 1.1731456300325283, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	131301
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.023928571500000002, 0.4546428585] [1.1731456300325283, 0.23996160614301712, 0.11998080307150856]
# new estimated n_0	131301
# score_function 0.000000
# Log likelihood	-55616.797510
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.023928571500000002, 0.4546428585]
# Fitted means	[1.1731456300325283, 0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	131301
# Log likelihood	-55616.797510
# Observed clones	93765.000000
# Observed clones + estimated clones	225066.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.020000000000000004, 0.38, 1.1731456300325283, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	109367
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.020000000000000004, 0.38] [1.1731456300325283, 0.23996160614301712, 0.11998080307150856]
# new estimated n_0	109367
# score_function 0.000000
# Log likelihood	-57531.187377
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.020000000000000004, 0.38]
# Fitted means	[1.1731456300325283, 0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	109367
# Log likelihood	-57531.187377
# Observed clones	93765.000000
# Observed clones + estimated clones	203132.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.026662400682557458, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	732444
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.026662400682557458, 0.23996160614301712, 0.11998080307150856]
# new estimated n_0	732444
# score_function 0.000000
# Log likelihood	-23329.456828
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.026662400682557458, 0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	732444
# Log likelihood	-23329.456828
# Observed clones	93765.000000
# Observed clones + estimated clones	826209.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.026662400682557458, 0.23996160614301712, 0.11998080307150856]
# iteration 1
# old estimated n0	732444
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.026662400682557458, 0.23996160614301712, 0.11998080307150856]
# new estimated n_0	732444
# score_function 0.000000
# Log likelihood	-23329.456828
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.026662400682557458, 0.23996160614301712, 0.11998080307150856]
# Final estimated_n0	732444
# Log likelihood	-23329.456828
# Observed clones	93765.000000
# Observed clones + estimated clones	826209.000000
# === END FIT ===
#
# ([0.05, 0.95], [0.23996160614301712, 0.11998080307150856], 700339, {1: 87837, 2: 5637, 3: 275, 4: 16}, None, -23329.757551708783, 2.426250696182251)

# %% [markdown]
# ### Uniform 1,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_1_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# Streaming output truncated to the last 5000 lines.
# iteration 1
# old estimated n0	180031
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.6129454126960603, 1.3077935778616703]
# new estimated n_0	180031
# score_function 0.000000
# Log likelihood	-683295.064536
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.6129454126960603, 1.3077935778616703]
# Final estimated_n0	180031
# Log likelihood	-683295.064536
# Observed clones	573485.000000
# Observed clones + estimated clones	753516.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.6129454126960603, 1.3077935778616703]
# iteration 1
# old estimated n0	174540
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.6129454126960603, 1.3077935778616703]
# new estimated n_0	174540
# score_function 0.000000
# Log likelihood	-684802.039109
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.6129454126960603, 1.3077935778616703]
# Final estimated_n0	174540
# Log likelihood	-684802.039109
# Observed clones	573485.000000
# Observed clones + estimated clones	748025.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.6129454126960603, 1.3077935778616703]
# iteration 1
# old estimated n0	169127
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.6129454126960603, 1.3077935778616703]
# new estimated n_0	169127
# score_function 0.000000
# Log likelihood	-686431.940197
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.6129454126960603, 1.3077935778616703]
# Final estimated_n0	169127
# Log likelihood	-686431.940197
# Observed clones	573485.000000
# Observed clones + estimated clones	742612.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	205960
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	205960
# score_function 0.000000
# Log likelihood	-678375.683685
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	205960
# Log likelihood	-678375.683685
# Observed clones	573485.000000
# Observed clones + estimated clones	779445.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	195812
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	195812
# score_function 0.000000
# Log likelihood	-680250.600225
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	195812
# Log likelihood	-680250.600225
# Observed clones	573485.000000
# Observed clones + estimated clones	769297.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	185924
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	185924
# score_function 0.000000
# Log likelihood	-682926.874299
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	185924
# Log likelihood	-682926.874299
# Observed clones	573485.000000
# Observed clones + estimated clones	759409.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	176288
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	176288
# score_function 0.000000
# Log likelihood	-686240.373365
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	176288
# Log likelihood	-686240.373365
# Observed clones	573485.000000
# Observed clones + estimated clones	749773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	166893
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	166893
# score_function 0.000000
# Log likelihood	-690084.137853
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	166893
# Log likelihood	-690084.137853
# Observed clones	573485.000000
# Observed clones + estimated clones	740378.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	157730
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	157730
# score_function 0.000000
# Log likelihood	-694382.850167
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	157730
# Log likelihood	-694382.850167
# Observed clones	573485.000000
# Observed clones + estimated clones	731215.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	148792
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	148792
# score_function 0.000000
# Log likelihood	-699080.953926
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	148792
# Log likelihood	-699080.953926
# Observed clones	573485.000000
# Observed clones + estimated clones	722277.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.91809724753045, 1.3077935778616703]
# iteration 1
# old estimated n0	140069
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.91809724753045, 1.3077935778616703]
# new estimated n_0	140069
# score_function 0.000000
# Log likelihood	-704136.204777
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.91809724753045, 1.3077935778616703]
# Final estimated_n0	140069
# Log likelihood	-704136.204777
# Observed clones	573485.000000
# Observed clones + estimated clones	713554.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.04359311926205568, 1.3077935778616703]
# iteration 1
# old estimated n0	774707
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.04359311926205568, 1.3077935778616703]
# new estimated n_0	774707
# score_function 0.000000
# Log likelihood	-676079.703676
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.04359311926205568, 1.3077935778616703]
# Final estimated_n0	774707
# Log likelihood	-676079.703676
# Observed clones	573485.000000
# Observed clones + estimated clones	1348192.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.482142855, 0.517857145, 0.06538967889308353, 1.3077935778616703]
# iteration 1
# old estimated n0	830949
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.482142855, 0.517857145] [0.06538967889308353, 1.3077935778616703]
# new estimated n_0	830949
# score_function 0.000000
# Log likelihood	-675613.202561
#
# Completed iteration of clone sizes
# Fitted weights	[0.482142855, 0.517857145]
# Fitted means	[0.06538967889308353, 1.3077935778616703]
# Final estimated_n0	830949
# Log likelihood	-675613.202561
# Observed clones	573485.000000
# Observed clones + estimated clones	1404434.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 0.08718623852411136, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	774433
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [0.08718623852411136, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	774433
# score_function 0.000000
# Log likelihood	-675563.140507
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[0.08718623852411136, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	774433
# Log likelihood	-675563.140507
# Observed clones	573485.000000
# Observed clones + estimated clones	1347918.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.3859183642244898, 0.4855102057755102, 0.08718623852411136, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	870418
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.38591836422448983, 0.48551020577551024] [0.08718623852411136, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	870418
# score_function 0.000000
# Log likelihood	-675633.093003
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.38591836422448983, 0.48551020577551024]
# Fitted means	[0.08718623852411136, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	870418
# Log likelihood	-675633.093003
# Observed clones	573485.000000
# Observed clones + estimated clones	1443903.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.2467346935510204, 0.3104081664489796] [0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	894026
# score_function 0.000000
# Log likelihood	-690615.264442
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.2467346935510204, 0.3104081664489796]
# Fitted means	[0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	894026
# Log likelihood	-690615.264442
# Observed clones	573485.000000
# Observed clones + estimated clones	1467511.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.2119387747755102, 0.2666326552244898, 0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	929978
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.2119387747755102, 0.2666326552244898] [0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	929978
# score_function 0.000000
# Log likelihood	-698168.316145
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.2119387747755102, 0.2666326552244898]
# Fitted means	[0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	929978
# Log likelihood	-698168.316145
# Observed clones	573485.000000
# Observed clones + estimated clones	1503463.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.17714285600000002, 0.222857144, 0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	967736
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.17714285600000002, 0.222857144] [0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	967736
# score_function 0.000000
# Log likelihood	-708218.666530
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.17714285600000002, 0.222857144]
# Fitted means	[0.3923380733585011, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	967736
# Log likelihood	-708218.666530
# Observed clones	573485.000000
# Observed clones + estimated clones	1541221.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	711222
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	711222
# score_function 0.000000
# Log likelihood	-675760.214853
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	711222
# Log likelihood	-675760.214853
# Observed clones	573485.000000
# Observed clones + estimated clones	1284707.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.3859183642244898, 0.4855102057755102, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	698082
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.38591836422448983, 0.48551020577551024] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	698082
# score_function 0.000000
# Log likelihood	-676564.352268
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.38591836422448983, 0.48551020577551024]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	698082
# Log likelihood	-676564.352268
# Observed clones	573485.000000
# Observed clones + estimated clones	1271567.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.3511224454489796, 0.4417346945510204, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	685208
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.3511224454489796, 0.4417346945510204] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	685208
# score_function 0.000000
# Log likelihood	-678007.944369
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.3511224454489796, 0.4417346945510204]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	685208
# Log likelihood	-678007.944369
# Observed clones	573485.000000
# Observed clones + estimated clones	1258693.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.3163265266734694, 0.3979591833265306, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	672593
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.3163265266734694, 0.3979591833265306] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	672593
# score_function 0.000000
# Log likelihood	-680100.953395
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.3163265266734694, 0.3979591833265306]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	672593
# Log likelihood	-680100.953395
# Observed clones	573485.000000
# Observed clones + estimated clones	1246078.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.2815306123265306, 0.3541836776734694, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	660228
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.2815306123265306, 0.3541836776734694] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	660228
# score_function 0.000000
# Log likelihood	-682864.183662
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.2815306123265306, 0.3541836776734694]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	660228
# Log likelihood	-682864.183662
# Observed clones	573485.000000
# Observed clones + estimated clones	1233713.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.2467346935510204, 0.3104081664489796, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	648105
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.2467346935510204, 0.3104081664489796] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	648105
# score_function 0.000000
# Log likelihood	-686331.700455
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.2467346935510204, 0.3104081664489796]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	648105
# Log likelihood	-686331.700455
# Observed clones	573485.000000
# Observed clones + estimated clones	1221590.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.2119387747755102, 0.2666326552244898, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	636219
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.2119387747755102, 0.2666326552244898] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	636219
# score_function 0.000000
# Log likelihood	-690554.717011
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.2119387747755102, 0.2666326552244898]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	636219
# Log likelihood	-690554.717011
# Observed clones	573485.000000
# Observed clones + estimated clones	1209704.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.17714285600000002, 0.222857144, 0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	624562
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.17714285600000002, 0.222857144] [0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	624562
# score_function 0.000000
# Log likelihood	-695607.978640
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.17714285600000002, 0.222857144]
# Fitted means	[0.6974899081928909, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	624562
# Log likelihood	-695607.978640
# Observed clones	573485.000000
# Observed clones + estimated clones	1198047.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 1.0026417430272805, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	692654
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [1.0026417430272805, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	692654
# score_function 0.000000
# Log likelihood	-675720.549405
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.15946428775, 0.039526785612500004, 0.33258966536515305, 0.4184192612723469, 0.032694839446541765, 0.06538967889308353, 1.6129454126960603, 0.08718623852411136, 1.3077935778616703]
# iteration 1
# old estimated n0	950152
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.15946428775, 0.039526785612500004, 0.33258966536515305, 0.4184192612723469] [0.032694839446541765, 0.06538967889308353, 1.6129454126960603, 0.08718623852411136, 1.3077935778616703]
# new estimated n_0	950152
# score_function 0.000000
# Log likelihood	-675293.793538
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.15946428775, 0.039526785612500004, 0.33258966536515305, 0.4184192612723469]
# Fitted means	[0.032694839446541765, 0.06538967889308353, 1.6129454126960603, 0.08718623852411136, 1.3077935778616703]
# Final estimated_n0	950152
# Log likelihood	-675293.793538
# Observed clones	573485.000000
# Observed clones + estimated clones	1523637.000000
# === END FIT ===
#
# ([0.16785714499999999, 0.041607142750000006, 0.35009438459489794, 0.440441327655102], [0.06538967889308353, 1.6129454126960603, 0.08718623852411136, 1.3077935778616703], 880181, {1: 303125, 2: 163447, 3: 71206, 4: 25478, 5: 7633, 6: 2028, 7: 452, 8: 97, 9: 14, 10: 3, 11: 2}, None, -675301.9255253274, 4.04986310005188)

# %% [markdown]
# ### Uniform 3,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_3_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_unif1_3_000_000.tsv...
# 870035 845046.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.17750512989825407]
# iteration 1
# old estimated n0	4350655
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.17750512989825407]
# new estimated n_0	4350655
# score_function 0.000000
# Log likelihood	-6409468.597710
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.17750512989825407]
# Final estimated_n0	4350655
# Log likelihood	-6409468.597710
# Observed clones	845046.000000
# Observed clones + estimated clones	5195701.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7987730845421434]
# iteration 1
# old estimated n0	691068
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7987730845421434]
# new estimated n_0	691068
# score_function 0.000000
# Log likelihood	-3451989.119012
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7987730845421434]
# Final estimated_n0	691068
# Log likelihood	-3451989.119012
# Observed clones	845046.000000
# Observed clones + estimated clones	1536114.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.4200410391860325]
# iteration 1
# old estimated n0	269355
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.4200410391860325]
# new estimated n_0	269355
# score_function 0.000000
# Log likelihood	-2522104.328369
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.4200410391860325]
# Final estimated_n0	269355
# Log likelihood	-2522104.328369
# Observed clones	845046.000000
# Observed clones + estimated clones	1114401.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.041308993829922]
# iteration 1
# old estimated n0	126113
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.041308993829922]
# new estimated n_0	126113
# score_function 0.000000
# Log likelihood	-2074650.988950
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.041308993829922]
# Final estimated_n0	126113
# Log likelihood	-2074650.988950
# Observed clones	845046.000000
# Observed clones + estimated clones	971159.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.662576948473811]
# iteration 1
# old estimated n0	63379
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.662576948473811]
# new estimated n_0	63379
# score_function 0.000000
# Log likelihood	-1858972.051354
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.662576948473811]
# Final estimated_n0	63379
# Log likelihood	-1858972.051354
# Observed clones	845046.000000
# Observed clones + estimated clones	908425.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 3.2838449031177004]
# iteration 1
# old estimated n0	32909
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [3.2838449031177004]
# new estimated n_0	32909
# score_function 0.000000
# Log likelihood	-1783640.923090
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[3.2838449031177004]
# Final estimated_n0	32909
# Log likelihood	-1783640.923090
# Observed clones	845046.000000
# Observed clones + estimated clones	877955.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 3.9051128577615897]
# iteration 1
# old estimated n0	17368
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [3.9051128577615897]
# new estimated n_0	17368
# score_function 0.000000
# Log likelihood	-1803918.460396
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[3.9051128577615897]
# Final estimated_n0	17368
# Log likelihood	-1803918.460396
# Observed clones	845046.000000
# Observed clones + estimated clones	862414.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.6419224515588502]
# iteration 1
# old estimated n0	202888
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.6419224515588502]
# new estimated n_0	202888
# score_function 0.000000
# Log likelihood	-2326026.037818
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.6419224515588502]
# Final estimated_n0	202888
# Log likelihood	-2326026.037818
# Observed clones	845046.000000
# Observed clones + estimated clones	1047934.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.77351765466022]
# iteration 1
# old estimated n0	56281
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.77351765466022]
# new estimated n_0	56281
# score_function 0.000000
# Log likelihood	-1836885.330705
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.77351765466022]
# Final estimated_n0	56281
# Log likelihood	-1836885.330705
# Observed clones	845046.000000
# Observed clones + estimated clones	901327.000000
# === END FIT ===
#
# ([], [], 0, {1: 167111, 2: 159857, 3: 145383, 4: 122281, 5: 94238, 6: 65951, 7: 42256, 8: 24541, 9: 12724, 10: 6139, 11: 2790, 12: 1124, 13: 426, 14: 142, 15: 61, 16: 17, 18: 2, 17: 2, 19: 1}, None, 1.0, 0.6228411197662354)

# %% [markdown]
# ### Uniform 10,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_10_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_unif1_10_000_000.tsv...
# 962797 962767.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.5193364541991988]
# iteration 1
# old estimated n0	1413052
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.5193364541991988]
# new estimated n_0	1413052
# score_function 0.000000
# Log likelihood	-23313768.609945
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.5193364541991988]
# Final estimated_n0	1413052
# Log likelihood	-23313768.609945
# Observed clones	962767.000000
# Observed clones + estimated clones	2375819.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.337014043896395]
# iteration 1
# old estimated n0	102902
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.337014043896395]
# new estimated n_0	102902
# score_function 0.000000
# Log likelihood	-10821564.504670
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.337014043896395]
# Final estimated_n0	102902
# Log likelihood	-10821564.504670
# Observed clones	962767.000000
# Observed clones + estimated clones	1065669.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 4.154691633593591]
# iteration 1
# old estimated n0	15338
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [4.154691633593591]
# new estimated n_0	15338
# score_function 0.000000
# Log likelihood	-6910069.184639
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[4.154691633593591]
# Final estimated_n0	15338
# Log likelihood	-6910069.184639
# Observed clones	962767.000000
# Observed clones + estimated clones	978105.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 5.9723692232907855]
# iteration 1
# old estimated n0	2458
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [5.9723692232907855]
# new estimated n_0	2458
# score_function 0.000000
# Log likelihood	-5049426.341023
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[5.9723692232907855]
# Final estimated_n0	2458
# Log likelihood	-5049426.341023
# Observed clones	962767.000000
# Observed clones + estimated clones	965225.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 7.790046812987982]
# iteration 1
# old estimated n0	398
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [7.790046812987982]
# new estimated n_0	398
# score_function 0.000000
# Log likelihood	-4148294.700402
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[7.790046812987982]
# Final estimated_n0	398
# Log likelihood	-4148294.700402
# Observed clones	962767.000000
# Observed clones + estimated clones	963165.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 9.607724402685179]
# iteration 1
# old estimated n0	65
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [9.607724402685179]
# new estimated n_0	65
# score_function 0.000000
# Log likelihood	-3804225.626889
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[9.607724402685179]
# Final estimated_n0	65
# Log likelihood	-3804225.626889
# Observed clones	962767.000000
# Observed clones + estimated clones	962832.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 11.425401992382374]
# iteration 1
# old estimated n0	11
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [11.425401992382374]
# new estimated n_0	11
# score_function 0.000000
# Log likelihood	-3823687.640986
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[11.425401992382374]
# Final estimated_n0	11
# Log likelihood	-3823687.640986
# Observed clones	962767.000000
# Observed clones + estimated clones	962778.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 4.803862201342589]
# iteration 1
# old estimated n0	7953
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [4.803862201342589]
# new estimated n_0	7953
# score_function 0.000000
# Log likelihood	-6092852.869045
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[4.803862201342589]
# Final estimated_n0	7953
# Log likelihood	-6092852.869045
# Observed clones	962767.000000
# Observed clones + estimated clones	970720.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 8.114632096862483]
# iteration 1
# old estimated n0	288
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [8.114632096862483]
# new estimated n_0	288
# score_function 0.000000
# Log likelihood	-4053248.314039
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[8.114632096862483]
# Final estimated_n0	288
# Log likelihood	-4053248.314039
# Observed clones	962767.000000
# Observed clones + estimated clones	963055.000000
# === END FIT ===
#
# ([], [], 0, {4: 51309, 3: 51070, 9: 50994, 6: 50963, 8: 50856, 11: 50816, 5: 50764, 7: 50701, 2: 50700, 10: 50680, 1: 49904, 12: 49706, 13: 48615, 14: 46660, 15: 43710, 16: 40707, 17: 36891, 18: 32020, 19: 27118, 20: 21754, 21: 17288, 22: 13080, 23: 9428, 24: 6365, 25: 4208, 26: 2721, 27: 1626, 28: 963, 29: 547, 30: 306, 31: 173, 32: 73, 33: 31, 34: 14, 35: 4, 36: 2}, None, 1.0, 0.39995646476745605)

# %% [markdown]
# ### Uniform 20,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_20_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# Streaming output truncated to the last 5000 lines.
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.04750000000000001, 0.045125000000000005, 0.11023392979624999, 0.0373570535101875, 0.09125794601743521, 0.22532020880976317, 0.11234453364698628, 0.2808613282193778] [22.276901890498902, 8.100691596545055, 4.3034924106645605, 22.276901890498902, 1.0125864495681318, 8.100691596545055, 22.276901890498902, 4.556639023056594, 15.188796743521976]
# new estimated n_0	11523
# score_function 0.000000
# Log likelihood	-2531490.622773
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.04750000000000001, 0.045125000000000005, 0.11023392979624999, 0.0373570535101875, 0.09125794601743521, 0.22532020880976317, 0.11234453364698628, 0.2808613282193778]
# Fitted means	[22.276901890498902, 8.100691596545055, 4.3034924106645605, 22.276901890498902, 1.0125864495681318, 8.100691596545055, 22.276901890498902, 4.556639023056594, 15.188796743521976]
# Final estimated_n0	11523
# Log likelihood	-2531490.622773
# Observed clones	987570.000000
# Observed clones + estimated clones	999093.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.04357142850000001, 0.041392857075000004, 0.10111683769244896, 0.03426737233662755, 0.08371029620959027, 0.20668470247915088, 0.10305288031927383, 0.2576321953879085, 22.276901890498902, 8.100691596545055, 4.3034924106645605, 22.276901890498902, 1.0125864495681318, 8.100691596545055, 22.276901890498902, 4.556639023056594, 15.188796743521976]
# iteration 1
# old estimated n0	10557
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.043571428500000016, 0.04139285707500001, 0.10111683769244897, 0.034267372336627556, 0.08371029620959028, 0.2066847024791509, 0.10305288031927384, 0.25763219538790855] [22.276901890498902, 8.100691596545055, 4.3034924106645605, 22.276901890498902, 1.0125864495681318, 8.100691596545055, 22.276901890498902, 4.556639023056594, 15.188796743521976]
# new estimated n_0	10557
# score_function 0.000000
# Log likelihood	-2532544.812008
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.04357142850000001, 0.041392857075000004, 0.10111683769244895, 0.03426737233662755, 0.08371029620959027, 0.20668470247915086, 0.10305288031927382, 0.2576321953879085]
# Fitted means	[22.276901890498902, 8.100691596545055, 4.3034924106645605, 22.276901890498902, 1.0125864495681318, 8.100691596545055, 22.276901890498902, 4.556639023056594, 15.188796743521976]
# Final estimated_n0	10557
# Log likelihood	-2532544.812008
# Observed clones	987570.000000
# Observed clones + estimated clones	998127.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.039642857000000004, 0.03766071415, 0.09199974558864794, 0.0311776911630676, 0.07616264640174533, 0.18804919614853857, 0.09376122699156138, 0.23440306255643917, 22.276901890498902, 8.100691596545055, 4.3034924106645605, 22.276901890498902, 1.0125864495681318, 8.100691596545055, 22.276901890498902, 4.556639023056594, 15.188796743521976]
# iteration 1
# old estimated n0	9592
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.039642857000000004, 0.03766071415, 0.09199974558864794, 0.0311776911630676, 0.07616264640174533, 0.18804919614853857, 0.09376122699156138, 0.23440306255643917] [22.276901890498902, 8.100691596545055, 4.3034924106645605, 22.276901890498902, 1.0125864495681318, 8.100691596545055, 22.276901890498902, 4.556639023056594, 15.188796743521976]
# new estimated n_0	9592
# score_function 0.000000
# Log likelihood	-2538704.837242
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0
: 25520, 20: 25511, 16: 25496, 25: 25467, 14: 25463, 11: 25449, 5: 25417, 15: 25416, 17: 25410, 6: 25405, 22: 25369, 24: 25311, 26: 25257, 12: 25210, 28: 25202, 13: 25174, 9: 25168, 29: 25006, 30: 24848, 31: 24203, 1: 23796, 32: 23680, 33: 22987, 34: 22182, 35: 20428, 36: 19139, 37: 17167, 38: 15218, 39: 13426, 40: 11282, 41: 9496, 42: 7466, 43: 5744, 44: 4290, 45: 3100, 46: 2207, 47: 1514, 48: 1035, 49: 598, 50: 447, 51: 229, 52: 128, 53: 59, 54: 40, 55: 22, 56: 11, 57: 4, 58: 2, 59: 2}, None, -2528926.2940912154, 14.547537803649902)

# %% [markdown]
# ### Uniform 30,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_30_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# Streaming output truncated to the last 5000 lines.
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.11603571557499998, 0.07022002595684948, 0.03581221292340753, 0.08748412111351271, 0.1694136952358426, 0.13764862448850096, 0.2858856047068867] [33.166795816159464, 1.5075816280072485, 22.613724420108724, 11.495309913555268, 0.7537908140036242, 6.784117326032618, 22.613724420108724, 5.0880879945244635, 17.337188722083354]
# new estimated n_0	14275
# score_function 0.000000
# Log likelihood	-1701217.434612
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.11603571557499998, 0.07022002595684948, 0.03581221292340753, 0.08748412111351271, 0.1694136952358426, 0.13764862448850096, 0.2858856047068867]
# Fitted means	[33.166795816159464, 1.5075816280072485, 22.613724420108724, 11.495309913555268, 0.7537908140036242, 6.784117326032618, 22.613724420108724, 5.0880879945244635, 17.337188722083354]
# Final estimated_n0	14275
# Log likelihood	-1701217.434612
# Observed clones	994971.000000
# Observed clones + estimated clones	1009246.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.10643877651836732, 0.06441235453151603, 0.03285030052250583, 0.0802485921680581, 0.15540203597661698, 0.1262641515794541, 0.2622409302034816, 33.166795816159464, 1.5075816280072485, 22.613724420108724, 11.495309913555268, 0.7537908140036242, 6.784117326032618, 22.613724420108724, 5.0880879945244635, 17.337188722083354]
# iteration 1
# old estimated n0	13063
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.0435714285, 0.10643877651836732, 0.06441235453151603, 0.03285030052250583, 0.0802485921680581, 0.15540203597661698, 0.1262641515794541, 0.2622409302034816] [33.166795816159464, 1.5075816280072485, 22.613724420108724, 11.495309913555268, 0.7537908140036242, 6.784117326032618, 22.613724420108724, 5.0880879945244635, 17.337188722083354]
# new estimated n_0	13063
# score_function 0.000000
# Log likelihood	-1725538.438273
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.0435714285, 0.10643877651836732, 0.06441235453151603, 0.03285030052250583, 0.0802485921680581, 0.15540203597661698, 0.1262641515794541, 0.2622409302034816]
# Fitted means	[33.166795816159464, 1.5075816280072485, 22.613724420108724, 11.495309913555268, 0.7537908140036242, 6.784117326032618, 22.613724420108724, 5.0880879945244635, 17.337188722083354]
# Final estimated_n0	13063
# Log likelihood	-1725538.438273
# Observed clones	994971.000000
# Observed clones + estimated clones	1008034.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0
# ([0.05, 0.04750000000000001, 0.045125000000000005, 0.042868750000000004, 0.10472223330643748, 0.06337357342605666, 0.0323205221633753, 0.07895441930494523, 0.15289585995034796, 0.12422788360087213, 0.25801175824796524], [12.060653024057988, 22.613724420108724, 11.495309913555268, 1.5075816280072485, 22.613724420108724, 11.495309913555268, 0.7537908140036242, 6.784117326032618, 22.613724420108724, 5.0880879945244635, 17.337188722083354], 12847, {34: 17323, 18: 17314, 41: 17280, 28: 17208, 32: 17185, 2: 17180, 17: 17124, 43: 17124, 3: 17120, 46: 17113, 9: 17094, 14: 17093, 27: 17092, 5: 17091, 42: 17090, 24: 17087, 4: 17071, 26: 17041, 8: 17008, 16: 17003, 22: 17002, 36: 17001, 19: 16963, 6: 16958, 44: 16955, 45: 16953, 31: 16944, 38: 16924, 35: 16924, 21: 16909, 25: 16907, 47: 16894, 10: 16888, 30: 16882, 20: 16878, 15: 16869, 39: 16864, 12: 16857, 40: 16831, 7: 16810, 23: 16806, 37: 16802, 13: 16775, 33: 16768, 29: 16767, 48: 16718, 49: 16714, 11: 16710, 50: 16347, 51: 16333, 52: 15933, 53: 15180, 54: 14565, 1: 14151, 55: 13618, 56: 12590, 57: 11472, 58: 10203, 59: 8794, 60: 7449, 61: 6119, 62: 4898, 63: 3745, 64: 2861, 65: 2015, 66: 1376, 67: 963, 68: 610, 69: 387, 70: 197, 71: 127, 72: 58, 73: 34, 75: 13, 74: 11, 77: 5, 76: 3}, None, -1684541.277675411, 14.289117574691772)

# %% [markdown]
# ### Uniform 40,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_unif1_40_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# Streaming output truncated to the last 5000 lines.
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.047500000000000014, 0.04512500000000001, 0.11023392979625, 0.15476493810546554, 0.145978406096992, 0.1275422093420738, 0.0660486436475682, 0.25280687301165045] [44.072278536800354, 23.037781962418364, 23.037781962418364, 9.014784246163709, 23.037781962418364, 5.008213470090949, 23.037781962418364, 2.0032853880363795, 15.525461757281942]
# new estimated n_0	3657
# score_function 0.000000
# Log likelihood	-1272736.167886
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.047500000000000014, 0.04512500000000001, 0.11023392979625, 0.15476493810546554, 0.145978406096992, 0.1275422093420738, 0.0660486436475682, 0.25280687301165045]
# Fitted means	[44.072278536800354, 23.037781962418364, 23.037781962418364, 9.014784246163709, 23.037781962418364, 5.008213470090949, 23.037781962418364, 2.0032853880363795, 15.525461757281942]
# Final estimated_n0	3657
# Log likelihood	-1272736.167886
# Observed clones	998360.000000
# Observed clones + estimated clones	1002017.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.04357142850000001, 0.04139285707500001, 0.10111683769244897, 0.14196483020987827, 0.1339050038694537, 0.11699360537010949, 0.06058597377288414, 0.23189803351022542, 44.072278536800354, 23.037781962418364, 23.037781962418364, 9.014784246163709, 23.037781962418364, 5.008213470090949, 23.037781962418364, 2.0032853880363795, 15.525461757281942]
# iteration 1
# old estimated n0	3352
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.04357142850000001, 0.04139285707500001, 0.10111683769244897, 0.14196483020987827, 0.1339050038694537, 0.11699360537010949, 0.06058597377288414, 0.23189803351022542] [44.072278536800354, 23.037781962418364, 23.037781962418364, 9.014784246163709, 23.037781962418364, 5.008213470090949, 23.037781962418364, 2.0032853880363795, 15.525461757281942]
 9.014784246163709, 23.037781962418364, 23.037781962418364, 9.014784246163709, 23.037781962418364, 5.008213470090949, 23.037781962418364, 2.0032853880363795, 15.525461757281942]
# Final estimated_n0	3299
# Log likelihood	-1253273.034403
# Observed clones	998360.000000
# Observed clones + estimated clones	1001659.000000
# === END FIT ===
#
# ([0.05, 0.0475, 0.04512500000000001, 0.04286875000000001, 0.1047222333064375, 0.14702669120019227, 0.1386794857921424, 0.12116509887497011, 0.06274621146518979, 0.24016652936106792], [23.037781962418364, 9.014784246163709, 23.037781962418364, 23.037781962418364, 9.014784246163709, 23.037781962418364, 5.008213470090949, 23.037781962418364, 2.0032853880363795, 15.525461757281942], 3474, {58: 13006, 9: 12974, 48: 12964, 18: 12947, 55: 12930, 4: 12921, 6: 12919, 46: 12918, 16: 12906, 66: 12875, 2: 12872, 43: 12871, 59: 12852, 19: 12836, 38: 12832, 3: 12829, 64: 12824, 17: 12822, 22: 12813, 53: 12811, 37: 12809, 42: 12806, 54: 12803, 7: 12799, 33: 12796, 34: 12796, 56: 12785, 14: 12783, 50: 12782, 23: 12782, 40: 12779, 67: 12771, 26: 12768, 24: 12766, 36: 12763, 27: 12755, 60: 12754, 68: 12741, 5: 12741, 65: 12735, 63: 12729, 51: 12728, 41: 12728, 31: 12716, 44: 12695, 28: 12690, 39: 12688, 29: 12675, 8: 12659, 32: 12653, 12: 12646, 15: 12636, 45: 12624, 52: 12623, 70: 12616, 49: 12614, 62: 12601, 47: 12596, 20: 12594, 21: 12593, 69: 12587, 25: 12581, 30: 12572, 13: 12568, 57: 12567, 35: 12565, 10: 12524, 11: 12516, 61: 12507, 71: 12392, 72: 12217, 73: 11884, 74: 11310, 75: 10711, 76: 9905, 77: 9077, 1: 8861, 78: 7792, 79: 6683, 80: 5296, 81: 4250, 82: 3168, 83: 2125, 84: 1458, 85: 890, 86: 537, 87: 245, 88: 127, 89: 59, 90: 31, 91: 12, 92: 3}, None, -1253158.8332853457, 14.533338069915771)

# %% [markdown]
# ## Mixed Poisson Distribution 2

# %% [markdown]
# ### Mixed Poisson 10,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp1_10_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp1_10_000.tsv...
# 15697 9951.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.050246206411415945]
# iteration 1
# old estimated n0	193111
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.050246206411415945]
# new estimated n_0	193111
# score_function 0.000000
# Log likelihood	-432.372107
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.050246206411415945]
# Final estimated_n0	193111
# Log likelihood	-432.372107
# Observed clones	9951.000000
# Observed clones + estimated clones	203062.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.22610792885137174]
# iteration 1
# old estimated n0	39222
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.22610792885137174]
# new estimated n_0	39222
# score_function 0.000000
# Log likelihood	-1253.814135
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.22610792885137174]
# Final estimated_n0	39222
# Log likelihood	-1253.814135
# Observed clones	9951.000000
# Observed clones + estimated clones	49173.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.40196965129132756]
# iteration 1
# old estimated n0	20113
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.40196965129132756]
# new estimated n_0	20113
# score_function 0.000000
# Log likelihood	-2146.337662
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.40196965129132756]
# Final estimated_n0	20113
# Log likelihood	-2146.337662
# Observed clones	9951.000000
# Observed clones + estimated clones	30064.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.5778313737312832]
# iteration 1
# old estimated n0	12722
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.5778313737312832]
# new estimated n_0	12722
# score_function 0.000000
# Log likelihood	-3074.705931
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.5778313737312832]
# Final estimated_n0	12722
# Log likelihood	-3074.705931
# Observed clones	9951.000000
# Observed clones + estimated clones	22673.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7536930961712391]
# iteration 1
# old estimated n0	8847
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7536930961712391]
# new estimated n_0	8847
# score_function 0.000000
# Log likelihood	-4033.054971
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7536930961712391]
# Final estimated_n0	8847
# Log likelihood	-4033.054971
# Observed clones	9951.000000
# Observed clones + estimated clones	18798.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.9295548186111949]
# iteration 1
# old estimated n0	6490
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.9295548186111949]
# new estimated n_0	6490
# score_function 0.000000
# Log likelihood	-5019.075576
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.9295548186111949]
# Final estimated_n0	6490
# Log likelihood	-5019.075576
# Observed clones	9951.000000
# Observed clones + estimated clones	16441.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.1054165410511507]
# iteration 1
# old estimated n0	4925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.1054165410511507]
# new estimated n_0	4925
# score_function 0.000000
# Log likelihood	-6031.452181
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.1054165410511507]
# Final estimated_n0	4925
# Log likelihood	-6031.452181
# Observed clones	9951.000000
# Observed clones + estimated clones	14876.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.025123103205707972]
# iteration 1
# old estimated n0	391135
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.025123103205707972]
# new estimated n_0	391135
# score_function 0.000000
# Log likelihood	-340.551243
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.025123103205707972]
# Final estimated_n0	391135
# Log likelihood	-340.551243
# Observed clones	9951.000000
# Observed clones + estimated clones	401086.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.025123103205707972]
# iteration 1
# old estimated n0	391135
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.025123103205707972]
# new estimated n_0	391135
# score_function 0.000000
# Log likelihood	-340.551243
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.025123103205707972]
# Final estimated_n0	391135
# Log likelihood	-340.551243
# Observed clones	9951.000000
# Observed clones + estimated clones	401086.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	372487
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	372487
# score_function 0.000000
# Log likelihood	-347.830377
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	372487
# Log likelihood	-347.830377
# Observed clones	9951.000000
# Observed clones + estimated clones	382438.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	346449
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	346449
# score_function 0.000000
# Log likelihood	-358.695474
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	346449
# Log likelihood	-358.695474
# Observed clones	9951.000000
# Observed clones + estimated clones	356400.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	323730
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	323730
# score_function 0.000000
# Log likelihood	-368.701743
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	323730
# Log likelihood	-368.701743
# Observed clones	9951.000000
# Observed clones + estimated clones	333681.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	303734
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	303734
# score_function 0.000000
# Log likelihood	-377.839563
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	303734
# Log likelihood	-377.839563
# Observed clones	9951.000000
# Observed clones + estimated clones	313685.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	285999
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	285999
# score_function 0.000000
# Log likelihood	-386.165807
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	285999
# Log likelihood	-386.165807
# Observed clones	9951.000000
# Observed clones + estimated clones	295950.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	270162
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	270162
# score_function 0.000000
# Log likelihood	-393.756410
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	270162
# Log likelihood	-393.756410
# Observed clones	9951.000000
# Observed clones + estimated clones	280113.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	255934
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	255934
# score_function 0.000000
# Log likelihood	-400.688787
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	255934
# Log likelihood	-400.688787
# Observed clones	9951.000000
# Observed clones + estimated clones	265885.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.050246206411415945, 0.025123103205707972]
# iteration 1
# old estimated n0	243082
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.050246206411415945, 0.025123103205707972]
# new estimated n_0	243082
# score_function 0.000000
# Log likelihood	-407.035234
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.050246206411415945, 0.025123103205707972]
# Final estimated_n0	243082
# Log likelihood	-407.035234
# Observed clones	9951.000000
# Observed clones + estimated clones	253033.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	285436
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	285436
# score_function 0.000000
# Log likelihood	-577.222518
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	285436
# Log likelihood	-577.222518
# Observed clones	9951.000000
# Observed clones + estimated clones	295387.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	198932
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	198932
# score_function 0.000000
# Log likelihood	-803.736215
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	198932
# Log likelihood	-803.736215
# Observed clones	9951.000000
# Observed clones + estimated clones	208883.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	151617
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	151617
# score_function 0.000000
# Log likelihood	-933.361698
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	151617
# Log likelihood	-933.361698
# Observed clones	9951.000000
# Observed clones + estimated clones	161568.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	121779
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	121779
# score_function 0.000000
# Log likelihood	-1016.802750
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	121779
# Log likelihood	-1016.802750
# Observed clones	9951.000000
# Observed clones + estimated clones	131730.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	101243
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	101243
# score_function 0.000000
# Log likelihood	-1074.935319
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	101243
# Log likelihood	-1074.935319
# Observed clones	9951.000000
# Observed clones + estimated clones	111194.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	86247
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	86247
# score_function 0.000000
# Log likelihood	-1117.738531
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	86247
# Log likelihood	-1117.738531
# Observed clones	9951.000000
# Observed clones + estimated clones	96198.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	74815
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	74815
# score_function 0.000000
# Log likelihood	-1150.563038
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	74815
# Log likelihood	-1150.563038
# Observed clones	9951.000000
# Observed clones + estimated clones	84766.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.22610792885137174, 0.025123103205707972]
# iteration 1
# old estimated n0	65811
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.22610792885137174, 0.025123103205707972]
# new estimated n_0	65811
# score_function 0.000000
# Log likelihood	-1176.531432
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.22610792885137174, 0.025123103205707972]
# Final estimated_n0	65811
# Log likelihood	-1176.531432
# Observed clones	9951.000000
# Observed clones + estimated clones	75762.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	238082
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	238082
# score_function 0.000000
# Log likelihood	-1002.914914
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	238082
# Log likelihood	-1002.914914
# Observed clones	9951.000000
# Observed clones + estimated clones	248033.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	145104
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	145104
# score_function 0.000000
# Log likelihood	-1469.956232
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	145104
# Log likelihood	-1469.956232
# Observed clones	9951.000000
# Observed clones + estimated clones	155055.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	102827
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	102827
# score_function 0.000000
# Log likelihood	-1692.567559
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	102827
# Log likelihood	-1692.567559
# Observed clones	9951.000000
# Observed clones + estimated clones	112778.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	78666
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	78666
# score_function 0.000000
# Log likelihood	-1822.610155
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	78666
# Log likelihood	-1822.610155
# Observed clones	9951.000000
# Observed clones + estimated clones	88617.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	63030
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	63030
# score_function 0.000000
# Log likelihood	-1907.859783
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	63030
# Log likelihood	-1907.859783
# Observed clones	9951.000000
# Observed clones + estimated clones	72981.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	52085
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	52085
# score_function 0.000000
# Log likelihood	-1968.054072
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	52085
# Log likelihood	-1968.054072
# Observed clones	9951.000000
# Observed clones + estimated clones	62036.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	43994
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	43994
# score_function 0.000000
# Log likelihood	-2012.821983
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	43994
# Log likelihood	-2012.821983
# Observed clones	9951.000000
# Observed clones + estimated clones	53945.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.40196965129132756, 0.025123103205707972]
# iteration 1
# old estimated n0	37770
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.40196965129132756, 0.025123103205707972]
# new estimated n_0	37770
# score_function 0.000000
# Log likelihood	-2047.419465
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.40196965129132756, 0.025123103205707972]
# Final estimated_n0	37770
# Log likelihood	-2047.419465
# Observed clones	9951.000000
# Observed clones + estimated clones	47721.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	208685
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	208685
# score_function 0.000000
# Log likelihood	-1514.457756
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	208685
# Log likelihood	-1514.457756
# Observed clones	9951.000000
# Observed clones + estimated clones	218636.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	117547
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	117547
# score_function 0.000000
# Log likelihood	-2205.799281
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	117547
# Log likelihood	-2205.799281
# Observed clones	9951.000000
# Observed clones + estimated clones	127498.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	80036
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	80036
# score_function 0.000000
# Log likelihood	-2507.255006
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	80036
# Log likelihood	-2507.255006
# Observed clones	9951.000000
# Observed clones + estimated clones	89987.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	59579
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	59579
# score_function 0.000000
# Log likelihood	-2676.013266
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	59579
# Log likelihood	-2676.013266
# Observed clones	9951.000000
# Observed clones + estimated clones	69530.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	46701
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	46701
# score_function 0.000000
# Log likelihood	-2783.882531
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	46701
# Log likelihood	-2783.882531
# Observed clones	9951.000000
# Observed clones + estimated clones	56652.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	37847
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	37847
# score_function 0.000000
# Log likelihood	-2858.780007
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	37847
# Log likelihood	-2858.780007
# Observed clones	9951.000000
# Observed clones + estimated clones	47798.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	31387
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	31387
# score_function 0.000000
# Log likelihood	-2913.819132
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	31387
# Log likelihood	-2913.819132
# Observed clones	9951.000000
# Observed clones + estimated clones	41338.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.5778313737312832, 0.025123103205707972]
# iteration 1
# old estimated n0	26465
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.5778313737312832, 0.025123103205707972]
# new estimated n_0	26465
# score_function 0.000000
# Log likelihood	-2955.973414
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.5778313737312832, 0.025123103205707972]
# Final estimated_n0	26465
# Log likelihood	-2955.973414
# Observed clones	9951.000000
# Observed clones + estimated clones	36416.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	188916
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	188916
# score_function 0.000000
# Log likelihood	-2066.054151
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	188916
# Log likelihood	-2066.054151
# Observed clones	9951.000000
# Observed clones + estimated clones	198867.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	101007
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	101007
# score_function 0.000000
# Log likelihood	-2974.233956
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	101007
# Log likelihood	-2974.233956
# Observed clones	9951.000000
# Observed clones + estimated clones	110958.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	66993
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	66993
# score_function 0.000000
# Log likelihood	-3351.276517
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	66993
# Log likelihood	-3351.276517
# Observed clones	9951.000000
# Observed clones + estimated clones	76944.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	48941
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	48941
# score_function 0.000000
# Log likelihood	-3557.735532
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	48941
# Log likelihood	-3557.735532
# Observed clones	9951.000000
# Observed clones + estimated clones	58892.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	37749
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	37749
# score_function 0.000000
# Log likelihood	-3688.032576
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	37749
# Log likelihood	-3688.032576
# Observed clones	9951.000000
# Observed clones + estimated clones	47700.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	30132
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	30132
# score_function 0.000000
# Log likelihood	-3777.752865
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	30132
# Log likelihood	-3777.752865
# Observed clones	9951.000000
# Observed clones + estimated clones	40083.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	24613
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	24613
# score_function 0.000000
# Log likelihood	-3843.298681
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	24613
# Log likelihood	-3843.298681
# Observed clones	9951.000000
# Observed clones + estimated clones	34564.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.7536930961712391, 0.025123103205707972]
# iteration 1
# old estimated n0	20429
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.7536930961712391, 0.025123103205707972]
# new estimated n_0	20429
# score_function 0.000000
# Log likelihood	-3893.281129
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.7536930961712391, 0.025123103205707972]
# Final estimated_n0	20429
# Log likelihood	-3893.281129
# Observed clones	9951.000000
# Observed clones + estimated clones	30380.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	174898
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	174898
# score_function 0.000000
# Log likelihood	-2635.594790
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	174898
# Log likelihood	-2635.594790
# Observed clones	9951.000000
# Observed clones + estimated clones	184849.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	90119
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	90119
# score_function 0.000000
# Log likelihood	-3760.658214
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	90119
# Log likelihood	-3760.658214
# Observed clones	9951.000000
# Observed clones + estimated clones	100070.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	58654
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	58654
# score_function 0.000000
# Log likelihood	-4214.945166
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	58654
# Log likelihood	-4214.945166
# Observed clones	9951.000000
# Observed clones + estimated clones	68605.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	42242
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	42242
# score_function 0.000000
# Log likelihood	-4460.750135
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	42242
# Log likelihood	-4460.750135
# Observed clones	9951.000000
# Observed clones + estimated clones	52193.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	32167
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	32167
# score_function 0.000000
# Log likelihood	-4614.837558
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	32167
# Log likelihood	-4614.837558
# Observed clones	9951.000000
# Observed clones + estimated clones	42118.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	25352
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	25352
# score_function 0.000000
# Log likelihood	-4720.479642
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	25352
# Log likelihood	-4720.479642
# Observed clones	9951.000000
# Observed clones + estimated clones	35303.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	20436
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	20436
# score_function 0.000000
# Log likelihood	-4797.422968
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	20436
# Log likelihood	-4797.422968
# Observed clones	9951.000000
# Observed clones + estimated clones	30387.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.9295548186111949, 0.025123103205707972]
# iteration 1
# old estimated n0	16721
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.9295548186111949, 0.025123103205707972]
# new estimated n_0	16721
# score_function 0.000000
# Log likelihood	-4855.964861
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.9295548186111949, 0.025123103205707972]
# Final estimated_n0	16721
# Log likelihood	-4855.964861
# Observed clones	9951.000000
# Observed clones + estimated clones	26672.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	164579
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	164579
# score_function 0.000000
# Log likelihood	-3210.365292
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	164579
# Log likelihood	-3210.365292
# Observed clones	9951.000000
# Observed clones + estimated clones	174530.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	82509
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	82509
# score_function 0.000000
# Log likelihood	-4557.075548
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	82509
# Log likelihood	-4557.075548
# Observed clones	9951.000000
# Observed clones + estimated clones	92460.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	52937
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	52937
# score_function 0.000000
# Log likelihood	-5092.885061
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	52937
# Log likelihood	-5092.885061
# Observed clones	9951.000000
# Observed clones + estimated clones	62888.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	37697
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	37697
# score_function 0.000000
# Log likelihood	-5381.073508
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	37697
# Log likelihood	-5381.073508
# Observed clones	9951.000000
# Observed clones + estimated clones	47648.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	28403
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	28403
# score_function 0.000000
# Log likelihood	-5561.138929
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	28403
# Log likelihood	-5561.138929
# Observed clones	9951.000000
# Observed clones + estimated clones	38354.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	22143
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	22143
# score_function 0.000000
# Log likelihood	-5684.335199
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	22143
# Log likelihood	-5684.335199
# Observed clones	9951.000000
# Observed clones + estimated clones	32094.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	17639
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	17639
# score_function 0.000000
# Log likelihood	-5773.934974
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	17639
# Log likelihood	-5773.934974
# Observed clones	9951.000000
# Observed clones + estimated clones	27590.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.1054165410511507, 0.025123103205707972]
# iteration 1
# old estimated n0	14244
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.1054165410511507, 0.025123103205707972]
# new estimated n_0	14244
# score_function 0.000000
# Log likelihood	-5842.034538
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.1054165410511507, 0.025123103205707972]
# Final estimated_n0	14244
# Log likelihood	-5842.034538
# Observed clones	9951.000000
# Observed clones + estimated clones	24195.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.012561551602853986, 0.025123103205707972]
# iteration 1
# old estimated n0	401353
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.012561551602853986, 0.025123103205707972]
# new estimated n_0	401353
# score_function 0.000000
# Log likelihood	-339.556004
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.012561551602853986, 0.025123103205707972]
# Final estimated_n0	401353
# Log likelihood	-339.556004
# Observed clones	9951.000000
# Observed clones + estimated clones	411304.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.012561551602853986, 0.025123103205707972]
# iteration 1
# old estimated n0	401353
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.012561551602853986, 0.025123103205707972]
# new estimated n_0	401353
# score_function 0.000000
# Log likelihood	-339.556004
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.012561551602853986, 0.025123103205707972]
# Final estimated_n0	401353
# Log likelihood	-339.556004
# Observed clones	9951.000000
# Observed clones + estimated clones	411304.000000
# === END FIT ===
#
# ([1.0], [0.025123103205707972], 391135, {1: 9904, 2: 45, 3: 2}, None, -340.5512427568028, 1.6330296993255615)

# %% [markdown]
# ### Mixed Poisson 100,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp1_100_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp1_100_000.tsv...
# 147756 95756.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.052216049124859026]
# iteration 1
# old estimated n0	1786381
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.052216049124859026]
# new estimated n_0	1786381
# score_function 0.000000
# Log likelihood	-18024.483978
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.052216049124859026]
# Final estimated_n0	1786381
# Log likelihood	-18024.483978
# Observed clones	95756.000000
# Observed clones + estimated clones	1882137.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.2349722210618656]
# iteration 1
# old estimated n0	361516
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.2349722210618656]
# new estimated n_0	361516
# score_function 0.000000
# Log likelihood	-20600.486602
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.2349722210618656]
# Final estimated_n0	361516
# Log likelihood	-20600.486602
# Observed clones	95756.000000
# Observed clones + estimated clones	457272.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.4177283929988722]
# iteration 1
# old estimated n0	184676
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.4177283929988722]
# new estimated n_0	184676
# score_function 0.000000
# Log likelihood	-27383.660368
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.4177283929988722]
# Final estimated_n0	184676
# Log likelihood	-27383.660368
# Observed clones	95756.000000
# Observed clones + estimated clones	280432.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6004845649358787]
# iteration 1
# old estimated n0	116350
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6004845649358787]
# new estimated n_0	116350
# score_function 0.000000
# Log likelihood	-35332.647620
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6004845649358787]
# Final estimated_n0	116350
# Log likelihood	-35332.647620
# Observed clones	95756.000000
# Observed clones + estimated clones	212106.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7832407368728853]
# iteration 1
# old estimated n0	80565
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7832407368728853]
# new estimated n_0	80565
# score_function 0.000000
# Log likelihood	-43955.875789
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7832407368728853]
# Final estimated_n0	80565
# Log likelihood	-43955.875789
# Observed clones	95756.000000
# Observed clones + estimated clones	176321.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.965996908809892]
# iteration 1
# old estimated n0	58840
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.965996908809892]
# new estimated n_0	58840
# score_function 0.000000
# Log likelihood	-53075.169590
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.965996908809892]
# Final estimated_n0	58840
# Log likelihood	-53075.169590
# Observed clones	95756.000000
# Observed clones + estimated clones	154596.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.1487530807468986]
# iteration 1
# old estimated n0	44450
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.1487530807468986]
# new estimated n_0	44450
# score_function 0.000000
# Log likelihood	-62603.623350
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.1487530807468986]
# Final estimated_n0	44450
# Log likelihood	-62603.623350
# Observed clones	95756.000000
# Observed clones + estimated clones	140206.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.026108024562429513]
# iteration 1
# old estimated n0	3620015
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.026108024562429513]
# new estimated n_0	3620015
# score_function 0.000000
# Log likelihood	-19708.042087
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.026108024562429513]
# Final estimated_n0	3620015
# Log likelihood	-19708.042087
# Observed clones	95756.000000
# Observed clones + estimated clones	3715771.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.026108024562429513]
# iteration 1
# old estimated n0	3620015
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.026108024562429513]
# new estimated n_0	3620015
# score_function 0.000000
# Log likelihood	-19708.042087
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.026108024562429513]
# Final estimated_n0	3620015
# Log likelihood	-19708.042087
# Observed clones	95756.000000
# Observed clones + estimated clones	3715771.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.052216049124859026, 0.052216049124859026]
# iteration 1
# old estimated n0	1786381
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.052216049124859026, 0.052216049124859026]
# new estimated n_0	1786381
# score_function 0.000000
# Log likelihood	-18024.483978
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.052216049124859026, 0.052216049124859026]
# Final estimated_n0	1786381
# Log likelihood	-18024.483978
# Observed clones	95756.000000
# Observed clones + estimated clones	1882137.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.052216049124859026, 0.052216049124859026]
# iteration 1
# old estimated n0	1786381
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.052216049124859026, 0.052216049124859026]
# new estimated n_0	1786381
# score_function 0.000000
# Log likelihood	-18024.483978
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.052216049124859026, 0.052216049124859026]
# Final estimated_n0	1786381
# Log likelihood	-18024.483978
# Observed clones	95756.000000
# Observed clones + estimated clones	1882137.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714,
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.6004845649358787, 0.052216049124859026]
# Final estimated_n0	483435
# Log likelihood	-29719.203037
# Observed clones	95756.000000
# Observed clones + estimated clones	579191.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.6004845649358787, 0.052216049124859026]
# iteration 1
# old estimated n0	390806
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.6004845649358787, 0.052216049124859026]
# new estimated n_0	390806
# score_function 0.000000
# Log likelihood	-31073.533719
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.6004845649358787, 0.052216049124859026]
# Final estimated_n0	390806
# Log likelihood	-31073.533719
# Observed clones	95756.000000
# Observed clones + estimated clones	486562.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.6004845649358787, 0.052216049124859026]
# iteration 1
# old estimated n0	323720
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.6004845649358787, 0.052216049124859026]
# new estimated n_0	323720
# score_function 0.000000
# Log likelihood	-32080.770465
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.6004845649358787, 0.052216049124859026]
# Final estimated_n0	323720
# Log likelihood	-32080.770465
# Observed clones	95756.000000
# Observed clones + estimated clones	419476.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.6004845649358787, 0.052216049124859026]
# iteration 1
# old estimated n0	272892
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.6004845649358787, 0.052216049124859026]
# new estimated n_0	272892
# score_function 0.000000
# Log likelihood	-32858.528426
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.6004845649358787, 0.052216049124859026]
# Final estimated_n0	272892
# Log likelihood	-32858.528426
# Observed clones	95756.000000
# Observed clones + estimated clones	368648.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.6004845649358787, 0.052216049124859026]
# iteration 1
# old estimated n0	233050
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.6004845649358787, 0.052216049124859026]
# new estimated n_0	233050
# score_function 0.000000
# Log likelihood	-33476.947401
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.6004845649358787, 0.052216049124859026]
# Final estimated_n0	233050
# Log likelihood	-33476.947401
# Observed clones	95756.000000
# Observed clones + estimated clones	328806.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.7832407368728853, 0.052216049124859026]
# iteration 1
# old estimated n0	1172766
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.7832407368728853, 0.052216049124859026]
# new estimated n_0	1172766
# score_function 0.000000
# Log likelihood	-23064.319383
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.7832407368728853, 0.052216049124859026]
# Final estimated_n0	1172766
# Log likelihood	-23064.319383
# Observed clones	95756.000000
# Observed clones + estimated clones	1268522.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.7832407368728853, 0.052216049124859026]
# iteration 1
# old estimated n0	743038
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.7832407368728853, 0.052216049124859026]
# new estimated n_0	743038
# score_function 0.000000
# Log likelihood	-30139.662997
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.7832407368728853, 0.052216049124859026]
# Final estimated_n0	743038
# Log likelihood	-30139.662997
# Observed clones	95756.000000
# Observed clones + estimated clones	838794.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.7832407368728853, 0.052216049124859026]
# iteration 1
# old estimated n0	530788
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.7832407368728853, 0.052216049124859026]
# new estimated n_0	530788
# score_function 0.000000
# Log likelihood	-34194.724976
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.7832407368728853, 0.052216049124859026]
# Final estimated_n0	530788
# Log likelihood	-34194.724976
# Observed clones	95756.000000
# Observed clones + estimated clones	626544.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.7832407368728853, 0.052216049124859026]
# iteration 1
# old estimated n0	404262
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.7832407368728853, 0.052216049124859026]
# new estimated n_0	404262
# score_function 0.000000
# Log likelihood	-36777.158820
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.7832407368728853, 0.052216049124859026]
# Final estimated_n0	404262
# Log likelihood	-36777.158820
# Observed clones	95756.000000
# Observed clones + estimated clones	500018.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.7832407368728853, 0.052216049124859026]
# iteration 1
# old estimated n0	320253
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429]
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.027857143, 0.529285717] [1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# new estimated n_0	189896
# score_function 0.000000
# Log likelihood	-56095.617411
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.027857143, 0.529285717]
# Fitted means	[1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# Final estimated_n0	189896
# Log likelihood	-56095.617411
# Observed clones	95756.000000
# Observed clones + estimated clones	285652.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.023928571500000002, 0.4546428585, 1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# iteration 1
# old estimated n0	153440
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.023928571500000002, 0.4546428585] [1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# new estimated n_0	153440
# score_function 0.000000
# Log likelihood	-57675.839213
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.023928571500000002, 0.4546428585]
# Fitted means	[1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# Final estimated_n0	153440
# Log likelihood	-57675.839213
# Observed clones	95756.000000
# Observed clones + estimated clones	249196.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.020000000000000004, 0.38, 1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# iteration 1
# old estimated n0	125235
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.020000000000000004, 0.38] [1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# new estimated n_0	125235
# score_function 0.000000
# Log likelihood	-58921.220282
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.020000000000000004, 0.38]
# Fitted means	[1.1487530807468986, 0.2349722210618656, 0.052216049124859026]
# Final estimated_n0	125235
# Log likelihood	-58921.220282
# Observed clones	95756.000000
# Observed clones + estimated clones	220991.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.026108024562429513, 0.2349722210618656, 0.052216049124859026]
# iteration 1
# old estimated n0	1579731
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.026108024562429513, 0.2349722210618656, 0.052216049124859026]
# new estimated n_0	1579731
# score_function 0.000000
# Log likelihood	-17576.355960
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.026108024562429513, 0.2349722210618656, 0.052216049124859026]
# Final estimated_n0	1579731
# Log likelihood	-17576.355960
# Observed clones	95756.000000
# Observed clones + estimated clones	1675487.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.026108024562429513, 0.2349722210618656, 0.052216049124859026]
# iteration 1
# old estimated n0	1579731
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.026108024562429513, 0.2349722210618656, 0.052216049124859026]
# new estimated n_0	1579731
# score_function 0.000000
# Log likelihood	-17576.355960
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.026108024562429513, 0.2349722210618656, 0.052216049124859026]
# Final estimated_n0	1579731
# Log likelihood	-17576.355960
# Observed clones	95756.000000
# Observed clones + estimated clones	1675487.000000
# === END FIT ===
#
# ([0.05, 0.95], [0.2349722210618656, 0.052216049124859026], 1532671, {1: 91615, 2: 4039, 3: 101, 4: 1}, None, -17573.494398656767, 2.5627551078796387)

# %% [markdown]
# ### Mixed Poisson 300,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp1_300_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp1_300_000.tsv...
# 388047 263668.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.056889724957143076]
# iteration 1
# old estimated n0	4504137
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.056889724957143076]
# new estimated n_0	4504137
# score_function 0.000000
# Log likelihood	-138007.900583
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.056889724957143076]
# Final estimated_n0	4504137
# Log likelihood	-138007.900583
# Observed clones	263668.000000
# Observed clones + estimated clones	4767805.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.4551177996571446]
# iteration 1
# old estimated n0	457472
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.4551177996571446]
# new estimated n_0	457472
# score_function 0.000000
# Log likelihood	-117193.749335
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.4551177996571446]
# Final estimated_n0	457472
# Log likelihood	-117193.749335
# Observed clones	263668.000000
# Observed clones + estimated clones	721140.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6542318370071453]
# iteration 1
# old estimated n0	285459
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6542318370071453]
# new estimated n_0	285459
# score_function 0.000000
# Log likelihood	-132672.625084
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6542318370071453]
# Final estimated_n0	285459
# Log likelihood	-132672.625084
# Observed clones	263668.000000
# Observed clones + estimated clones	549127.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.853345874357146]
# iteration 1
# old estimated n0	195674
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.853345874357146]
# new estimated n_0	195674
# score_function 0.000000
# Log likelihood	-152535.589398
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.853345874357146]
# Final estimated_n0	195674
# Log likelihood	-152535.589398
# Observed clones	263668.000000
# Observed clones + estimated clones	459342.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.052459911707147]
# iteration 1
# old estimated n0	141400
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.052459911707147]
# new estimated n_0	141400
# score_function 0.000000
# Log likelihood	-175272.574008
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.052459911707147]
# Final estimated_n0	141400
# Log likelihood	-175272.574008
# Observed clones	263668.000000
# Observed clones + estimated clones	405068.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.2515739490571478]
# iteration 1
# old estimated n0	105643
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.2515739490571478]
# new estimated n_0	105643
# score_function 0.000000
# Log likelihood	-200158.517320
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.2515739490571478]
# Final estimated_n0	105643
# Log likelihood	-200158.517320
# Observed clones	263668.000000
# Observed clones + estimated clones	369311.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.12800188115357192]
# iteration 1
# old estimated n0	1930854
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.12800188115357192]
# new estimated n_0	1930854
# score_function 0.000000
# Log likelihood	-118064.606923
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.12800188115357192]
# Final estimated_n0	1930854
# Log likelihood	-118064.606923
# Observed clones	263668.000000
# Observed clones + estimated clones	2194522.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.29155984040535826]
# iteration 1
# old estimated n0	778899
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.29155984040535826]
# new estimated n_0	778899
# score_function 0.000000
# Log likelihood	-110471.857163
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.29155984040535826]
# Final estimated_n0	778899
# Log likelihood	-110471.857163
# Observed clones	263668.000000
# Observed clones + estimated clones	1042567.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	949530
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	949530
# score_function 0.000000
# Log likelihood	-110311.761137
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	949530
# Log likelihood	-110311.761137
# Observed clones	263668.000000
# Observed clones + estimated clones	1213198.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	1029254
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	1029254
# score_function 0.000000
# Log likelihood	-110348.420941
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	1029254
# Log likelihood	-110348.420941
# Observed clones	263668.000000
# Observed clones + estimated clones	1292922.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	1120192
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	1120192
# score_function 0.000000
# Log likelihood	-110404.462223
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	1120192
# Log likelihood	-110404.462223
# Observed clones	263668.000000
# Observed clones + estimated clones	1383860.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	1224891
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	1224891
# score_function 0.000000
# Log likelihood	-110488.447887
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	1224891
# Log likelihood	-110488.447887
# Observed clones	263668.000000
# Observed clones + estimated clones	1488559.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	1346728
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	1346728
# score_function 0.000000
# Log likelihood	-110613.561284
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	1346728
# Log likelihood	-110613.561284
# Observed clones	263668.000000
# Observed clones + estimated clones	1610396.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	1490288
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	1490288
# score_function 0.000000
# Log likelihood	-110800.788765
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	1490288
# Log likelihood	-110800.788765
# Observed clones	263668.000000
# Observed clones + estimated clones	1753956.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	1661949
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	1661949
# score_function 0.000000
# Log likelihood	-111084.930833
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	1661949
# Log likelihood	-111084.930833
# Observed clones	263668.000000
# Observed clones + estimated clones	1925617.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.056889724957143076, 0.25600376230714383]
# iteration 1
# old estimated n0	1870856
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.056889724957143076, 0.25600376230714383]
# new estimated n_0	1870856
# score_function 0.000000
# Log likelihood	-111526.718375
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.056889724957143076, 0.25600376230714383]
# Final estimated_n0	1870856
# Log likelihood	-111526.718375
# Observed clones	263668.000000
# Observed clones + estimated clones	2134524.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.25600376230714383, 0.25600376230714383]
# iteration 1
# old estimated n0	903723
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.25600376230714383, 0.25600376230714383]
# new estimated n_0	903723
# score_function 0.000000
# Log likelihood	-110295.823241
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.25600376230714383, 0.25600376230714383]
# Final estimated_n0	903723
# Log likelihood	-110295.823241
# Observed clones	263668.000000
# Observed clones + estimated clones	1167391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.4551177996571446, 0.25600376230714383]
# iteration 1
# old estimated n0	868687
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.4551177996571446, 0.25600376230714383]
# new estimated n_0	868687
# score_function 0.000000
# Log likelihood	-110313.698583
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.6542318370071453, 0.25600376230714383]
# Final estimated_n0	756102
# Log likelihood	-112211.441636
# Observed clones	263668.000000
# Observed clones + estimated clones	1019770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.6542318370071453, 0.25600376230714383]
# iteration 1
# old estimated n0	682950
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.6542318370071453, 0.25600376230714383]
# new estimated n_0	682950
# score_function 0.000000
# Log likelihood	-114224.049144
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.6542318370071453, 0.25600376230714383]
# Final estimated_n0	682950
# Log likelihood	-114224.049144
# Observed clones	263668.000000
# Observed clones + estimated clones	946618.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.6542318370071453, 0.25600376230714383]
# iteration 1
# old estimated n0	619590
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.6542318370071453, 0.25600376230714383]
# new estimated n_0	619590
# score_function 0.000000
# Log likelihood	-116379.688264
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.6542318370071453, 0.25600376230714383]
# Final estimated_n0	619590
# Log likelihood	-116379.688264
# Observed clones	263668.000000
# Observed clones + estimated clones	883258.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.6542318370071453, 0.25600376230714383]
# iteration 1
# old estimated n0	564180
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.6542318370071453, 0.25600376230714383]
# new estimated n_0	564180
# score_function 0.000000
# Log likelihood	-118539.385234
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.6542318370071453, 0.25600376230714383]
# Final estimated_n0	564180
# Log likelihood	-118539.385234
# Observed clones	263668.000000
# Observed clones + estimated clones	827848.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.6542318370071453, 0.25600376230714383]
# iteration 1
# old estimated n0	515312
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.6542318370071453, 0.25600376230714383]
# new estimated n_0	515312
# score_function 0.000000
# Log likelihood	-120638.246303
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.6542318370071453, 0.25600376230714383]
# Final estimated_n0	515312
# Log likelihood	-120638.246303
# Observed clones	263668.000000
# Observed clones + estimated clones	778980.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.6542318370071453, 0.25600376230714383]
# iteration 1
# old estimated n0	471892
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.6542318370071453, 0.25600376230714383]
# new estimated n_0	471892
# score_function 0.000000
# Log likelihood	-122646.260008
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.6542318370071453, 0.25600376230714383]
# Final estimated_n0	471892
# Log likelihood	-122646.260008
# Observed clones	263668.000000
# Observed clones + estimated clones	735560.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.6542318370071453, 0.25600376230714383]
# iteration 1
# old estimated n0	433056
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.6542318370071453, 0.25600376230714383]
# new estimated n_0	433056
# score_function 0.000000
# Log likelihood	-124551.081752
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.6542318370071453, 0.25600376230714383]
# Final estimated_n0	433056
# Log likelihood	-124551.081752
# Observed clones	263668.000000
# Observed clones + estimated clones	696724.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	820188
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	820188
# score_function 0.000000
# Log likelihood	-111548.179570
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	820188
# Log likelihood	-111548.179570
# Observed clones	263668.000000
# Observed clones + estimated clones	1083856.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	710631
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	710631
# score_function 0.000000
# Log likelihood	-115484.865355
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	710631
# Log likelihood	-115484.865355
# Observed clones	263668.000000
# Observed clones + estimated clones	974299.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	621189
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	621189
# score_function 0.000000
# Log likelihood	-119963.105105
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	621189
# Log likelihood	-119963.105105
# Observed clones	263668.000000
# Observed clones + estimated clones	884857.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	546788
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	546788
# score_function 0.000000
# Log likelihood	-124388.308654
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	546788
# Log likelihood	-124388.308654
# Observed clones	263668.000000
# Observed clones + estimated clones	810456.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	483928
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	483928
# score_function 0.000000
# Log likelihood	-128572.484787
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	483928
# Log likelihood	-128572.484787
# Observed clones	263668.000000
# Observed clones + estimated clones	747596.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	430118
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	430118
# score_function 0.000000
# Log likelihood	-132460.002653
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	430118
# Log likelihood	-132460.002653
# Observed clones	263668.000000
# Observed clones + estimated clones	693786.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	383533
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	383533
# score_function 0.000000
# Log likelihood	-136045.869038
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	383533
# Log likelihood	-136045.869038
# Observed clones	263668.000000
# Observed clones + estimated clones	647201.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.853345874357146, 0.25600376230714383]
# iteration 1
# old estimated n0	342811
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.853345874357146, 0.25600376230714383]
# new estimated n_0	342811
# score_function 0.000000
# Log likelihood	-139345.134225
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.853345874357146, 0.25600376230714383]
# Final estimated_n0	342811
# Log likelihood	-139345.134225
# Observed clones	263668.000000
# Observed clones + estimated clones	606479.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	803321
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	803321
# score_function 0.000000
# Log likelihood	-112988.575916
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	803321
# Log likelihood	-112988.575916
# Observed clones	263668.000000
# Observed clones + estimated clones	1066989.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	676286
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	676286
# score_function 0.000000
# Log likelihood	-120086.855066
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	676286
# Log likelihood	-120086.855066
# Observed clones	263668.000000
# Observed clones + estimated clones	939954.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	576282
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	576282
# score_function 0.000000
# Log likelihood	-127528.009538
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	576282
# Log likelihood	-127528.009538
# Observed clones	263668.000000
# Observed clones + estimated clones	839950.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	495511
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	495511
# score_function 0.000000
# Log likelihood	-134542.641506
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	495511
# Log likelihood	-134542.641506
# Observed clones	263668.000000
# Observed clones + estimated clones	759179.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	428911
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	428911
# score_function 0.000000
# Log likelihood	-140962.112099
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	428911
# Log likelihood	-140962.112099
# Observed clones	263668.000000
# Observed clones + estimated clones	692579.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	373054
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	373054
# score_function 0.000000
# Log likelihood	-146781.463151
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	373054
# Log likelihood	-146781.463151
# Observed clones	263668.000000
# Observed clones + estimated clones	636722.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	325534
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	325534
# score_function 0.000000
# Log likelihood	-152045.772791
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	325534
# Log likelihood	-152045.772791
# Observed clones	263668.000000
# Observed clones + estimated clones	589202.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.052459911707147, 0.25600376230714383]
# iteration 1
# old estimated n0	284615
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.052459911707147, 0.25600376230714383]
# new estimated n_0	284615
# score_function 0.000000
# Log likelihood	-156812.884403
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.052459911707147, 0.25600376230714383]
# Final estimated_n0	284615
# Log likelihood	-156812.884403
# Observed clones	263668.000000
# Observed clones + estimated clones	548283.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	789886
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	789886
# score_function 0.000000
# Log likelihood	-114896.465525
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	789886
# Log likelihood	-114896.465525
# Observed clones	263668.000000
# Observed clones + estimated clones	1053554.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	649896
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	649896
# score_function 0.000000
# Log likelihood	-125629.320864
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	649896
# Log likelihood	-125629.320864
# Observed clones	263668.000000
# Observed clones + estimated clones	913564.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	542744
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	542744
# score_function 0.000000
# Log likelihood	-136300.823097
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	542744
# Log likelihood	-136300.823097
# Observed clones	263668.000000
# Observed clones + estimated clones	806412.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	458090
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	458090
# score_function 0.000000
# Log likelihood	-146077.501155
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	458090
# Log likelihood	-146077.501155
# Observed clones	263668.000000
# Observed clones + estimated clones	721758.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	389520
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	389520
# score_function 0.000000
# Log likelihood	-154858.382044
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	389520
# Log likelihood	-154858.382044
# Observed clones	263668.000000
# Observed clones + estimated clones	653188.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	332849
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	332849
# score_function 0.000000
# Log likelihood	-162711.755882
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	332849
# Log likelihood	-162711.755882
# Observed clones	263668.000000
# Observed clones + estimated clones	596517.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	285226
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	285226
# score_function 0.000000
# Log likelihood	-169743.821613
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	285226
# Log likelihood	-169743.821613
# Observed clones	263668.000000
# Observed clones + estimated clones	548894.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.2515739490571478, 0.25600376230714383]
# iteration 1
# old estimated n0	244645
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.2515739490571478, 0.25600376230714383]
# new estimated n_0	244645
# score_function 0.000000
# Log likelihood	-176060.776886
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.2515739490571478, 0.25600376230714383]
# Final estimated_n0	244645
# Log likelihood	-176060.776886
# Observed clones	263668.000000
# Observed clones + estimated clones	508313.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.12800188115357192, 0.25600376230714383]
# iteration 1
# old estimated n0	931697
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.12800188115357192, 0.25600376230714383]
# new estimated n_0	931697
# score_function 0.000000
# Log likelihood	-110317.318745
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.12800188115357192, 0.25600376230714383]
# Final estimated_n0	931697
# Log likelihood	-110317.318745
# Observed clones	263668.000000
# Observed clones + estimated clones	1195365.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.12857143000000001, 0.87142857, 0.19200282173035788, 0.25600376230714383]
# iteration 1
# old estimated n0	938744
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.87142857] [0.19200282173035788, 0.25600376230714383]
# new estimated n_0	938744
# score_function 0.000000
# Log likelihood	-110339.705574
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.87142857]
# Fitted means	[0.19200282173035788, 0.25600376230714383]
# Final estimated_n0	938744
# Log likelihood	-110339.705574
# Observed clones	263668.000000
# Observed clones + estimated clones	1202412.000000
# === END FIT ===
#
# ([1.0], [0.25600376230714383], 903723, {1: 230038, 2: 31069, 3: 2429, 4: 123, 5: 9}, None, -110295.82324050105, 1.2751388549804688)

# %% [markdown]
# ### Mixed Poisson 1,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp1_1_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp1_1_000_000.tsv...
# 844932 659465.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.07581903512695898]
# iteration 1
# old estimated n0	8372315
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.07581903512695898]
# new estimated n_0	8372315
# score_function 0.000000
# Log likelihood	-1175428.898132
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.07581903512695898]
# Final estimated_n0	8372315
# Log likelihood	-1175428.898132
# Observed clones	659465.000000
# Observed clones + estimated clones	9031780.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.3411856580713154]
# iteration 1
# old estimated n0	1621844
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.3411856580713154]
# new estimated n_0	1621844
# score_function 0.000000
# Log likelihood	-753775.471467
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.3411856580713154]
# Final estimated_n0	1621844
# Log likelihood	-753775.471467
# Observed clones	659465.000000
# Observed clones + estimated clones	2281309.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.6065522810156718]
# iteration 1
# old estimated n0	790633
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.6065522810156718]
# new estimated n_0	790633
# score_function 0.000000
# Log likelihood	-652226.714804
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.6065522810156718]
# Final estimated_n0	790633
# Log likelihood	-652226.714804
# Observed clones	659465.000000
# Observed clones + estimated clones	1450098.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.1372855269043847]
# iteration 1
# old estimated n0	311319
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.1372855269043847]
# new estimated n_0	311319
# score_function 0.000000
# Log likelihood	-638249.856296
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.1372855269043847]
# Final estimated_n0	311319
# Log likelihood	-638249.856296
# Observed clones	659465.000000
# Observed clones + estimated clones	970784.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.4026521498487412]
# iteration 1
# old estimated n0	215092
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.4026521498487412]
# new estimated n_0	215092
# score_function 0.000000
# Log likelihood	-672368.804510
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.4026521498487412]
# Final estimated_n0	215092
# Log likelihood	-672368.804510
# Observed clones	659465.000000
# Observed clones + estimated clones	874557.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.6680187727930977]
# iteration 1
# old estimated n0	153305
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.6680187727930977]
# new estimated n_0	153305
# score_function 0.000000
# Log likelihood	-722415.514996
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.6680187727930977]
# Final estimated_n0	153305
# Log likelihood	-722415.514996
# Observed clones	659465.000000
# Observed clones + estimated clones	812770.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.43595945198001407]
# iteration 1
# old estimated n0	1206825
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.43595945198001407]
# new estimated n_0	1206825
# score_function 0.000000
# Log likelihood	-703571.361129
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.43595945198001407]
# Final estimated_n0	1206825
# Log likelihood	-703571.361129
# Observed clones	659465.000000
# Observed clones + estimated clones	1866290.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.7866224894421994]
# iteration 1
# old estimated n0	551407
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.7866224894421994]
# new estimated n_0	551407
# score_function 0.000000
# Log likelihood	-629914.384220
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.7866224894421994]
# Final estimated_n0	551407
# Log likelihood	-629914.384220
# Observed clones	659465.000000
# Observed clones + estimated clones	1210872.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	525750
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	525750
# score_function 0.000000
# Log likelihood	-626976.170846
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	525750
# Log likelihood	-626976.170846
# Observed clones	659465.000000
# Observed clones + estimated clones	1185215.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	617504
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	617504
# score_function 0.000000
# Log likelihood	-627278.026343
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	617504
# Log likelihood	-627278.026343
# Observed clones	659465.000000
# Observed clones + estimated clones	1276969.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	724657
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	724657
# score_function 0.000000
# Log likelihood	-627687.120839
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	724657
# Log likelihood	-627687.120839
# Observed clones	659465.000000
# Observed clones + estimated clones	1384122.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	851441
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	851441
# score_function 0.000000
# Log likelihood	-628250.856201
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	851441
# Log likelihood	-628250.856201
# Observed clones	659465.000000
# Observed clones + estimated clones	1510906.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	1003792
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	1003792
# score_function 0.000000
# Log likelihood	-629044.300409
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	1003792
# Log likelihood	-629044.300409
# Observed clones	659465.000000
# Observed clones + estimated clones	1663257.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	1190314
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	1190314
# score_function 0.000000
# Log likelihood	-630191.538130
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	1190314
# Log likelihood	-630191.538130
# Observed clones	659465.000000
# Observed clones + estimated clones	1849779.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	1423954
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	1423954
# score_function 0.000000
# Log likelihood	-631908.800779
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	1423954
# Log likelihood	-631908.800779
# Observed clones	659465.000000
# Observed clones + estimated clones	2083419.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.07581903512695898, 0.8719189039600281]
# iteration 1
# old estimated n0	1725147
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.07581903512695898, 0.8719189039600281]
# new estimated n_0	1725147
# score_function 0.000000
# Log likelihood	-634598.967487
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.07581903512695898, 0.8719189039600281]
# Final estimated_n0	1725147
# Log likelihood	-634598.967487
# Observed clones	659465.000000
# Observed clones + estimated clones	2384612.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	503176
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	503176
# score_function 0.000000
# Log likelihood	-627184.429612
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	503176
# Log likelihood	-627184.429612
# Observed clones	659465.000000
# Observed clones + estimated clones	1162641.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	552322
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	552322
# score_function 0.000000
# Log likelihood	-627988.374610
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	552322
# Log likelihood	-627988.374610
# Observed clones	659465.000000
# Observed clones + estimated clones	1211787.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	605806
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	605806
# score_function 0.000000
# Log likelihood	-629156.848928
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	605806
# Log likelihood	-629156.848928
# Observed clones	659465.000000
# Observed clones + estimated clones	1265271.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	664229
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	664229
# score_function 0.000000
# Log likelihood	-630796.034512
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	664229
# Log likelihood	-630796.034512
# Observed clones	659465.000000
# Observed clones + estimated clones	1323694.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	728308
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	728308
# score_function 0.000000
# Log likelihood	-633049.610280
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	728308
# Log likelihood	-633049.610280
# Observed clones	659465.000000
# Observed clones + estimated clones	1387773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	798907
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	798907
# score_function 0.000000
# Log likelihood	-636115.967623
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	798907
# Log likelihood	-636115.967623
# Observed clones	659465.000000
# Observed clones + estimated clones	1458372.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	877074
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	877074
# score_function 0.000000
# Log likelihood	-640275.924207
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	877074
# Log likelihood	-640275.924207
# Observed clones	659465.000000
# Observed clones + estimated clones	1536539.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.3411856580713154, 0.8719189039600281]
# iteration 1
# old estimated n0	964095
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.3411856580713154, 0.8719189039600281]
# new estimated n_0	964095
# score_function 0.000000
# Log likelihood	-645939.600375
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.3411856580713154, 0.8719189039600281]
# Final estimated_n0	964095
# Log likelihood	-645939.600375
# Observed clones	659465.000000
# Observed clones + estimated clones	1623560.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	486439
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	486439
# score_function 0.000000
# Log likelihood	-627045.860592
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	486439
# Log likelihood	-627045.860592
# Observed clones	659465.000000
# Observed clones + estimated clones	1145904.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	506671
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	506671
# score_function 0.000000
# Log likelihood	-627512.005644
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	506671
# Log likelihood	-627512.005644
# Observed clones	659465.000000
# Observed clones + estimated clones	1166136.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	527631
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	527631
# score_function 0.000000
# Log likelihood	-628141.561488
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	527631
# Log likelihood	-628141.561488
# Observed clones	659465.000000
# Observed clones + estimated clones	1187096.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	549357
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	549357
# score_function 0.000000
# Log likelihood	-628957.327913
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	549357
# Log likelihood	-628957.327913
# Observed clones	659465.000000
# Observed clones + estimated clones	1208822.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	571894
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	571894
# score_function 0.000000
# Log likelihood	-629986.138068
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	571894
# Log likelihood	-629986.138068
# Observed clones	659465.000000
# Observed clones + estimated clones	1231359.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	595288
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	595288
# score_function 0.000000
# Log likelihood	-631259.846656
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	595288
# Log likelihood	-631259.846656
# Observed clones	659465.000000
# Observed clones + estimated clones	1254753.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	619587
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	619587
# score_function 0.000000
# Log likelihood	-632816.654566
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	619587
# Log likelihood	-632816.654566
# Observed clones	659465.000000
# Observed clones + estimated clones	1279052.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.6065522810156718, 0.8719189039600281]
# iteration 1
# old estimated n0	644846
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.6065522810156718, 0.8719189039600281]
# new estimated n_0	644846
# score_function 0.000000
# Log likelihood	-634702.932473
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.6065522810156718, 0.8719189039600281]
# Final estimated_n0	644846
# Log likelihood	-634702.932473
# Observed clones	659465.000000
# Observed clones + estimated clones	1304311.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.8719189039600281, 0.8719189039600281]
# iteration 1
# old estimated n0	473925
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.8719189039600281, 0.8719189039600281]
# new estimated n_0	473925
# score_function 0.000000
# Log likelihood	-626825.256232
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.8719189039600281, 0.8719189039600281]
# Final estimated_n0	473925
# Log likelihood	-626825.256232
# Observed clones	659465.000000
# Observed clones + estimated clones	1133390.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	464512
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	464512
# score_function 0.000000
# Log likelihood	-626756.447861
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	464512
# Log likelihood	-626756.447861
# Observed clones	659465.000000
# Observed clones + estimated clones	1123977.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	450032
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	450032
# score_function 0.000000
# Log likelihood	-626857.087536
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	450032
# Log likelihood	-626857.087536
# Observed clones	659465.000000
# Observed clones + estimated clones	1109497.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	435919
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	435919
# score_function 0.000000
# Log likelihood	-627181.232178
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	435919
# Log likelihood	-627181.232178
# Observed clones	659465.000000
# Observed clones + estimated clones	1095384.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	422162
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	422162
# score_function 0.000000
# Log likelihood	-627699.384213
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	422162
# Log likelihood	-627699.384213
# Observed clones	659465.000000
# Observed clones + estimated clones	1081627.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	408746
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	408746
# score_function 0.000000
# Log likelihood	-628387.381194
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	408746
# Log likelihood	-628387.381194
# Observed clones	659465.000000
# Observed clones + estimated clones	1068211.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	395658
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	395658
# score_function 0.000000
# Log likelihood	-629225.073688
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	395658
# Log likelihood	-629225.073688
# Observed clones	659465.000000
# Observed clones + estimated clones	1055123.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	382887
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	382887
# score_function 0.000000
# Log likelihood	-630195.421774
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	382887
# Log likelihood	-630195.421774
# Observed clones	659465.000000
# Observed clones + estimated clones	1042352.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	370422
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.1372855269043847, 0.8719189039600281]
# new estimated n_0	370422
# score_function 0.000000
# Log likelihood	-631283.851583
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	370422
# Log likelihood	-631283.851583
# Observed clones	659465.000000
# Observed clones + estimated clones	1029887.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	457398
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	457398
# score_function 0.000000
# Log likelihood	-627019.115143
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	457398
# Log likelihood	-627019.115143
# Observed clones	659465.000000
# Observed clones + estimated clones	1116863.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	432379
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	432379
# score_function 0.000000
# Log likelihood	-628238.868336
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	432379
# Log likelihood	-628238.868336
# Observed clones	659465.000000
# Observed clones + estimated clones	1091844.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	408456
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	408456
# score_function 0.000000
# Log likelihood	-630303.216463
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	408456
# Log likelihood	-630303.216463
# Observed clones	659465.000000
# Observed clones + estimated clones	1067921.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	385558
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	385558
# score_function 0.000000
# Log likelihood	-633010.107068
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	385558
# Log likelihood	-633010.107068
# Observed clones	659465.000000
# Observed clones + estimated clones	1045023.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	363622
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	363622
# score_function 0.000000
# Log likelihood	-636222.289893
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	363622
# Log likelihood	-636222.289893
# Observed clones	659465.000000
# Observed clones + estimated clones	1023087.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	342588
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	342588
# score_function 0.000000
# Log likelihood	-639840.578105
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	342588
# Log likelihood	-639840.578105
# Observed clones	659465.000000
# Observed clones + estimated clones	1002053.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	322402
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	322402
# score_function 0.000000
# Log likelihood	-643790.333959
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	322402
# Log likelihood	-643790.333959
# Observed clones	659465.000000
# Observed clones + estimated clones	981867.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.4026521498487412, 0.8719189039600281]
# iteration 1
# old estimated n0	303013
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.4026521498487412, 0.8719189039600281]
# new estimated n_0	303013
# score_function 0.000000
# Log likelihood	-648013.744715
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.4026521498487412, 0.8719189039600281]
# Final estimated_n0	303013
# Log likelihood	-648013.744715
# Observed clones	659465.000000
# Observed clones + estimated clones	962478.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	452003
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	452003
# score_function 0.000000
# Log likelihood	-627734.852991
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	452003
# Log likelihood	-627734.852991
# Observed clones	659465.000000
# Observed clones + estimated clones	1111468.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	419216
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	419216
# score_function 0.000000
# Log likelihood	-631236.674838
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	419216
# Log likelihood	-631236.674838
# Observed clones	659465.000000
# Observed clones + estimated clones	1078681.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	388308
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	388308
# score_function 0.000000
# Log likelihood	-636395.121992
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	388308
# Log likelihood	-636395.121992
# Observed clones	659465.000000
# Observed clones + estimated clones	1047773.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	359122
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	359122
# score_function 0.000000
# Log likelihood	-642690.171274
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	359122
# Log likelihood	-642690.171274
# Observed clones	659465.000000
# Observed clones + estimated clones	1018587.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	331518
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	331518
# score_function 0.000000
# Log likelihood	-649816.588014
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	331518
# Log likelihood	-649816.588014
# Observed clones	659465.000000
# Observed clones + estimated clones	990983.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	305371
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	305371
# score_function 0.000000
# Log likelihood	-657575.150576
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	305371
# Log likelihood	-657575.150576
# Observed clones	659465.000000
# Observed clones + estimated clones	964836.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	280568
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	280568
# score_function 0.000000
# Log likelihood	-665827.481103
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	280568
# Log likelihood	-665827.481103
# Observed clones	659465.000000
# Observed clones + estimated clones	940033.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.6680187727930977, 0.8719189039600281]
# iteration 1
# old estimated n0	257008
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.6680187727930977, 0.8719189039600281]
# new estimated n_0	257008
# score_function 0.000000
# Log likelihood	-674473.390065
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.6680187727930977, 0.8719189039600281]
# Final estimated_n0	257008
# Log likelihood	-674473.390065
# Observed clones	659465.000000
# Observed clones + estimated clones	916473.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.43595945198001407, 0.8719189039600281]
# iteration 1
# old estimated n0	496625
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.43595945198001407, 0.8719189039600281]
# new estimated n_0	496625
# score_function 0.000000
# Log likelihood	-627161.096771
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.43595945198001407, 0.8719189039600281]
# Final estimated_n0	496625
# Log likelihood	-627161.096771
# Observed clones	659465.000000
# Observed clones + estimated clones	1156090.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.6539391779700211, 0.8719189039600281]
# iteration 1
# old estimated n0	483932
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.6539391779700211, 0.8719189039600281]
# new estimated n_0	483932
# score_function 0.000000
# Log likelihood	-627005.055503
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.6539391779700211, 0.8719189039600281]
# Final estimated_n0	483932
# Log likelihood	-627005.055503
# Observed clones	659465.000000
# Observed clones + estimated clones	1143397.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.07581903512695898, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	515970
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.07581903512695898, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	515970
# score_function 0.000000
# Log likelihood	-626874.229134
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.07581903512695898, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	515970
# Log likelihood	-626874.229134
# Observed clones	659465.000000
# Observed clones + estimated clones	1175435.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 0.07581903512695898, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	607090
# ...
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	448710
# score_function 0.000000
# Log likelihood	-627161.145045
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	448710
# Log likelihood	-627161.145045
# Observed clones	659465.000000
# Observed clones + estimated clones	1108175.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	424756
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.04357142850000001, 0.8278571415] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	424756
# score_function 0.000000
# Log likelihood	-628597.859207
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.04357142850000001, 0.8278571415]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	424756
# Log likelihood	-628597.859207
# Observed clones	659465.000000
# Observed clones + estimated clones	1084221.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.039642857000000004, 0.7532142829999999, 1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	401815
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.039642857000000004, 0.7532142829999999] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	401815
# score_function 0.000000
# Log likelihood	-630787.003804
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.039642857000000004, 0.7532142829999999]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	401815
# Log likelihood	-630787.003804
# Observed clones	659465.000000
# Observed clones + estimated clones	1061280.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.0357142855, 0.6785714245, 1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	379826
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.0357142855, 0.6785714245] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	379826
# score_function 0.000000
# Log likelihood	-633556.515377
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.0357142855, 0.6785714245]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	379826
# Log likelihood	-633556.515377
# Observed clones	659465.000000
# Observed clones + estimated clones	1039291.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.0317857145, 0.6039285755, 1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	358729
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.0317857145, 0.6039285755] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	358729
# score_function 0.000000
# Log likelihood	-636787.060985
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.0317857145, 0.6039285755]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	358729
# Log likelihood	-636787.060985
# Observed clones	659465.000000
# Observed clones + estimated clones	1018194.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.027857143, 0.529285717, 1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	338472
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.027857143, 0.529285717] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	338472
# score_function 0.000000
# Log likelihood	-640391.167718
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.027857143, 0.529285717]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	338472
# Log likelihood	-640391.167718
# Observed clones	659465.000000
# Observed clones + estimated clones	997937.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.023928571500000002, 0.4546428585, 1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	319004
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.023928571500000002, 0.4546428585] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	319004
# score_function 0.000000
# Log likelihood	-644302.301173
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.023928571500000002, 0.4546428585]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	319004
# Log likelihood	-644302.301173
# Observed clones	659465.000000
# Observed clones + estimated clones	978469.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.020000000000000004, 0.38, 1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	300282
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.020000000000000004, 0.38] [1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	300282
# score_function 0.000000
# Log likelihood	-648468.479092
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.020000000000000004, 0.38]
# Fitted means	[1.4026521498487412, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	300282
# Log likelihood	-648468.479092
# Observed clones	659465.000000
# Observed clones + estimated clones	959747.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	443398
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	443398
# score_function 0.000000
# Log likelihood	-627978.584314
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	443398
# Log likelihood	-627978.584314
# Observed clones	659465.000000
# Observed clones + estimated clones	1102863.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.0435714285, 0.8278571414999999, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	411775
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.04357142850000001, 0.8278571415] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	411775
# score_function 0.000000
# Log likelihood	-631754.239305
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.04357142850000001, 0.8278571415]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	411775
# Log likelihood	-631754.239305
# Observed clones	659465.000000
# Observed clones + estimated clones	1071240.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.039642857000000004, 0.7532142829999999, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	381916
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.039642857000000004, 0.7532142829999999] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	381916
# score_function 0.000000
# Log likelihood	-637045.463763
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.039642857000000004, 0.7532142829999999]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	381916
# Log likelihood	-637045.463763
# Observed clones	659465.000000
# Observed clones + estimated clones	1041381.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.0357142855, 0.6785714245, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	353675
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.0357142855, 0.6785714245] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	353675
# score_function 0.000000
# Log likelihood	-643391.333857
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.0357142855, 0.6785714245]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	353675
# Log likelihood	-643391.333857
# Observed clones	659465.000000
# Observed clones + estimated clones	1013140.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.0317857145, 0.6039285755, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	326926
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.0317857145, 0.6039285755] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	326926
# score_function 0.000000
# Log likelihood	-650516.188023
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.0317857145, 0.6039285755]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	326926
# Log likelihood	-650516.188023
# Observed clones	659465.000000
# Observed clones + estimated clones	986391.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.027857143, 0.529285717, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	301553
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.027857143, 0.529285717] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	301553
# score_function 0.000000
# Log likelihood	-658237.982519
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.027857143, 0.529285717]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	301553
# Log likelihood	-658237.982519
# Observed clones	659465.000000
# Observed clones + estimated clones	961018.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.023928571500000002, 0.4546428585, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	277453
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.023928571500000002, 0.4546428585] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	277453
# score_function 0.000000
# Log likelihood	-666429.193479
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.023928571500000002, 0.4546428585]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	277453
# Log likelihood	-666429.193479
# Observed clones	659465.000000
# Observed clones + estimated clones	936918.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.020000000000000004, 0.38, 1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	254532
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.020000000000000004, 0.38] [1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	254532
# score_function 0.000000
# Log likelihood	-674996.877558
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.020000000000000004, 0.38]
# Fitted means	[1.6680187727930977, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	254532
# Log likelihood	-674996.877558
# Observed clones	659465.000000
# Observed clones + estimated clones	913997.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.0475, 0.9025, 0.43595945198001407, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	487319
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.0475, 0.9025] [0.43595945198001407, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	487319
# score_function 0.000000
# Log likelihood	-627003.413685
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.0475, 0.9025]
# Fitted means	[0.43595945198001407, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	487319
# Log likelihood	-627003.413685
# Observed clones	659465.000000
# Observed clones + estimated clones	1146784.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.08928571499999999, 0.04553571425, 0.8651785707499999, 0.6539391779700211, 1.1372855269043847, 0.8719189039600281]
# iteration 1
# old estimated n0	483067
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.089285715, 0.045535714250000005, 0.86517857075] [0.6539391779700211, 1.1372855269043847, 0.8719189039600281]
# new estimated n_0	483067
# score_function 0.000000
# Log likelihood	-627002.039619
#
# Completed iteration of clone sizes
# Fitted weights	[0.089285715, 0.045535714250000005, 0.86517857075]
# Fitted means	[0.6539391779700211, 1.1372855269043847, 0.8719189039600281]
# Final estimated_n0	483067
# Log likelihood	-627002.039619
# Observed clones	659465.000000
# Observed clones + estimated clones	1142532.000000
# === END FIT ===
#
# ([0.05, 0.95], [1.1372855269043847, 0.8719189039600281], 464512, {1: 397567, 2: 195834, 3: 54950, 4: 9785, 5: 1207, 6: 114, 7: 8}, None, -626756.447861084, 3.2601311206817627)

# %% [markdown]
# ### Mixed Poisson 2,000,000

# %%
# THIS CODE HAS TO BE RUN FIRST IN THE NOTEBOOK (AFTER THE IMPORTS)
# THEN THE CLASSES/FUNCTIONS CAN BE RUN - FUNCTIONS DEPEND ON THESE VARIABLES
# THIS IS ADAPTED FROM THE PARSER SECTION

aicc_multiple = 1.3
precomputed_error_bar_file = '' #file name for precomputed error bars
###
clone_distribution_in_file = True # input file is of the form clone_size tab number_of_clones of that size
###
bin_size = 1 # average number of observations for each individual
D_number_file = None # None or string, output of -D option
make_error_bars = False # make a precomputed error bar file that can be used to calculate error bars
fraction_small_clones = 0.1 # see get_sampling_limit
fit_file = None # Recon fit-file (output of -R option)
javascript_file = 'plot_clone_size_distribution_ref.js' # reference js file, for plotting resample
parameter_limit = 20 # maximum number of parameters to fit
min_number_of_doublets = 100 # see get_sampling_limit
number_of_error_bars = 2 # mapping between gold-standard error bar fits and standard deviations in power calculation
file_out = 'test_recon_output.txt' # output file for fit
make_power_table = False # ouput a table of cells required to see fold difference
q = 0. # Hill number parameter to use when making table for power calculations
resample = False # output a resampling of the model fit with the given fit file
noise_test_ratio_threshold = 3. # for avoiding fitting noise
sample_size = None # sample size, for calculating U_max
threshold = 30 # largest clone to fit using parameters. Any larger clones will be assumed to be statistically accurate between sample and overall population and added back in after the fit is performed
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
cutoff_score = 0.1 # for stopping iteration when estimated clone distribution is at a fixed point
###
verbose = True # print verbose output to stdout
very_verbose = False # print even more verbose output to stdout
###
make_resample_plot = False # plots resample of fit against original sample
total_clones_in_overall_population = None # total clones in an overall distribution. for use with plot_resample (optionally) and reconstruct_overall_distribution(optionally)
list_of_number_of_clones = [1e4, 3e4, 1e5, 1e6, 3e6] # column headers for power table
make_table_of_D_numbers = False # output a table of reconstructed D numbers with error bars from input fit files
list_of_fold_differences = [1.1, 1.2, 1.3, 1.4, 1.5, 2., 5.] # row titles for power table
N = None # overall population size, for calculating U_max
qs = [0., 1., 2., float('inf')] # space-separated list of Hill-number parameters for making error-bar files and table of D numbers
run_recon = True # run Recon on sample to generate overall distribution parameters and fit file
initial_scale_factors = [0.05, 0.225, 0.4, 0.575, 0.75 , 0.925, 1.1] # for determining means
resource_path = PATH # folder that contains style.css, d3.js, and plot_clone_size_distribution_ref.js
upper_bound = False # calculate U_max
test_weights_list = [0.05, 0.12857143, 0.20714286, 0.28571429, 0.36428571, 0.44285714, 0.52142857, 0.6] # list of weights to attempt to add
x_max = None # the x_max for the output plot
y_max = None # the y_max for the output plot (note, log scale)
###
file_in = ['df_fill_in_mp1_2_000_000.tsv'] # list of file names containing clone data. a long list of files can be conveniently input using a shell variable, e.g. MLE_files=$(ls);python recon.py file_out $MLE_files
###

if very_verbose: verbose = True

list_of_number_of_clones = list(map(float, list_of_number_of_clones))
list_of_fold_differences = list(map(float, list_of_fold_differences))
initial_scale_factors = list(map(float, initial_scale_factors))
test_weights_list = list(map(float, test_weights_list))
qs = list(map(float, qs))

## Formatting

# Handle file/directory names

if make_table_of_D_numbers:
    list_of_filenames = file_in

elif len(file_in) == 1:
    file_in = file_in[0]
    if make_error_bars:
        if not isdir(file_in):
            print('error: input file %s is not a directory. Input must be a directory containing the error bar fits when making error-bar files. exiting...' % file_in)
            exit()
        else:
            error_bar_fits_directory = file_in
            if not error_bar_fits_directory.endswith('/'):
                error_bar_fits_directory = error_bar_fits_directory + '/'
    else:
        if not isfile(file_in):
            print('error: input file %s does not exist. exiting...' % file_in)
            exit()

elif len(file_in) > 1:
    print('error: multiple files input, but this is allowed only for outputting table of D numbers. check the order of command-line parameters. exiting...')
    exit()

# %%
if run_recon: 
    print("running recon on %s..." % file_in)
    print(reconstruct_overall_distribution(file_in, file_out, total_clones_in_overall_population)) 
    # total_clones_in_overall_population passed just to record in
    # file_out. When this is a fit of a known overall distribution,
    # e.g. for error-bar fits, we will need this record of how many
    # clones there were in the overall population
# Out:
# running recon on df_fill_in_mp1_2_000_000.tsv...
# 1018711 906533.0
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.11031038031709822]
# iteration 1
# old estimated n0	7773086
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.11031038031709822]
# new estimated n_0	7773086
# score_function 0.000000
# Log likelihood	-3454156.384256
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.11031038031709822]
# Final estimated_n0	7773086
# Log likelihood	-3454156.384256
# Observed clones	906533.000000
# Observed clones + estimated clones	8679619.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.496396711426942]
# iteration 1
# old estimated n0	1410307
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.496396711426942]
# new estimated n_0	1410307
# score_function 0.000000
# Log likelihood	-1993326.206172
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.496396711426942]
# Final estimated_n0	1410307
# Log likelihood	-1993326.206172
# Observed clones	906533.000000
# Observed clones + estimated clones	2316840.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 0.8824830425367858]
# iteration 1
# old estimated n0	639803
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [0.8824830425367858]
# new estimated n_0	639803
# score_function 0.000000
# Log likelihood	-1559123.622687
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[0.8824830425367858]
# Final estimated_n0	639803
# Log likelihood	-1559123.622687
# Observed clones	906533.000000
# Observed clones + estimated clones	1546336.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.2685693736466293]
# iteration 1
# old estimated n0	354702
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.2685693736466293]
# new estimated n_0	354702
# score_function 0.000000
# Log likelihood	-1368061.578788
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.2685693736466293]
# Final estimated_n0	354702
# Log likelihood	-1368061.578788
# Observed clones	906533.000000
# Observed clones + estimated clones	1261235.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.6546557047564732]
# iteration 1
# old estimated n0	214246
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.6546557047564732]
# new estimated n_0	214246
# score_function 0.000000
# Log likelihood	-1293687.299317
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.6546557047564732]
# Final estimated_n0	214246
# Log likelihood	-1293687.299317
# Observed clones	906533.000000
# Observed clones + estimated clones	1120779.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 2.426828366976161]
# iteration 1
# old estimated n0	87818
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [2.426828366976161]
# new estimated n_0	87818
# score_function 0.000000
# Log likelihood	-1336204.936389
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[2.426828366976161]
# Final estimated_n0	87818
# Log likelihood	-1336204.936389
# Observed clones	906533.000000
# Observed clones + estimated clones	994351.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.0203710179331584]
# iteration 1
# old estimated n0	510946
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.0203710179331584]
# new estimated n_0	510946
# score_function 0.000000
# Log likelihood	-1472635.482607
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.0203710179331584]
# Final estimated_n0	510946
# Log likelihood	-1472635.482607
# Observed clones	906533.000000
# Observed clones + estimated clones	1417479.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [1.0, 1.3375133613448158]
# iteration 1
# old estimated n0	322660
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [1.0] [1.3375133613448158]
# new estimated n_0	322660
# score_function 0.000000
# Log likelihood	-1348044.629815
#
# Completed iteration of clone sizes
# Fitted weights	[1.0]
# Fitted means	[1.3375133613448158]
# Final estimated_n0	322660
# Log likelihood	-1348044.629815
# Observed clones	906533.000000
# Observed clones + estimated clones	1229193.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	183330
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	183330
# score_function 0.000000
# Log likelihood	-1290489.450465
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	183330
# Log likelihood	-1290489.450465
# Observed clones	906533.000000
# Observed clones + estimated clones	1089863.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	268295
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	268295
# score_function 0.000000
# Log likelihood	-1290824.177146
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	268295
# Log likelihood	-1290824.177146
# Observed clones	906533.000000
# Observed clones + estimated clones	1174828.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	367628
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	367628
# score_function 0.000000
# Log likelihood	-1291476.773534
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	367628
# Log likelihood	-1291476.773534
# Observed clones	906533.000000
# Observed clones + estimated clones	1274161.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	485311
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	485311
# score_function 0.000000
# Log likelihood	-1292604.959749
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	485311
# Log likelihood	-1292604.959749
# Observed clones	906533.000000
# Observed clones + estimated clones	1391844.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	626944
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	626944
# score_function 0.000000
# Log likelihood	-1294459.197683
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	626944
# Log likelihood	-1294459.197683
# Observed clones	906533.000000
# Observed clones + estimated clones	1533477.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	800667
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	800667
# score_function 0.000000
# Log likelihood	-1297452.469733
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	800667
# Log likelihood	-1297452.469733
# Observed clones	906533.000000
# Observed clones + estimated clones	1707200.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	1018780
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	1018780
# score_function 0.000000
# Log likelihood	-1302298.660964
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	1018780
# Log likelihood	-1302298.660964
# Observed clones	906533.000000
# Observed clones + estimated clones	1925313.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.11031038031709822, 2.040742035866317]
# iteration 1
# old estimated n0	1300790
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.11031038031709822, 2.040742035866317]
# new estimated n_0	1300790
# score_function 0.000000
# Log likelihood	-1310309.130606
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.11031038031709822, 2.040742035866317]
# Final estimated_n0	1300790
# Log likelihood	-1310309.130606
# Observed clones	906533.000000
# Observed clones + estimated clones	2207323.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	164856
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.496396711426942, 2.040742035866317]
# new estimated n_0	164856
# score_function 0.000000
# Log likelihood	-1290372.229559
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	164856
# Log likelihood	-1290372.229559
# Observed clones	906533.000000
# Observed clones + estimated clones	1071389.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	214707
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.496396711426942, 2.040742035866317]
# new estimated n_0	214707
# score_function 0.000000
# Log likelihood	-1291430.616145
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	214707
# Log likelihood	-1291430.616145
# Observed clones	906533.000000
# Observed clones + estimated clones	1121240.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	269423
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.496396711426942, 2.040742035866317]
# new estimated n_0	269423
# score_function 0.000000
# Log likelihood	-1294111.877083
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	269423
# Log likelihood	-1294111.877083
# Observed clones	906533.000000
# Observed clones + estimated clones	1175956.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	329753
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.496396711426942, 2.040742035866317]
# new estimated n_0	329753
# score_function 0.000000
# Log likelihood	-1298843.703651
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	329753
# Log likelihood	-1298843.703651
# Observed clones	906533.000000
# Observed clones + estimated clones	1236286.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	396608
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.496396711426942, 2.040742035866317]
# new estimated n_0	396608
# score_function 0.000000
# Log likelihood	-1306209.120637
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	396608
# Log likelihood	-1306209.120637
# Observed clones	906533.000000
# Observed clones + estimated clones	1303141.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	471107
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.496396711426942, 2.040742035866317]
# new estimated n_0	471107
# score_function 0.000000
# Log likelihood	-1317024.578082
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	471107
# Log likelihood	-1317024.578082
# Observed clones	906533.000000
# Observed clones + estimated clones	1377640.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	554641
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.496396711426942, 2.040742035866317]
# new estimated n_0	554641
# score_function 0.000000
# Log likelihood	-1332472.476023
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	554641
# Log likelihood	-1332472.476023
# Observed clones	906533.000000
# Observed clones + estimated clones	1461174.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.496396711426942, 2.040742035866317]
# iteration 1
# old estimated n0	648959
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.496396711426942, 2.040742035866317]
# new estimated n_0	648959
# score_function 0.000000
# Log likelihood	-1354340.955386
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.496396711426942, 2.040742035866317]
# Final estimated_n0	648959
# Log likelihood	-1354340.955386
# Observed clones	906533.000000
# Observed clones + estimated clones	1555492.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	152654
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	152654
# score_function 0.000000
# Log likelihood	-1289828.787205
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	152654
# Log likelihood	-1289828.787205
# Observed clones	906533.000000
# Observed clones + estimated clones	1059187.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	180989
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	180989
# score_function 0.000000
# Log likelihood	-1290035.442697
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	180989
# Log likelihood	-1290035.442697
# Observed clones	906533.000000
# Observed clones + estimated clones	1087522.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	210883
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	210883
# score_function 0.000000
# Log likelihood	-1291741.545731
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	210883
# Log likelihood	-1291741.545731
# Observed clones	906533.000000
# Observed clones + estimated clones	1117416.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	242467
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	242467
# score_function 0.000000
# Log likelihood	-1295178.899897
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	242467
# Log likelihood	-1295178.899897
# Observed clones	906533.000000
# Observed clones + estimated clones	1149000.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	275888
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	275888
# score_function 0.000000
# Log likelihood	-1300648.490117
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	275888
# Log likelihood	-1300648.490117
# Observed clones	906533.000000
# Observed clones + estimated clones	1182421.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	311311
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	311311
# score_function 0.000000
# Log likelihood	-1308548.244772
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	311311
# Log likelihood	-1308548.244772
# Observed clones	906533.000000
# Observed clones + estimated clones	1217844.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	348923
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	348923
# score_function 0.000000
# Log likelihood	-1319416.996640
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	348923
# Log likelihood	-1319416.996640
# Observed clones	906533.000000
# Observed clones + estimated clones	1255456.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 0.8824830425367858, 2.040742035866317]
# iteration 1
# old estimated n0	388931
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [0.8824830425367858, 2.040742035866317]
# new estimated n_0	388931
# score_function 0.000000
# Log likelihood	-1334007.907310
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[0.8824830425367858, 2.040742035866317]
# Final estimated_n0	388931
# Log likelihood	-1334007.907310
# Observed clones	906533.000000
# Observed clones + estimated clones	1295464.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	144517
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	144517
# score_function 0.000000
# Log likelihood	-1289431.943420
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	144517
# Log likelihood	-1289431.943420
# Observed clones	906533.000000
# Observed clones + estimated clones	1051050.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	159206
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	159206
# score_function 0.000000
# Log likelihood	-1288542.797052
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	159206
# Log likelihood	-1288542.797052
# Observed clones	906533.000000
# Observed clones + estimated clones	1065739.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	174311
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	174311
# score_function 0.000000
# Log likelihood	-1288467.483182
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	174311
# Log likelihood	-1288467.483182
# Observed clones	906533.000000
# Observed clones + estimated clones	1080844.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	189851
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	189851
# score_function 0.000000
# Log likelihood	-1289280.086921
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	189851
# Log likelihood	-1289280.086921
# Observed clones	906533.000000
# Observed clones + estimated clones	1096384.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	205845
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	205845
# score_function 0.000000
# Log likelihood	-1291072.314786
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	205845
# Log likelihood	-1291072.314786
# Observed clones	906533.000000
# Observed clones + estimated clones	1112378.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	222311
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	222311
# score_function 0.000000
# Log likelihood	-1293958.601121
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	222311
# Log likelihood	-1293958.601121
# Observed clones	906533.000000
# Observed clones + estimated clones	1128844.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	239273
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	239273
# score_function 0.000000
# Log likelihood	-1298083.498291
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	239273
# Log likelihood	-1298083.498291
# Observed clones	906533.000000
# Observed clones + estimated clones	1145806.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.2685693736466293, 2.040742035866317]
# iteration 1
# old estimated n0	256752
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.2685693736466293, 2.040742035866317]
# new estimated n_0	256752
# score_function 0.000000
# Log likelihood	-1303632.770257
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.2685693736466293, 2.040742035866317]
# Final estimated_n0	256752
# Log likelihood	-1303632.770257
# Observed clones	906533.000000
# Observed clones + estimated clones	1163285.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	139057
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	139057
# score_function 0.000000
# Log likelihood	-1289564.116337
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	139057
# Log likelihood	-1289564.116337
# Observed clones	906533.000000
# Observed clones + estimated clones	1045590.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	144890
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	144890
# score_function 0.000000
# Log likelihood	-1288434.365184
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	144890
# Log likelihood	-1288434.365184
# Observed clones	906533.000000
# Observed clones + estimated clones	1051423.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	150790
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	150790
# score_function 0.000000
# Log likelihood	-1287524.153297
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	150790
# Log likelihood	-1287524.153297
# Observed clones	906533.000000
# Observed clones + estimated clones	1057323.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	156756
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	156756
# score_function 0.000000
# Log likelihood	-1286842.956851
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	156756
# Log likelihood	-1286842.956851
# Observed clones	906533.000000
# Observed clones + estimated clones	1063289.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	162789
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	162789
# score_function 0.000000
# Log likelihood	-1286401.575868
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	162789
# Log likelihood	-1286401.575868
# Observed clones	906533.000000
# Observed clones + estimated clones	1069322.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	168892
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	168892
# score_function 0.000000
# Log likelihood	-1286212.343546
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	168892
# Log likelihood	-1286212.343546
# Observed clones	906533.000000
# Observed clones + estimated clones	1075425.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	175064
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	175064
# score_function 0.000000
# Log likelihood	-1286289.389081
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	175064
# Log likelihood	-1286289.389081
# Observed clones	906533.000000
# Observed clones + estimated clones	1081597.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	181308
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [1.6546557047564732, 2.040742035866317]
# new estimated n_0	181308
# score_function 0.000000
# Log likelihood	-1286648.970827
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[1.6546557047564732, 2.040742035866317]
# Final estimated_n0	181308
# Log likelihood	-1286648.970827
# Observed clones	906533.000000
# Observed clones + estimated clones	1087841.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 2.040742035866317, 2.040742035866317]
# iteration 1
# old estimated n0	135378
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [2.040742035866317, 2.040742035866317]
# new estimated n_0	135378
# score_function 0.000000
# Log likelihood	-1290393.503235
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[2.040742035866317, 2.040742035866317]
# Final estimated_n0	135378
# Log likelihood	-1290393.503235
# Observed clones	906533.000000
# Observed clones + estimated clones	1041911.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.95, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	132892
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.95] [2.426828366976161, 2.040742035866317]
# new estimated n_0	132892
# score_function 0.000000
# Log likelihood	-1291943.009104
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.95]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	132892
# Log likelihood	-1291943.009104
# Observed clones	906533.000000
# Observed clones + estimated clones	1039425.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.87142857, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	129010
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143, 0.87142857] [2.426828366976161, 2.040742035866317]
# new estimated n_0	129010
# score_function 0.000000
# Log likelihood	-1294555.622099
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143, 0.87142857]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	129010
# Log likelihood	-1294555.622099
# Observed clones	906533.000000
# Observed clones + estimated clones	1035543.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.79285714, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	125156
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.79285714] [2.426828366976161, 2.040742035866317]
# new estimated n_0	125156
# score_function 0.000000
# Log likelihood	-1297376.804645
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.79285714]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	125156
# Log likelihood	-1297376.804645
# Observed clones	906533.000000
# Observed clones + estimated clones	1031689.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.71428571, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	121331
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.71428571] [2.426828366976161, 2.040742035866317]
# new estimated n_0	121331
# score_function 0.000000
# Log likelihood	-1300398.266623
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.71428571]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	121331
# Log likelihood	-1300398.266623
# Observed clones	906533.000000
# Observed clones + estimated clones	1027864.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.63571429, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	117535
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.63571429] [2.426828366976161, 2.040742035866317]
# new estimated n_0	117535
# score_function 0.000000
# Log likelihood	-1303613.079212
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.63571429]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	117535
# Log likelihood	-1303613.079212
# Observed clones	906533.000000
# Observed clones + estimated clones	1024068.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	113766
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [2.426828366976161, 2.040742035866317]
# new estimated n_0	113766
# score_function 0.000000
# Log likelihood	-1307015.457421
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	113766
# Log likelihood	-1307015.457421
# Observed clones	906533.000000
# Observed clones + estimated clones	1020299.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.47857143, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	110025
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.47857143] [2.426828366976161, 2.040742035866317]
# new estimated n_0	110025
# score_function 0.000000
# Log likelihood	-1310600.592380
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.47857143]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	110025
# Log likelihood	-1310600.592380
# Observed clones	906533.000000
# Observed clones + estimated clones	1016558.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.4, 2.426828366976161, 2.040742035866317]
# iteration 1
# old estimated n0	106311
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.4] [2.426828366976161, 2.040742035866317]
# new estimated n_0	106311
# score_function 0.000000
# Log likelihood	-1314364.526003
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.4]
# Fitted means	[2.426828366976161, 2.040742035866317]
# Final estimated_n0	106311
# Log likelihood	-1314364.526003
# Observed clones	906533.000000
# Observed clones + estimated clones	1012844.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.55714286, 0.8273278523782366, 2.040742035866317]
# iteration 1
# old estimated n0	328551
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.55714286] [0.8273278523782366, 2.040742035866317]
# new estimated n_0	328551
# score_function 0.000000
# Log likelihood	-1310570.104872
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.55714286]
# Fitted means	[0.8273278523782366, 2.040742035866317]
# Final estimated_n0	328551
# Log likelihood	-1310570.104872
# Observed clones	906533.000000
# Observed clones + estimated clones	1235084.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.482142855, 0.517857145, 1.2409917785673548, 2.040742035866317]
# iteration 1
# old estimated n0	236164
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.482142855, 0.517857145] [1.2409917785673548, 2.040742035866317]
# new estimated n_0	236164
# score_function 0.000000
# Log likelihood	-1296966.765147
#
# Completed iteration of clone sizes
# Fitted weights	[0.482142855, 0.517857145]
# Fitted means	[1.2409917785673548, 2.040742035866317]
# Final estimated_n0	236164
# Log likelihood	-1296966.765147
# Observed clones	906533.000000
# Observed clones + estimated clones	1142697.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 0.11031038031709822, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	218159
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [0.11031038031709822, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	218159
# score_function 0.000000
# Log likelihood	-1286895.449286
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[0.11031038031709822, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	218159
# Log likelihood	-1286895.449286
# Observed clones	906533.000000
# Observed clones + estimated clones	1124692.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.3859183642244898, 0.4855102057755102, 0.11031038031709822, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	305406
# ...
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[2.040742035866317, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	167165
# Log likelihood	-1286239.373111
# Observed clones	906533.000000
# Observed clones + estimated clones	1073698.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.3859183642244898, 0.4855102057755102, 2.040742035866317, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	164462
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.38591836422448983, 0.48551020577551024] [2.040742035866317, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	164462
# score_function 0.000000
# Log likelihood	-1286323.757158
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.38591836422448983, 0.48551020577551024]
# Fitted means	[2.040742035866317, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	164462
# Log likelihood	-1286323.757158
# Observed clones	906533.000000
# Observed clones + estimated clones	1070995.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.3511224454489796, 0.4417346945510204, 2.040742035866317, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	161774
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.3511224454489796, 0.4417346945510204] [2.040742035866317, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	161774
# score_function 0.000000
# Log likelihood	-1286458.293978
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.3511224454489796, 0.4417346945510204]
# Fitted means	[2.040742035866317, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	161774
# Log likelihood	-1286458.293978
# Observed clones	906533.000000
# Observed clones + estimated clones	1068307.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	164525
# Log likelihood	-1287010.870710
# Observed clones	906533.000000
# Observed clones + estimated clones	1071058.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.12857143, 0.3859183642244898, 0.4855102057755102, 2.426828366976161, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	157735
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.12857143000000001, 0.38591836422448983, 0.48551020577551024] [2.426828366976161, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	157735
# score_function 0.000000
# Log likelihood	-1288720.033730
#
# Completed iteration of clone sizes
# Fitted weights	[0.12857143000000001, 0.38591836422448983, 0.48551020577551024]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	157735
# Log likelihood	-1288720.033730
# Observed clones	906533.000000
# Observed clones + estimated clones	1064268.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.20714286, 0.3511224454489796, 0.4417346945510204, 2.426828366976161, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	151030
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.20714286, 0.3511224454489796, 0.4417346945510204] [2.426828366976161, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	151030
# score_function 0.000000
# Log likelihood	-1290941.174225
#
# Completed iteration of clone sizes
# Fitted weights	[0.20714286, 0.3511224454489796, 0.4417346945510204]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	151030
# Log likelihood	-1290941.174225
# Observed clones	906533.000000
# Observed clones + estimated clones	1057563.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.28571429, 0.3163265266734694, 0.3979591833265306, 2.426828366976161, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	144409
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.28571429, 0.3163265266734694, 0.3979591833265306] [2.426828366976161, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	144409
# score_function 0.000000
# Log likelihood	-1293634.978180
#
# Completed iteration of clone sizes
# Fitted weights	[0.28571429, 0.3163265266734694, 0.3979591833265306]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	144409
# Log likelihood	-1293634.978180
# Observed clones	906533.000000
# Observed clones + estimated clones	1050942.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.36428571, 0.2815306123265306, 0.3541836776734694, 2.426828366976161, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	137871
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.36428571, 0.2815306123265306, 0.3541836776734694] [2.426828366976161, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	137871
# score_function 0.000000
# Log likelihood	-1296770.370763
#
# Completed iteration of clone sizes
# Fitted weights	[0.36428571, 0.2815306123265306, 0.3541836776734694]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	137871
# Log likelihood	-1296770.370763
# Observed clones	906533.000000
# Observed clones + estimated clones	1044404.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.44285714, 0.2467346935510204, 0.3104081664489796, 2.426828366976161, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	131413
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.44285714, 0.2467346935510204, 0.3104081664489796] [2.426828366976161, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	131413
# score_function 0.000000
# Log likelihood	-1300322.563191
#
# Completed iteration of clone sizes
# Fitted weights	[0.44285714, 0.2467346935510204, 0.3104081664489796]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	131413
# Log likelihood	-1300322.563191
# Observed clones	906533.000000
# Observed clones + estimated clones	1037946.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.52142857, 0.2119387747755102, 0.2666326552244898, 2.426828366976161, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	125035
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.52142857, 0.2119387747755102, 0.2666326552244898] [2.426828366976161, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	125035
# score_function 0.000000
# Log likelihood	-1304271.733015
#
# Completed iteration of clone sizes
# Fitted weights	[0.52142857, 0.2119387747755102, 0.2666326552244898]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	125035
# Log likelihood	-1304271.733015
# Observed clones	906533.000000
# Observed clones + estimated clones	1031568.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.6, 0.17714285600000002, 0.222857144, 2.426828366976161, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	118735
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.6, 0.17714285600000002, 0.222857144] [2.426828366976161, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	118735
# score_function 0.000000
# Log likelihood	-1308602.103969
#
# Completed iteration of clone sizes
# Fitted weights	[0.6, 0.17714285600000002, 0.222857144]
# Fitted means	[2.426828366976161, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	118735
# Log likelihood	-1308602.103969
# Observed clones	906533.000000
# Observed clones + estimated clones	1025268.000000
# === END FIT ===
#
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 0.8273278523782366, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	187065
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [0.8273278523782366, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	187065
# score_function 0.000000
# Log likelihood	-1287645.031154
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[0.8273278523782366, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	187065
# Log likelihood	-1287645.031154
# Observed clones	906533.000000
# Observed clones + estimated clones	1093598.000000
# === END FIT ===
#
# SMALLER SPIKE TRIGGERED
# ==== BEGIN FIT ===
# initial parameters [0.05, 0.42071428299999997, 0.529285717, 1.4340349441222768, 1.6546557047564732, 2.040742035866317]
# iteration 1
# old estimated n0	174103
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Log likelihood is -inf!
# Fitted parameters (new_weights, new_means) [0.05, 0.42071428299999997, 0.529285717] [1.4340349441222768, 1.6546557047564732, 2.040742035866317]
# new estimated n_0	174103
# score_function 0.000000
# Log likelihood	-1286470.955392
#
# Completed iteration of clone sizes
# Fitted weights	[0.05, 0.42071428299999997, 0.529285717]
# Fitted means	[1.4340349441222768, 1.6546557047564732, 2.040742035866317]
# Final estimated_n0	174103
# Log likelihood	-1286470.955392
# Observed clones	906533.000000
# Observed clones + estimated clones	1080636.000000
# === END FIT ===
#
# ([0.44285714, 0.55714286], [1.6546557047564732, 2.040742035866317], 168892, {2: 320454, 1: 270970, 3: 205284, 4: 82550, 5: 22304, 6: 4325, 7: 576, 8: 62, 9: 8}, None, -1286212.3435455272, 2.7689406871795654)
